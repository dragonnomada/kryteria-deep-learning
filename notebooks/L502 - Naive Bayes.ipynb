# %% [markdown]
# > Teorema de Bayes
#
# $P(y \mid x_1, \dots, x_n) = \frac{P(y) P(x_1, \dots, x_n \mid y)}
#                                  {P(x_1, \dots, x_n)}$
#
# > Simplificando
#
# $P(y \mid x_1, \dots, x_n) = \frac{P(y) \prod_{i=1}^{n} P(x_i \mid y)}
#                                  {P(x_1, \dots, x_n)}$
#
# > Aproximando
#
# $\begin{align}\begin{aligned}P(y \mid x_1, \dots, x_n) \propto P(y) \prod_{i=1}^{n} P(x_i \mid y)\\\Downarrow\\\hat{y} = \arg\max_y P(y) \prod_{i=1}^{n} P(x_i \mid y),\end{aligned}\end{align}$

# %%
import pandas as pd

proyectos = pd.read_excel("D:\\data\\ProyectosFinalizados.xlsx", sheet_name="base")

def limpiar_columna(columna):
    # 1. Reemplazar caracteres especiales
    columna = columna.replace(" ", "_") \
        .replace("á", "a") \
        .replace("é", "e") \
        .replace("í", "i") \
        .replace("ó", "o") \
        .replace("ú", "u") \
        .replace("ñ", "n") \
        .replace("+", "_") \
        .replace(".", "_") \
        .replace("(", "_") \
        .replace(")", "")
    import re
    # 2. Poner un guion bajo entre cambio de letras de minúscula a mayúsculas
    columna = re.sub("([a-z])([A-Z])", "\\1_\\2", columna)
    # 3. Poner un guion bajo entre ID y letra
    columna = re.sub("ID([A-Za-z])", "ID_\\1", columna)
    # 4. Poner un guion bajo entre número y letra
    columna = re.sub("([0-9])([A-Za-z])", "\\1_\\2", columna)
    # 4. Poner un guion bajo entre letra y número
    columna = re.sub("([A-Za-z])([0-9])", "\\1_\\2", columna)
    # 5. Quitar un guion bajo entre letra y número
    columna = re.sub("([A-Za-z])_([0-9])", "\\1\\2", columna)
    # 6. Poner un guion bajo entre letra y número final
    columna = re.sub("([A-Za-z])([0-9])$", "\\1_\\2", columna)
    # 7. Convertir a mayúsculas
    columna = columna.upper()
    return columna

proyectos.columns = map(limpiar_columna, proyectos.columns.values)

proyectos.head()
# Out:
#    ID_PROYECTO EMPRESA  PETICION  PETICION_1  PET_EMPRESA
# 0            1  México    8318.0        8318   8318México  \
# 1            2  México    9619.0        9619   9619México
# 2            3  México   10438.0       10438  10438México
# 3            4  México   10522.0       10522  10522México
# 4            5  México   10528.0       10528  10528México
#
#                                               NOMBRE  CFP  EFICIENCIA
# 0  Modificación a la utileria de generación de pa...   12         NaN  \
# 1              Modificacion al programa Vbncarga.exe    2         NaN
# 2  Permisos para Cambios de puntos de Sembrado- P...   11         NaN
# 3             Corrección del informe TabuladoCredito   11         NaN
# 4  Corrección al Tabulado de Carteras y Hojas men...    4         NaN
#
#           PDR  ESFUERZO_TOTAL_P  ...  PDR_S  PDR_M_1  PDR_M_2 PDR_L LEAD_TIME
# 0   33.708333             404.5  ...    NaN      NaN      NaN   NaN     914.0  \
# 1  147.500000             295.0  ...    NaN      NaN      NaN   NaN     609.0
# 2   51.375455            1019.0  ...    NaN      NaN      NaN   NaN     519.0
# 3   47.727273             525.0  ...    NaN      NaN      NaN   NaN     493.0
# 4   26.290000             213.0  ...    NaN      NaN      NaN   NaN     557.0
#
#    F1_GESTIONDELA_DEMANDA F2_ELICITACION F3_CONTRUCCION  F4_FINAL  TAMANO
# 0                   825.0            8.0           42.0      35.0   10-29
# 1                   584.0            7.0           14.0       1.0     2-9
# 2                   461.0            2.0           37.0       1.0   10-29
# 3                   455.0            9.0           27.0       1.0   10-29
# 4                   520.0            5.0           30.0       0.0     2-9
#
# [5 rows x 138 columns]

# %%
# [Apriori >>>] CFP - NUM
# [Apriori] ARQUITECTURA_I - CAT + TEXTO
# [Apriori] LENGUAJE_I - CAT + TEXTO
# [Apriori] BDI - CAT + TEXTO
# [Apriori] FRAMEWORK_I - CAT + TEXTO
# [Priori] METODOLOGIA - CAT + TEXTO
# [Posteriori] EFICIENCIA - DEC

dataset = proyectos[ ["ID_PROYECTO", "CFP", "ARQUITECTURA_I", "LENGUAJE_I", "BDI", "FRAMEWORK_I", "METODOLOGIA", "EFICIENCIA"] ].copy()

import re

def normalizar(cat):
    if str(cat) == "nan":
        return "OTRO"
    return re.sub("\s*", "", str(cat)).upper()

dataset["ARQUITECTURA_I"] = dataset["ARQUITECTURA_I"].map(normalizar)
dataset["LENGUAJE_I"] = dataset["LENGUAJE_I"].map(normalizar)
dataset["BDI"] = dataset["BDI"].map(normalizar).fillna("OTRO")
dataset["FRAMEWORK_I"] = dataset["FRAMEWORK_I"].map(normalizar)
dataset["METODOLOGIA"] = dataset["METODOLOGIA"].map(normalizar)

dataset = dataset.dropna()

dataset.info()

print("ARQUITECTURAS")
print(dataset["ARQUITECTURA_I"].unique())
print("LENGUAJES")
print(dataset["LENGUAJE_I"].unique())
print("BASES DE DATOS")
print(dataset["BDI"].unique())
print("FRAMEWORKS")
print(dataset["FRAMEWORK_I"].unique())
print("METODOLOGÍAS")
print(dataset["METODOLOGIA"].unique())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1514 entries, 886 to 2954
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ID_PROYECTO     1514 non-null   int64
#  1   CFP             1514 non-null   int64
#  2   ARQUITECTURA_I  1514 non-null   object
#  3   LENGUAJE_I      1514 non-null   object
#  4   BDI             1514 non-null   object
#  5   FRAMEWORK_I     1514 non-null   object
#  6   METODOLOGIA     1514 non-null   object
#  7   EFICIENCIA      1514 non-null   float64
# dtypes: float64(1), int64(2), object(5)
# memory usage: 106.5+ KB
# ARQUITECTURAS
# ['CLIENTE/SERVIDOR' 'CAPAS' 'MVC' 'OTRO']
# LENGUAJES
# ['PHP' 'C++' 'C#' 'COLDFUSION' 'OTRO' 'JAVA' 'VISUALBASIC' 'TYPESCRIPT'
#  'OTROS']
# BASES DE DATOS
# ['POSTGRESQL' 'SQLSERVER' 'POSTGRESQL/INFORMIX' 'OTRO' 'INFORMIX' 'VOLTDB'
#  'MYSQL' 'DB2']
# FRAMEWORKS
# ['COPPELFRONTWEB' 'OTRO' 'CSHARP' 'RAC(PHP)' 'COPPELFRAMEWORKJAVA(V2.1.2)'
#  'CLIENTESWEB(ANGULAR,V1.6.3)' 'SPRINGBOOT(V2.0)' 'OTROS'
#  'SPRINGBOOT(V2.0.0)' 'COPPELFRAMEWORKANDROID(JAVAV1.1.0)' 'RAC'
#  'COPPELFRAMEWORKJAVA' 'VUEJS']
# METODOLOGÍAS
# ['CASCADA' 'ÁGIL']

# %%
cfp_mean = dataset["CFP"].mean()

cfp_mean
# Out:
# 45.89498018494056

# %%
import numpy as np

cfp_25 = np.quantile(dataset["CFP"], 0.25)
cfp_75 = np.quantile(dataset["CFP"], 0.75)

cfp_25, cfp_75
# Out:
# (6.0, 52.0)

# %%
eficiencia_mean = dataset["EFICIENCIA"].mean()
eficiencia_25 = np.quantile(dataset["EFICIENCIA"], 0.25)
eficiencia_75 = np.quantile(dataset["EFICIENCIA"], 0.75)

eficiencia_25, eficiencia_mean, eficiencia_75
# Out:
# (0.47862903276785673, 0.8178825563593339, 1.2412652093650638)

# %%
premises = [
    [
        ("CFP > mean(CFP)", lambda row: row["CFP"] > cfp_mean),
        ("CFP < mean(CFP)", lambda row: row["CFP"] < cfp_mean),
        ("CFP > q_25(CFP)", lambda row: row["CFP"] > cfp_25),
        ("CFP < q_25(CFP)", lambda row: row["CFP"] < cfp_25),
        ("CFP > q_75(CFP)", lambda row: row["CFP"] > cfp_75),
        ("CFP < q_75(CFP)", lambda row: row["CFP"] < cfp_75),
    ],
    [
        ("ARQUITECTURA=CLIENTE/SERVIDOR", lambda row: row["ARQUITECTURA_I"] == "CLIENTE/SERVIDOR"),
        ("ARQUITECTURA=CAPAS", lambda row: row["ARQUITECTURA_I"] == "CAPAS"),
        ("ARQUITECTURA=MVC", lambda row: row["ARQUITECTURA_I"] == "MVC"),
        ("ARQUITECTURA=OTRO", lambda row: row["ARQUITECTURA_I"] == "OTRO"),
    ],
    [
        ("LENGUAJE=PHP", lambda row: row["LENGUAJE_I"] == "PHP"),
        ("LENGUAJE=C++", lambda row: row["LENGUAJE_I"] == "C++"),
        ("LENGUAJE=C#", lambda row: row["LENGUAJE_I"] == "C#"),
        ("LENGUAJE=COLDFUSION", lambda row: row["LENGUAJE_I"] == "COLDFUSION"),
        ("LENGUAJE=OTRO", lambda row: row["LENGUAJE_I"] == "OTRO"),
        ("LENGUAJE=VISUALBASIC", lambda row: row["LENGUAJE_I"] == "VISUALBASIC"),
        ("LENGUAJE=TYPESCRIPT", lambda row: row["LENGUAJE_I"] == "TYPESCRIPT"),
        ("LENGUAJE=OTROS", lambda row: row["LENGUAJE_I"] == "OTROS"),
    ],
    [
        ("BD=POSTGRESQL", lambda row: row["BDI"] == "POSTGRESQL"),
        ("BD=SQLSERVER", lambda row: row["BDI"] == "SQLSERVER"),
        ("BD=POSTGRESQL/INFORMIX", lambda row: row["BDI"] == "POSTGRESQL/INFORMIX"),
        ("BD=OTRO", lambda row: row["BDI"] == "OTRO"),
        ("BD=INFORMIX", lambda row: row["BDI"] == "INFORMIX"),
        ("BD=VOLTDB", lambda row: row["BDI"] == "VOLTDB"),
        ("BD=MYSQL", lambda row: row["BDI"] == "MYSQL"),
        ("BD=DB2", lambda row: row["BDI"] == "DB2"),
    ],
    [
        ("FRAMEWORK=COPPELFRONTWEB", lambda row: row["FRAMEWORK_I"] == "COPPELFRONTWEB"),
        ("FRAMEWORK=OTRO", lambda row: row["FRAMEWORK_I"] == "OTRO"),
        ("FRAMEWORK=CSHARP", lambda row: row["FRAMEWORK_I"] == "CSHARP"),
        ("FRAMEWORK=RAC(PHP)", lambda row: row["FRAMEWORK_I"] == "RAC(PHP)"),
        ("FRAMEWORK=COPPELFRAMEWORKJAVA(V2.1.2)", lambda row: row["FRAMEWORK_I"] == "COPPELFRAMEWORKJAVA(V2.1.2)"),
        ("FRAMEWORK=CLIENTESWEB(ANGULAR,V1.6.3)", lambda row: row["FRAMEWORK_I"] == "CLIENTESWEB(ANGULAR,V1.6.3)"),
        ("FRAMEWORK=SPRINGBOOT(V2.0)", lambda row: row["FRAMEWORK_I"] == "SPRINGBOOT(V2.0)"),
        ("FRAMEWORK=OTROS", lambda row: row["FRAMEWORK_I"] == "OTROS"),
        ("FRAMEWORK=SPRINGBOOT(V2.0.0)", lambda row: row["FRAMEWORK_I"] == "SPRINGBOOT(V2.0.0)"),
        ("FRAMEWORK=COPPELFRAMEWORKANDROID(JAVAV1.1.0)", lambda row: row["FRAMEWORK_I"] == "COPPELFRAMEWORKANDROID(JAVAV1.1.0)"),
        ("FRAMEWORK=RAC", lambda row: row["FRAMEWORK_I"] == "RAC"),
        ("FRAMEWORK=COPPELFRAMEWORKJAVA", lambda row: row["FRAMEWORK_I"] == "COPPELFRAMEWORKJAVA"),
        ("FRAMEWORK=VUEJS", lambda row: row["FRAMEWORK_I"] == "VUEJS"),
    ],
    [
        ("METODOLOGÍA=CASCADA", lambda row: row["METODOLOGIA"] == "CASCADA"),
        ("METODOLOGÍA=ÁGIL", lambda row: row["METODOLOGIA"] == "ÁGIL"),
    ]
]

conclusions = [
    [
        ("EFICIENCIA > mean(EFICIENCIA)", lambda row: row["EFICIENCIA"] > eficiencia_mean),
        ("EFICIENCIA < mean(EFICIENCIA)", lambda row: row["EFICIENCIA"] < eficiencia_mean),
        ("EFICIENCIA > q_25(EFICIENCIA)", lambda row: row["EFICIENCIA"] > eficiencia_25),
        ("EFICIENCIA < q_25(EFICIENCIA)", lambda row: row["EFICIENCIA"] < eficiencia_25),
        ("EFICIENCIA > q_75(EFICIENCIA)", lambda row: row["EFICIENCIA"] > eficiencia_75),
        ("EFICIENCIA < q_75(EFICIENCIA)", lambda row: row["EFICIENCIA"] < eficiencia_75),
    ]
]

# %%
premises = [
    [
        ("CFP > mean(CFP)", lambda row: row["CFP"] > cfp_mean),
        ("CFP < mean(CFP)", lambda row: row["CFP"] < cfp_mean),
    ],
    [
        ("ARQUITECTURA=CLIENTE/SERVIDOR", lambda row: row["ARQUITECTURA_I"] == "CLIENTE/SERVIDOR"),
        ("ARQUITECTURA=CAPAS", lambda row: row["ARQUITECTURA_I"] == "CAPAS"),
        ("ARQUITECTURA=MVC", lambda row: row["ARQUITECTURA_I"] == "MVC"),
        ("ARQUITECTURA=OTRO", lambda row: row["ARQUITECTURA_I"] == "OTRO"),
    ],
    [
        ("LENGUAJE=PHP", lambda row: row["LENGUAJE_I"] == "PHP"),
        ("LENGUAJE=C++", lambda row: row["LENGUAJE_I"] == "C++"),
        ("LENGUAJE=C#", lambda row: row["LENGUAJE_I"] == "C#"),
    ],
    [
        ("BD=POSTGRESQL", lambda row: row["BDI"] == "POSTGRESQL"),
        ("BD=SQLSERVER", lambda row: row["BDI"] == "SQLSERVER"),
        ("BD=POSTGRESQL/INFORMIX", lambda row: row["BDI"] == "POSTGRESQL/INFORMIX"),
        ("BD=MYSQL", lambda row: row["BDI"] == "MYSQL"),
        ("BD=DB2", lambda row: row["BDI"] == "DB2"),
    ],
    [
        ("FRAMEWORK=COPPELFRONTWEB", lambda row: row["FRAMEWORK_I"] == "COPPELFRONTWEB"),
        ("FRAMEWORK=CSHARP", lambda row: row["FRAMEWORK_I"] == "CSHARP"),
        ("FRAMEWORK=RAC(PHP)", lambda row: row["FRAMEWORK_I"] == "RAC(PHP)"),
        ("FRAMEWORK=VUEJS", lambda row: row["FRAMEWORK_I"] == "VUEJS"),
        ("FRAMEWORK=OTRO", lambda row: row["FRAMEWORK_I"] == "OTRO"),
    ],
    [
        ("METODOLOGÍA=CASCADA", lambda row: row["METODOLOGIA"] == "CASCADA"),
        ("METODOLOGÍA=ÁGIL", lambda row: row["METODOLOGIA"] == "ÁGIL"),
    ]
]

conclusions = [
    [
        ("EFICIENCIA > mean(EFICIENCIA)", lambda row: row["EFICIENCIA"] > eficiencia_mean),
        ("EFICIENCIA < mean(EFICIENCIA)", lambda row: row["EFICIENCIA"] < eficiencia_mean),
    ]
]

# %%
# Seleccionar 2 premisas y una conclusión

from collections import defaultdict

occurrences = defaultdict(int)
supports = defaultdict(int)
confidences = defaultdict(float)

for premise_i in range(len(premises)):
    for premise_j in range(len(premises)):
        if premise_i == premise_j:
            continue

        sub_premises_i = premises[premise_i]
        sub_premises_j = premises[premise_j]

        for premise_i_label, premise_i_func in sub_premises_i:
            for premise_j_label, premise_j_func in sub_premises_j:
                for sub_conclusions in conclusions:
                    for conclusion_label, conclusion_func in sub_conclusions:
                        need_print = np.random.random() < 0.05

                        if need_print:
                            print("SI {} y {}, ENTONCES, {}".format(premise_i_label, premise_j_label, conclusion_label))

                        for index, row in dataset.iterrows():
                            if premise_i_func(row) and premise_j_func(row):
                                occurrences[(premise_i_label, premise_j_label)] += 1
                                total = occurrences[(premise_i_label, premise_j_label)]
                                if conclusion_func(row):
                                    supports[(premise_i_label, premise_j_label, conclusion_label)] += 1
                                    support = supports[(premise_i_label, premise_j_label, conclusion_label)]

                        support = supports[(premise_i_label, premise_j_label, conclusion_label)]
                        total = occurrences[(premise_i_label, premise_j_label)]

                        if total != 0:
                            confidences[(premise_i_label, premise_j_label, conclusion_label)] = 100 * support / total

                        confidence = confidences[(premise_i_label, premise_j_label, conclusion_label)]

                        if need_print:
                            print("SUPPORT: {} TOTAL: {} CONFIDENCE: {:.2f}".format(support, total, confidence))
# Out:
# SI CFP > mean(CFP) y ARQUITECTURA=MVC, ENTONCES, EFICIENCIA > mean(EFICIENCIA)
# SUPPORT: 0 TOTAL: 1 CONFIDENCE: 0.00
# SI CFP < mean(CFP) y ARQUITECTURA=CAPAS, ENTONCES, EFICIENCIA > mean(EFICIENCIA)
# SUPPORT: 68 TOTAL: 182 CONFIDENCE: 37.36
# SI CFP < mean(CFP) y ARQUITECTURA=OTRO, ENTONCES, EFICIENCIA < mean(EFICIENCIA)
# SUPPORT: 1 TOTAL: 8 CONFIDENCE: 12.50
# SI CFP > mean(CFP) y LENGUAJE=C#, ENTONCES, EFICIENCIA < mean(EFICIENCIA)
# SUPPORT: 44 TOTAL: 180 CONFIDENCE: 24.44
# SI CFP < mean(CFP) y LENGUAJE=PHP, ENTONCES, EFICIENCIA > mean(EFICIENCIA)
# SUPPORT: 135 TOTAL: 321 CONFIDENCE: 42.06
# SI CFP < mean(CFP) y FRAMEWORK=COPPELFRONTWEB, ENTONCES, EFICIENCIA > mean(EFICIENCIA)
# SUPPORT: 7 TOTAL: 24 CONFIDENCE: 29.17
# SI ARQUITECTURA=OTRO y BD=SQLSERVER, ENTONCES, EFICIENCIA < mean(EFICIENCIA)
# SUPPORT: 0 TOTAL: 0 CONFIDENCE: 0.00
# SI ARQUITECTURA=OTRO y BD=MYSQL, ENTONCES, EFICIENCIA < mean(EFICIENCIA)
# SUPPORT: 0 TOTAL: 0 CONFIDENCE: 0.00
# SI ARQUITECTURA=CAPAS y FRAMEWORK=RAC(PHP), ENTONCES, EFICIENCIA < mean(EFICIENCIA)
# SUPPORT: 17 TOTAL: 60 CONFIDENCE: 28.33
# SI ARQUITECTURA=OTRO y FRAMEWORK=VUEJS, ENTONCES, EFICIENCIA < mean(EFICIENCIA)
# SUPPORT: 0 TOTAL: 0 CONFIDENCE: 0.00
# SI ARQUITECTURA=MVC y METODOLOGÍA=CASCADA, ENTONCES, EFICIENCIA < mean(EFICIENCIA)
# SUPPORT: 1 TOTAL: 2 CONFIDENCE: 50.00
# SI LENGUAJE=PHP y ARQUITECTURA=CLIENTE/SERVIDOR, ENTONCES, EFICIENCIA < mean(EFICIENCIA)
# SUPPORT: 179 TOTAL: 680 CONFIDENCE: 26.32
# SI LENGUAJE=PHP y ARQUITECTURA=CAPAS, ENTONCES, EFICIENCIA < mean(EFICIENCIA)
# SUPPORT: 82 TOTAL: 250 CONFIDENCE: 32.80
# SI LENGUAJE=C++ y BD=MYSQL, ENTONCES, EFICIENCIA < mean(EFICIENCIA)
# SUPPORT: 0 TOTAL: 0 CONFIDENCE: 0.00
# SI LENGUAJE=C# y FRAMEWORK=OTRO, ENTONCES, EFICIENCIA > mean(EFICIENCIA)
# SUPPORT: 121 TOTAL: 252 CONFIDENCE: 48.02
# SI LENGUAJE=C# y METODOLOGÍA=CASCADA, ENTONCES, EFICIENCIA < mean(EFICIENCIA)
# SUPPORT: 138 TOTAL: 532 CONFIDENCE: 25.94
# SI BD=POSTGRESQL/INFORMIX y CFP < mean(CFP), ENTONCES, EFICIENCIA > mean(EFICIENCIA)
# SUPPORT: 40 TOTAL: 123 CONFIDENCE: 32.52
# SI BD=POSTGRESQL y ARQUITECTURA=CLIENTE/SERVIDOR, ENTONCES, EFICIENCIA > mean(EFICIENCIA)
# SUPPORT: 332 TOTAL: 682 CONFIDENCE: 48.68
# SI BD=POSTGRESQL y ARQUITECTURA=OTRO, ENTONCES, EFICIENCIA > mean(EFICIENCIA)
# SUPPORT: 0 TOTAL: 0 CONFIDENCE: 0.00
# SI BD=SQLSERVER y ARQUITECTURA=MVC, ENTONCES, EFICIENCIA < mean(EFICIENCIA)
# SUPPORT: 1 TOTAL: 2 CONFIDENCE: 50.00
# SI BD=MYSQL y ARQUITECTURA=CLIENTE/SERVIDOR, ENTONCES, EFICIENCIA > mean(EFICIENCIA)
# SUPPORT: 1 TOTAL: 3 CONFIDENCE: 33.33
# SI BD=MYSQL y ARQUITECTURA=CLIENTE/SERVIDOR, ENTONCES, EFICIENCIA < mean(EFICIENCIA)
# SUPPORT: 2 TOTAL: 6 CONFIDENCE: 33.33
# SI BD=SQLSERVER y LENGUAJE=C++, ENTONCES, EFICIENCIA < mean(EFICIENCIA)
# SUPPORT: 40 TOTAL: 154 CONFIDENCE: 25.97
# SI BD=SQLSERVER y FRAMEWORK=CSHARP, ENTONCES, EFICIENCIA < mean(EFICIENCIA)
# SUPPORT: 10 TOTAL: 46 CONFIDENCE: 21.74
# SI BD=POSTGRESQL/INFORMIX y METODOLOGÍA=CASCADA, ENTONCES, EFICIENCIA < mean(EFICIENCIA)
# SUPPORT: 92 TOTAL: 302 CONFIDENCE: 30.46
# SI FRAMEWORK=CSHARP y CFP > mean(CFP), ENTONCES, EFICIENCIA < mean(EFICIENCIA)
# SUPPORT: 6 TOTAL: 34 CONFIDENCE: 17.65
# SI FRAMEWORK=OTRO y CFP < mean(CFP), ENTONCES, EFICIENCIA > mean(EFICIENCIA)
# SUPPORT: 402 TOTAL: 921 CONFIDENCE: 43.65
# SI FRAMEWORK=OTRO y CFP < mean(CFP), ENTONCES, EFICIENCIA < mean(EFICIENCIA)
# SUPPORT: 519 TOTAL: 1842 CONFIDENCE: 28.18
# SI FRAMEWORK=COPPELFRONTWEB y BD=POSTGRESQL, ENTONCES, EFICIENCIA < mean(EFICIENCIA)
# SUPPORT: 15 TOTAL: 46 CONFIDENCE: 32.61
# SI FRAMEWORK=COPPELFRONTWEB y BD=POSTGRESQL/INFORMIX, ENTONCES, EFICIENCIA < mean(EFICIENCIA)
# SUPPORT: 3 TOTAL: 6 CONFIDENCE: 50.00
# SI FRAMEWORK=RAC(PHP) y BD=MYSQL, ENTONCES, EFICIENCIA > mean(EFICIENCIA)
# SUPPORT: 0 TOTAL: 0 CONFIDENCE: 0.00
# SI FRAMEWORK=VUEJS y BD=MYSQL, ENTONCES, EFICIENCIA < mean(EFICIENCIA)
# SUPPORT: 0 TOTAL: 0 CONFIDENCE: 0.00
# SI FRAMEWORK=OTRO y BD=SQLSERVER, ENTONCES, EFICIENCIA > mean(EFICIENCIA)
# SUPPORT: 138 TOTAL: 303 CONFIDENCE: 45.54
# SI METODOLOGÍA=CASCADA y ARQUITECTURA=CAPAS, ENTONCES, EFICIENCIA < mean(EFICIENCIA)
# SUPPORT: 148 TOTAL: 470 CONFIDENCE: 31.49
# SI METODOLOGÍA=CASCADA y ARQUITECTURA=MVC, ENTONCES, EFICIENCIA > mean(EFICIENCIA)
# SUPPORT: 0 TOTAL: 1 CONFIDENCE: 0.00
# SI METODOLOGÍA=ÁGIL y LENGUAJE=C#, ENTONCES, EFICIENCIA < mean(EFICIENCIA)
# SUPPORT: 22 TOTAL: 82 CONFIDENCE: 26.83
# SI METODOLOGÍA=CASCADA y BD=SQLSERVER, ENTONCES, EFICIENCIA < mean(EFICIENCIA)
# SUPPORT: 195 TOTAL: 736 CONFIDENCE: 26.49
# SI METODOLOGÍA=ÁGIL y BD=DB2, ENTONCES, EFICIENCIA < mean(EFICIENCIA)
# SUPPORT: 1 TOTAL: 6 CONFIDENCE: 16.67

# %%
from operator import itemgetter

# %%
sorted(occurrences.items(), key=itemgetter(1), reverse=True)
# Out:
# [(('ARQUITECTURA=CLIENTE/SERVIDOR', 'METODOLOGÍA=CASCADA'), 2292),
#  (('METODOLOGÍA=CASCADA', 'ARQUITECTURA=CLIENTE/SERVIDOR'), 2292),
#  (('FRAMEWORK=OTRO', 'METODOLOGÍA=CASCADA'), 2246),
#  (('METODOLOGÍA=CASCADA', 'FRAMEWORK=OTRO'), 2246),
#  (('ARQUITECTURA=CLIENTE/SERVIDOR', 'FRAMEWORK=OTRO'), 2062),
#  (('FRAMEWORK=OTRO', 'ARQUITECTURA=CLIENTE/SERVIDOR'), 2062),
#  (('CFP < mean(CFP)', 'METODOLOGÍA=CASCADA'), 2010),
#  (('METODOLOGÍA=CASCADA', 'CFP < mean(CFP)'), 2010),
#  (('CFP < mean(CFP)', 'FRAMEWORK=OTRO'), 1842),
#  (('FRAMEWORK=OTRO', 'CFP < mean(CFP)'), 1842),
#  (('CFP < mean(CFP)', 'ARQUITECTURA=CLIENTE/SERVIDOR'), 1814),
#  (('ARQUITECTURA=CLIENTE/SERVIDOR', 'CFP < mean(CFP)'), 1814),
#  (('BD=POSTGRESQL', 'METODOLOGÍA=CASCADA'), 1510),
#  (('METODOLOGÍA=CASCADA', 'BD=POSTGRESQL'), 1510),
#  (('ARQUITECTURA=CLIENTE/SERVIDOR', 'BD=POSTGRESQL'), 1364),
#  (('BD=POSTGRESQL', 'ARQUITECTURA=CLIENTE/SERVIDOR'), 1364),
#  (('BD=POSTGRESQL', 'FRAMEWORK=OTRO'), 1348),
#  (('FRAMEWORK=OTRO', 'BD=POSTGRESQL'), 1348),
#  (('CFP < mean(CFP)', 'BD=POSTGRESQL'), 1158),
#  (('BD=POSTGRESQL', 'CFP < mean(CFP)'), 1158),
#  (('LENGUAJE=PHP', 'METODOLOGÍA=CASCADA'), 864),
#  (('METODOLOGÍA=CASCADA', 'LENGUAJE=PHP'), 864),
#  (('LENGUAJE=C++', 'FRAMEWORK=OTRO'), 776),
#  (('FRAMEWORK=OTRO', 'LENGUAJE=C++'), 776),
#  (('ARQUITECTURA=CLIENTE/SERVIDOR', 'LENGUAJE=C++'), 768),
#  (('LENGUAJE=C++', 'ARQUITECTURA=CLIENTE/SERVIDOR'), 768),
#  (('CFP > mean(CFP)', 'METODOLOGÍA=CASCADA'), 764),
#  (('METODOLOGÍA=CASCADA', 'CFP > mean(CFP)'), 764),
#  (('LENGUAJE=C++', 'METODOLOGÍA=CASCADA'), 760),
#  (('METODOLOGÍA=CASCADA', 'LENGUAJE=C++'), 760),
#  (('BD=SQLSERVER', 'METODOLOGÍA=CASCADA'), 736),
#  (('METODOLOGÍA=CASCADA', 'BD=SQLSERVER'), 736),
#  (('LENGUAJE=PHP', 'FRAMEWORK=OTRO'), 686),
#  (('FRAMEWORK=OTRO', 'LENGUAJE=PHP'), 686),
#  (('ARQUITECTURA=CLIENTE/SERVIDOR', 'LENGUAJE=PHP'), 680),
#  (('LENGUAJE=PHP', 'ARQUITECTURA=CLIENTE/SERVIDOR'), 680),
#  (('CFP > mean(CFP)', 'ARQUITECTURA=CLIENTE/SERVIDOR'), 648),
#  (('ARQUITECTURA=CLIENTE/SERVIDOR', 'CFP > mean(CFP)'), 648),
#  (('CFP < mean(CFP)', 'LENGUAJE=PHP'), 642),
#  (('LENGUAJE=PHP', 'CFP < mean(CFP)'), 642),
#  (('ARQUITECTURA=CLIENTE/SERVIDOR', 'BD=SQLSERVER'), 636),
#  (('BD=SQLSERVER', 'ARQUITECTURA=CLIENTE/SERVIDOR'), 636),
#  (('CFP < mean(CFP)', 'LENGUAJE=C++'), 632),
#  (('LENGUAJE=C++', 'CFP < mean(CFP)'), 632),
#  (('CFP > mean(CFP)', 'FRAMEWORK=OTRO'), 606),
#  (('BD=SQLSERVER', 'FRAMEWORK=OTRO'), 606),
#  (('FRAMEWORK=OTRO', 'CFP > mean(CFP)'), 606),
#  (('FRAMEWORK=OTRO', 'BD=SQLSERVER'), 606),
#  (('LENGUAJE=C++', 'BD=POSTGRESQL'), 602),
#  (('BD=POSTGRESQL', 'LENGUAJE=C++'), 602),
#  (('CFP < mean(CFP)', 'BD=SQLSERVER'), 584),
#  (('BD=SQLSERVER', 'CFP < mean(CFP)'), 584),
#  (('LENGUAJE=PHP', 'BD=POSTGRESQL'), 576),
#  (('BD=POSTGRESQL', 'LENGUAJE=PHP'), 576),
#  (('LENGUAJE=C#', 'METODOLOGÍA=CASCADA'), 532),
#  (('METODOLOGÍA=CASCADA', 'LENGUAJE=C#'), 532),
#  (('ARQUITECTURA=CLIENTE/SERVIDOR', 'LENGUAJE=C#'), 522),
#  (('LENGUAJE=C#', 'ARQUITECTURA=CLIENTE/SERVIDOR'), 522),
#  (('LENGUAJE=C#', 'FRAMEWORK=OTRO'), 504),
#  (('FRAMEWORK=OTRO', 'LENGUAJE=C#'), 504),
#  (('ARQUITECTURA=CAPAS', 'METODOLOGÍA=CASCADA'), 470),
#  (('METODOLOGÍA=CASCADA', 'ARQUITECTURA=CAPAS'), 470),
#  (('CFP > mean(CFP)', 'BD=POSTGRESQL'), 458),
#  (('BD=POSTGRESQL', 'CFP > mean(CFP)'), 458),
#  (('CFP < mean(CFP)', 'LENGUAJE=C#'), 434),
#  (('LENGUAJE=C#', 'CFP < mean(CFP)'), 434),
#  (('LENGUAJE=C#', 'BD=SQLSERVER'), 398),
#  (('BD=SQLSERVER', 'LENGUAJE=C#'), 398),
#  (('ARQUITECTURA=CAPAS', 'FRAMEWORK=OTRO'), 374),
#  (('FRAMEWORK=OTRO', 'ARQUITECTURA=CAPAS'), 374),
#  (('CFP < mean(CFP)', 'ARQUITECTURA=CAPAS'), 364),
#  (('ARQUITECTURA=CAPAS', 'CFP < mean(CFP)'), 364),
#  (('BD=POSTGRESQL/INFORMIX', 'METODOLOGÍA=CASCADA'), 302),
#  (('METODOLOGÍA=CASCADA', 'BD=POSTGRESQL/INFORMIX'), 302),
#  (('CFP > mean(CFP)', 'LENGUAJE=PHP'), 290),
#  (('LENGUAJE=PHP', 'CFP > mean(CFP)'), 290),
#  (('ARQUITECTURA=CLIENTE/SERVIDOR', 'BD=POSTGRESQL/INFORMIX'), 288),
#  (('BD=POSTGRESQL/INFORMIX', 'ARQUITECTURA=CLIENTE/SERVIDOR'), 288),
#  (('BD=POSTGRESQL/INFORMIX', 'FRAMEWORK=OTRO'), 284),
#  (('FRAMEWORK=OTRO', 'BD=POSTGRESQL/INFORMIX'), 284),
#  (('CFP > mean(CFP)', 'BD=SQLSERVER'), 268),
#  (('BD=SQLSERVER', 'CFP > mean(CFP)'), 268),
#  (('ARQUITECTURA=CAPAS', 'BD=POSTGRESQL'), 252),
#  (('BD=POSTGRESQL', 'ARQUITECTURA=CAPAS'), 252),
#  (('ARQUITECTURA=CAPAS', 'LENGUAJE=PHP'), 250),
#  (('LENGUAJE=PHP', 'ARQUITECTURA=CAPAS'), 250),
#  (('CFP < mean(CFP)', 'BD=POSTGRESQL/INFORMIX'), 246),
#  (('BD=POSTGRESQL/INFORMIX', 'CFP < mean(CFP)'), 246),
#  (('LENGUAJE=PHP', 'BD=SQLSERVER'), 228),
#  (('BD=SQLSERVER', 'LENGUAJE=PHP'), 228),
#  (('ARQUITECTURA=CAPAS', 'BD=SQLSERVER'), 214),
#  (('BD=SQLSERVER', 'ARQUITECTURA=CAPAS'), 214),
#  (('LENGUAJE=C#', 'BD=POSTGRESQL'), 206),
#  (('BD=POSTGRESQL', 'LENGUAJE=C#'), 206),
#  (('FRAMEWORK=OTRO', 'METODOLOGÍA=ÁGIL'), 202),
#  (('METODOLOGÍA=ÁGIL', 'FRAMEWORK=OTRO'), 202),
#  (('CFP > mean(CFP)', 'ARQUITECTURA=CAPAS'), 188),
#  (('CFP > mean(CFP)', 'LENGUAJE=C++'), 188),
#  (('ARQUITECTURA=CAPAS', 'CFP > mean(CFP)'), 188),
#  (('LENGUAJE=C++', 'CFP > mean(CFP)'), 188),
#  (('CFP > mean(CFP)', 'LENGUAJE=C#'), 180),
#  (('LENGUAJE=C#', 'CFP > mean(CFP)'), 180),
#  (('CFP < mean(CFP)', 'METODOLOGÍA=ÁGIL'), 176),
#  (('METODOLOGÍA=ÁGIL', 'CFP < mean(CFP)'), 176),
#  (('ARQUITECTURA=CLIENTE/SERVIDOR', 'METODOLOGÍA=ÁGIL'), 170),
#  (('METODOLOGÍA=ÁGIL', 'ARQUITECTURA=CLIENTE/SERVIDOR'), 170),
#  (('LENGUAJE=C++', 'BD=SQLSERVER'), 154),
#  (('BD=SQLSERVER', 'LENGUAJE=C++'), 154),
#  (('FRAMEWORK=RAC(PHP)', 'METODOLOGÍA=CASCADA'), 122),
#  (('METODOLOGÍA=CASCADA', 'FRAMEWORK=RAC(PHP)'), 122),
#  (('BD=SQLSERVER', 'METODOLOGÍA=ÁGIL'), 116),
#  (('METODOLOGÍA=ÁGIL', 'BD=SQLSERVER'), 116),
#  (('LENGUAJE=PHP', 'FRAMEWORK=RAC(PHP)'), 114),
#  (('FRAMEWORK=RAC(PHP)', 'LENGUAJE=PHP'), 114),
#  (('BD=POSTGRESQL', 'METODOLOGÍA=ÁGIL'), 106),
#  (('METODOLOGÍA=ÁGIL', 'BD=POSTGRESQL'), 106),
#  (('LENGUAJE=PHP', 'BD=POSTGRESQL/INFORMIX'), 104),
#  (('BD=POSTGRESQL/INFORMIX', 'LENGUAJE=PHP'), 104),
#  (('FRAMEWORK=COPPELFRONTWEB', 'METODOLOGÍA=CASCADA'), 102),
#  (('METODOLOGÍA=CASCADA', 'FRAMEWORK=COPPELFRONTWEB'), 102),
#  (('CFP < mean(CFP)', 'FRAMEWORK=RAC(PHP)'), 94),
#  (('FRAMEWORK=RAC(PHP)', 'CFP < mean(CFP)'), 94),
#  (('ARQUITECTURA=CAPAS', 'LENGUAJE=C#'), 92),
#  (('LENGUAJE=C#', 'ARQUITECTURA=CAPAS'), 92),
#  (('LENGUAJE=PHP', 'FRAMEWORK=COPPELFRONTWEB'), 88),
#  (('FRAMEWORK=COPPELFRONTWEB', 'LENGUAJE=PHP'), 88),
#  (('ARQUITECTURA=CAPAS', 'METODOLOGÍA=ÁGIL'), 82),
#  (('LENGUAJE=C#', 'METODOLOGÍA=ÁGIL'), 82),
#  (('METODOLOGÍA=ÁGIL', 'ARQUITECTURA=CAPAS'), 82),
#  (('METODOLOGÍA=ÁGIL', 'LENGUAJE=C#'), 82),
#  (('CFP > mean(CFP)', 'METODOLOGÍA=ÁGIL'), 78),
#  (('METODOLOGÍA=ÁGIL', 'CFP > mean(CFP)'), 78),
#  (('LENGUAJE=C#', 'FRAMEWORK=CSHARP'), 76),
#  (('BD=SQLSERVER', 'FRAMEWORK=RAC(PHP)'), 76),
#  (('FRAMEWORK=CSHARP', 'LENGUAJE=C#'), 76),
#  (('FRAMEWORK=RAC(PHP)', 'BD=SQLSERVER'), 76),
#  (('ARQUITECTURA=CLIENTE/SERVIDOR', 'FRAMEWORK=COPPELFRONTWEB'), 70),
#  (('FRAMEWORK=COPPELFRONTWEB', 'ARQUITECTURA=CLIENTE/SERVIDOR'), 70),
#  (('FRAMEWORK=CSHARP', 'METODOLOGÍA=CASCADA'), 70),
#  (('METODOLOGÍA=CASCADA', 'FRAMEWORK=CSHARP'), 70),
#  (('ARQUITECTURA=CLIENTE/SERVIDOR', 'FRAMEWORK=RAC(PHP)'), 68),
#  (('LENGUAJE=PHP', 'METODOLOGÍA=ÁGIL'), 68),
#  (('FRAMEWORK=RAC(PHP)', 'ARQUITECTURA=CLIENTE/SERVIDOR'), 68),
#  (('METODOLOGÍA=ÁGIL', 'LENGUAJE=PHP'), 68),
#  (('CFP > mean(CFP)', 'BD=POSTGRESQL/INFORMIX'), 64),
#  (('BD=POSTGRESQL/INFORMIX', 'CFP > mean(CFP)'), 64),
#  (('ARQUITECTURA=CLIENTE/SERVIDOR', 'FRAMEWORK=CSHARP'), 60),
#  (('ARQUITECTURA=CAPAS', 'FRAMEWORK=RAC(PHP)'), 60),
#  (('LENGUAJE=C++', 'METODOLOGÍA=ÁGIL'), 60),
#  (('FRAMEWORK=CSHARP', 'ARQUITECTURA=CLIENTE/SERVIDOR'), 60),
#  (('FRAMEWORK=RAC(PHP)', 'ARQUITECTURA=CAPAS'), 60),
#  (('METODOLOGÍA=ÁGIL', 'LENGUAJE=C++'), 60),
#  (('CFP > mean(CFP)', 'FRAMEWORK=COPPELFRONTWEB'), 58),
#  (('FRAMEWORK=COPPELFRONTWEB', 'CFP > mean(CFP)'), 58),
#  (('BD=SQLSERVER', 'FRAMEWORK=COPPELFRONTWEB'), 54),
#  (('FRAMEWORK=COPPELFRONTWEB', 'BD=SQLSERVER'), 54),
#  (('ARQUITECTURA=CAPAS', 'LENGUAJE=C++'), 52),
#  (('LENGUAJE=C++', 'ARQUITECTURA=CAPAS'), 52),
#  (('BD=POSTGRESQL', 'FRAMEWORK=RAC(PHP)'), 50),
#  (('FRAMEWORK=RAC(PHP)', 'BD=POSTGRESQL'), 50),
#  (('CFP < mean(CFP)', 'FRAMEWORK=COPPELFRONTWEB'), 48),
#  (('FRAMEWORK=COPPELFRONTWEB', 'CFP < mean(CFP)'), 48),
#  (('CFP < mean(CFP)', 'FRAMEWORK=CSHARP'), 46),
#  (('BD=POSTGRESQL', 'FRAMEWORK=COPPELFRONTWEB'), 46),
#  (('BD=SQLSERVER', 'FRAMEWORK=CSHARP'), 46),
#  (('FRAMEWORK=CSHARP', 'CFP < mean(CFP)'), 46),
#  (('FRAMEWORK=COPPELFRONTWEB', 'BD=POSTGRESQL'), 46),
#  (('FRAMEWORK=CSHARP', 'BD=SQLSERVER'), 46),
#  (('LENGUAJE=C++', 'BD=POSTGRESQL/INFORMIX'), 42),
#  (('BD=POSTGRESQL/INFORMIX', 'LENGUAJE=C++'), 42),
#  (('CFP > mean(CFP)', 'FRAMEWORK=CSHARP'), 34),
#  (('CFP > mean(CFP)', 'FRAMEWORK=RAC(PHP)'), 34),
#  (('ARQUITECTURA=CAPAS', 'FRAMEWORK=COPPELFRONTWEB'), 34),
#  (('FRAMEWORK=CSHARP', 'CFP > mean(CFP)'), 34),
#  (('FRAMEWORK=RAC(PHP)', 'CFP > mean(CFP)'), 34),
#  (('FRAMEWORK=COPPELFRONTWEB', 'ARQUITECTURA=CAPAS'), 34),
#  (('BD=POSTGRESQL', 'FRAMEWORK=CSHARP'), 32),
#  (('FRAMEWORK=CSHARP', 'BD=POSTGRESQL'), 32),
#  (('ARQUITECTURA=CAPAS', 'BD=POSTGRESQL/INFORMIX'), 22),
#  (('BD=POSTGRESQL/INFORMIX', 'ARQUITECTURA=CAPAS'), 22),
#  (('ARQUITECTURA=CLIENTE/SERVIDOR', 'BD=DB2'), 20),
#  (('ARQUITECTURA=CAPAS', 'FRAMEWORK=CSHARP'), 20),
#  (('BD=DB2', 'ARQUITECTURA=CLIENTE/SERVIDOR'), 20),
#  (('BD=DB2', 'FRAMEWORK=OTRO'), 20),
#  (('BD=DB2', 'METODOLOGÍA=CASCADA'), 20),
#  (('FRAMEWORK=CSHARP', 'ARQUITECTURA=CAPAS'), 20),
#  (('FRAMEWORK=OTRO', 'BD=DB2'), 20),
#  (('METODOLOGÍA=CASCADA', 'BD=DB2'), 20),
#  (('CFP > mean(CFP)', 'BD=DB2'), 14),
#  (('BD=DB2', 'CFP > mean(CFP)'), 14),
#  (('CFP < mean(CFP)', 'BD=DB2'), 12),
#  (('ARQUITECTURA=OTRO', 'FRAMEWORK=OTRO'), 12),
#  (('BD=DB2', 'CFP < mean(CFP)'), 12),
#  (('FRAMEWORK=OTRO', 'ARQUITECTURA=OTRO'), 12),
#  (('ARQUITECTURA=OTRO', 'METODOLOGÍA=CASCADA'), 10),
#  (('FRAMEWORK=CSHARP', 'METODOLOGÍA=ÁGIL'), 10),
#  (('METODOLOGÍA=CASCADA', 'ARQUITECTURA=OTRO'), 10),
#  (('METODOLOGÍA=ÁGIL', 'FRAMEWORK=CSHARP'), 10),
#  (('CFP < mean(CFP)', 'ARQUITECTURA=OTRO'), 8),
#  (('ARQUITECTURA=OTRO', 'CFP < mean(CFP)'), 8),
#  (('LENGUAJE=C#', 'FRAMEWORK=RAC(PHP)'), 8),
#  (('BD=POSTGRESQL/INFORMIX', 'METODOLOGÍA=ÁGIL'), 8),
#  (('FRAMEWORK=RAC(PHP)', 'LENGUAJE=C#'), 8),
#  (('METODOLOGÍA=ÁGIL', 'BD=POSTGRESQL/INFORMIX'), 8),
#  (('ARQUITECTURA=CLIENTE/SERVIDOR', 'BD=MYSQL'), 6),
#  (('ARQUITECTURA=CAPAS', 'BD=DB2'), 6),
#  (('LENGUAJE=PHP', 'BD=MYSQL'), 6),
#  (('LENGUAJE=C#', 'FRAMEWORK=COPPELFRONTWEB'), 6),
#  (('BD=MYSQL', 'ARQUITECTURA=CLIENTE/SERVIDOR'), 6),
#  (('BD=DB2', 'ARQUITECTURA=CAPAS'), 6),
#  (('BD=MYSQL', 'LENGUAJE=PHP'), 6),
#  (('BD=POSTGRESQL/INFORMIX', 'FRAMEWORK=COPPELFRONTWEB'), 6),
#  (('BD=MYSQL', 'FRAMEWORK=OTRO'), 6),
#  (('BD=MYSQL', 'METODOLOGÍA=CASCADA'), 6),
#  (('BD=DB2', 'METODOLOGÍA=ÁGIL'), 6),
#  (('FRAMEWORK=COPPELFRONTWEB', 'LENGUAJE=C#'), 6),
#  (('FRAMEWORK=COPPELFRONTWEB', 'BD=POSTGRESQL/INFORMIX'), 6),
#  (('FRAMEWORK=OTRO', 'BD=MYSQL'), 6),
#  (('FRAMEWORK=RAC(PHP)', 'METODOLOGÍA=ÁGIL'), 6),
#  (('METODOLOGÍA=CASCADA', 'BD=MYSQL'), 6),
#  (('METODOLOGÍA=ÁGIL', 'BD=DB2'), 6),
#  (('METODOLOGÍA=ÁGIL', 'FRAMEWORK=RAC(PHP)'), 6),
#  (('CFP > mean(CFP)', 'ARQUITECTURA=OTRO'), 4),
#  (('CFP < mean(CFP)', 'BD=MYSQL'), 4),
#  (('ARQUITECTURA=OTRO', 'CFP > mean(CFP)'), 4),
#  (('LENGUAJE=C++', 'FRAMEWORK=COPPELFRONTWEB'), 4),
#  (('LENGUAJE=C++', 'FRAMEWORK=CSHARP'), 4),
#  (('LENGUAJE=C++', 'FRAMEWORK=RAC(PHP)'), 4),
#  (('BD=MYSQL', 'CFP < mean(CFP)'), 4),
#  (('FRAMEWORK=COPPELFRONTWEB', 'LENGUAJE=C++'), 4),
#  (('FRAMEWORK=CSHARP', 'LENGUAJE=C++'), 4),
#  (('FRAMEWORK=RAC(PHP)', 'LENGUAJE=C++'), 4),
#  (('FRAMEWORK=COPPELFRONTWEB', 'METODOLOGÍA=ÁGIL'), 4),
#  (('METODOLOGÍA=ÁGIL', 'FRAMEWORK=COPPELFRONTWEB'), 4),
#  (('CFP > mean(CFP)', 'ARQUITECTURA=MVC'), 2),
#  (('CFP > mean(CFP)', 'BD=MYSQL'), 2),
#  (('CFP > mean(CFP)', 'FRAMEWORK=VUEJS'), 2),
#  (('ARQUITECTURA=MVC', 'CFP > mean(CFP)'), 2),
#  (('ARQUITECTURA=MVC', 'LENGUAJE=PHP'), 2),
#  (('ARQUITECTURA=MVC', 'BD=SQLSERVER'), 2),
#  (('ARQUITECTURA=CAPAS', 'FRAMEWORK=VUEJS'), 2),
#  (('ARQUITECTURA=MVC', 'FRAMEWORK=COPPELFRONTWEB'), 2),
#  (('ARQUITECTURA=MVC', 'METODOLOGÍA=CASCADA'), 2),
#  (('ARQUITECTURA=OTRO', 'METODOLOGÍA=ÁGIL'), 2),
#  (('LENGUAJE=PHP', 'ARQUITECTURA=MVC'), 2),
#  (('LENGUAJE=C#', 'BD=POSTGRESQL/INFORMIX'), 2),
#  (('BD=MYSQL', 'CFP > mean(CFP)'), 2),
#  (('BD=SQLSERVER', 'ARQUITECTURA=MVC'), 2),
#  (('BD=POSTGRESQL/INFORMIX', 'LENGUAJE=C#'), 2),
#  (('BD=POSTGRESQL', 'FRAMEWORK=VUEJS'), 2),
#  (('FRAMEWORK=VUEJS', 'CFP > mean(CFP)'), 2),
#  (('FRAMEWORK=COPPELFRONTWEB', 'ARQUITECTURA=MVC'), 2),
#  (('FRAMEWORK=VUEJS', 'ARQUITECTURA=CAPAS'), 2),
#  (('FRAMEWORK=VUEJS', 'BD=POSTGRESQL'), 2),
#  (('FRAMEWORK=VUEJS', 'METODOLOGÍA=CASCADA'), 2),
#  (('METODOLOGÍA=CASCADA', 'ARQUITECTURA=MVC'), 2),
#  (('METODOLOGÍA=ÁGIL', 'ARQUITECTURA=OTRO'), 2),
#  (('METODOLOGÍA=CASCADA', 'FRAMEWORK=VUEJS'), 2),
#  (('CFP < mean(CFP)', 'ARQUITECTURA=MVC'), 0),
#  (('CFP < mean(CFP)', 'FRAMEWORK=VUEJS'), 0),
#  (('ARQUITECTURA=MVC', 'CFP < mean(CFP)'), 0),
#  (('ARQUITECTURA=MVC', 'LENGUAJE=C++'), 0),
#  (('ARQUITECTURA=MVC', 'LENGUAJE=C#'), 0),
#  (('ARQUITECTURA=OTRO', 'LENGUAJE=PHP'), 0),
#  (('ARQUITECTURA=OTRO', 'LENGUAJE=C++'), 0),
#  (('ARQUITECTURA=OTRO', 'LENGUAJE=C#'), 0),
#  (('ARQUITECTURA=CAPAS', 'BD=MYSQL'), 0),
#  (('ARQUITECTURA=MVC', 'BD=POSTGRESQL'), 0),
#  (('ARQUITECTURA=MVC', 'BD=POSTGRESQL/INFORMIX'), 0),
#  (('ARQUITECTURA=MVC', 'BD=MYSQL'), 0),
#  (('ARQUITECTURA=MVC', 'BD=DB2'), 0),
#  (('ARQUITECTURA=OTRO', 'BD=POSTGRESQL'), 0),
#  (('ARQUITECTURA=OTRO', 'BD=SQLSERVER'), 0),
#  (('ARQUITECTURA=OTRO', 'BD=POSTGRESQL/INFORMIX'), 0),
#  (('ARQUITECTURA=OTRO', 'BD=MYSQL'), 0),
#  (('ARQUITECTURA=OTRO', 'BD=DB2'), 0),
#  (('ARQUITECTURA=CLIENTE/SERVIDOR', 'FRAMEWORK=VUEJS'), 0),
#  (('ARQUITECTURA=MVC', 'FRAMEWORK=CSHARP'), 0),
#  (('ARQUITECTURA=MVC', 'FRAMEWORK=RAC(PHP)'), 0),
#  (('ARQUITECTURA=MVC', 'FRAMEWORK=VUEJS'), 0),
#  (('ARQUITECTURA=MVC', 'FRAMEWORK=OTRO'), 0),
#  (('ARQUITECTURA=OTRO', 'FRAMEWORK=COPPELFRONTWEB'), 0),
#  (('ARQUITECTURA=OTRO', 'FRAMEWORK=CSHARP'), 0),
#  (('ARQUITECTURA=OTRO', 'FRAMEWORK=RAC(PHP)'), 0),
#  (('ARQUITECTURA=OTRO', 'FRAMEWORK=VUEJS'), 0),
#  (('ARQUITECTURA=MVC', 'METODOLOGÍA=ÁGIL'), 0),
#  (('LENGUAJE=PHP', 'ARQUITECTURA=OTRO'), 0),
#  (('LENGUAJE=C++', 'ARQUITECTURA=MVC'), 0),
#  (('LENGUAJE=C++', 'ARQUITECTURA=OTRO'), 0),
#  (('LENGUAJE=C#', 'ARQUITECTURA=MVC'), 0),
#  (('LENGUAJE=C#', 'ARQUITECTURA=OTRO'), 0),
#  (('LENGUAJE=PHP', 'BD=DB2'), 0),
#  (('LENGUAJE=C++', 'BD=MYSQL'), 0),
#  (('LENGUAJE=C++', 'BD=DB2'), 0),
#  (('LENGUAJE=C#', 'BD=MYSQL'), 0),
#  (('LENGUAJE=C#', 'BD=DB2'), 0),
#  (('LENGUAJE=PHP', 'FRAMEWORK=CSHARP'), 0),
#  (('LENGUAJE=PHP', 'FRAMEWORK=VUEJS'), 0),
#  (('LENGUAJE=C++', 'FRAMEWORK=VUEJS'), 0),
#  (('LENGUAJE=C#', 'FRAMEWORK=VUEJS'), 0),
#  (('BD=POSTGRESQL', 'ARQUITECTURA=MVC'), 0),
#  (('BD=POSTGRESQL', 'ARQUITECTURA=OTRO'), 0),
#  (('BD=SQLSERVER', 'ARQUITECTURA=OTRO'), 0),
#  (('BD=POSTGRESQL/INFORMIX', 'ARQUITECTURA=MVC'), 0),
#  (('BD=POSTGRESQL/INFORMIX', 'ARQUITECTURA=OTRO'), 0),
#  (('BD=MYSQL', 'ARQUITECTURA=CAPAS'), 0),
#  (('BD=MYSQL', 'ARQUITECTURA=MVC'), 0),
#  (('BD=MYSQL', 'ARQUITECTURA=OTRO'), 0),
#  (('BD=DB2', 'ARQUITECTURA=MVC'), 0),
#  (('BD=DB2', 'ARQUITECTURA=OTRO'), 0),
#  (('BD=MYSQL', 'LENGUAJE=C++'), 0),
#  (('BD=MYSQL', 'LENGUAJE=C#'), 0),
#  (('BD=DB2', 'LENGUAJE=PHP'), 0),
#  (('BD=DB2', 'LENGUAJE=C++'), 0),
#  (('BD=DB2', 'LENGUAJE=C#'), 0),
#  (('BD=SQLSERVER', 'FRAMEWORK=VUEJS'), 0),
#  (('BD=POSTGRESQL/INFORMIX', 'FRAMEWORK=CSHARP'), 0),
#  (('BD=POSTGRESQL/INFORMIX', 'FRAMEWORK=RAC(PHP)'), 0),
#  (('BD=POSTGRESQL/INFORMIX', 'FRAMEWORK=VUEJS'), 0),
#  (('BD=MYSQL', 'FRAMEWORK=COPPELFRONTWEB'), 0),
#  (('BD=MYSQL', 'FRAMEWORK=CSHARP'), 0),
#  (('BD=MYSQL', 'FRAMEWORK=RAC(PHP)'), 0),
#  (('BD=MYSQL', 'FRAMEWORK=VUEJS'), 0),
#  (('BD=DB2', 'FRAMEWORK=COPPELFRONTWEB'), 0),
#  (('BD=DB2', 'FRAMEWORK=CSHARP'), 0),
#  (('BD=DB2', 'FRAMEWORK=RAC(PHP)'), 0),
#  (('BD=DB2', 'FRAMEWORK=VUEJS'), 0),
#  (('BD=MYSQL', 'METODOLOGÍA=ÁGIL'), 0),
#  (('FRAMEWORK=VUEJS', 'CFP < mean(CFP)'), 0),
#  (('FRAMEWORK=COPPELFRONTWEB', 'ARQUITECTURA=OTRO'), 0),
#  (('FRAMEWORK=CSHARP', 'ARQUITECTURA=MVC'), 0),
#  (('FRAMEWORK=CSHARP', 'ARQUITECTURA=OTRO'), 0),
#  (('FRAMEWORK=RAC(PHP)', 'ARQUITECTURA=MVC'), 0),
#  (('FRAMEWORK=RAC(PHP)', 'ARQUITECTURA=OTRO'), 0),
#  (('FRAMEWORK=VUEJS', 'ARQUITECTURA=CLIENTE/SERVIDOR'), 0),
#  (('FRAMEWORK=VUEJS', 'ARQUITECTURA=MVC'), 0),
#  (('FRAMEWORK=VUEJS', 'ARQUITECTURA=OTRO'), 0),
#  (('FRAMEWORK=OTRO', 'ARQUITECTURA=MVC'), 0),
#  (('FRAMEWORK=CSHARP', 'LENGUAJE=PHP'), 0),
#  (('FRAMEWORK=VUEJS', 'LENGUAJE=PHP'), 0),
#  (('FRAMEWORK=VUEJS', 'LENGUAJE=C++'), 0),
#  (('FRAMEWORK=VUEJS', 'LENGUAJE=C#'), 0),
#  (('FRAMEWORK=COPPELFRONTWEB', 'BD=MYSQL'), 0),
#  (('FRAMEWORK=COPPELFRONTWEB', 'BD=DB2'), 0),
#  (('FRAMEWORK=CSHARP', 'BD=POSTGRESQL/INFORMIX'), 0),
#  (('FRAMEWORK=CSHARP', 'BD=MYSQL'), 0),
#  (('FRAMEWORK=CSHARP', 'BD=DB2'), 0),
#  (('FRAMEWORK=RAC(PHP)', 'BD=POSTGRESQL/INFORMIX'), 0),
#  (('FRAMEWORK=RAC(PHP)', 'BD=MYSQL'), 0),
#  (('FRAMEWORK=RAC(PHP)', 'BD=DB2'), 0),
#  (('FRAMEWORK=VUEJS', 'BD=SQLSERVER'), 0),
#  (('FRAMEWORK=VUEJS', 'BD=POSTGRESQL/INFORMIX'), 0),
#  (('FRAMEWORK=VUEJS', 'BD=MYSQL'), 0),
#  (('FRAMEWORK=VUEJS', 'BD=DB2'), 0),
#  (('FRAMEWORK=VUEJS', 'METODOLOGÍA=ÁGIL'), 0),
#  (('METODOLOGÍA=ÁGIL', 'ARQUITECTURA=MVC'), 0),
#  (('METODOLOGÍA=ÁGIL', 'BD=MYSQL'), 0),
#  (('METODOLOGÍA=ÁGIL', 'FRAMEWORK=VUEJS'), 0)]

# %%
sorted(supports.items(), key=itemgetter(1), reverse=True)
# Out:
# [(('ARQUITECTURA=CLIENTE/SERVIDOR',
#    'METODOLOGÍA=CASCADA',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   601),
#  (('METODOLOGÍA=CASCADA',
#    'ARQUITECTURA=CLIENTE/SERVIDOR',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   601),
#  (('FRAMEWORK=OTRO', 'METODOLOGÍA=CASCADA', 'EFICIENCIA < mean(EFICIENCIA)'),
#   590),
#  (('METODOLOGÍA=CASCADA', 'FRAMEWORK=OTRO', 'EFICIENCIA < mean(EFICIENCIA)'),
#   590),
#  (('CFP < mean(CFP)', 'METODOLOGÍA=CASCADA', 'EFICIENCIA < mean(EFICIENCIA)'),
#   572),
#  (('METODOLOGÍA=CASCADA', 'CFP < mean(CFP)', 'EFICIENCIA < mean(EFICIENCIA)'),
#   572),
#  (('ARQUITECTURA=CLIENTE/SERVIDOR',
#    'METODOLOGÍA=CASCADA',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   545),
#  (('METODOLOGÍA=CASCADA',
#    'ARQUITECTURA=CLIENTE/SERVIDOR',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   545),
#  (('ARQUITECTURA=CLIENTE/SERVIDOR',
#    'FRAMEWORK=OTRO',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   537),
#  (('FRAMEWORK=OTRO',
#    'ARQUITECTURA=CLIENTE/SERVIDOR',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   537),
#  (('FRAMEWORK=OTRO', 'METODOLOGÍA=CASCADA', 'EFICIENCIA > mean(EFICIENCIA)'),
#   533),
#  (('METODOLOGÍA=CASCADA', 'FRAMEWORK=OTRO', 'EFICIENCIA > mean(EFICIENCIA)'),
#   533),
#  (('CFP < mean(CFP)', 'FRAMEWORK=OTRO', 'EFICIENCIA < mean(EFICIENCIA)'), 519),
#  (('FRAMEWORK=OTRO', 'CFP < mean(CFP)', 'EFICIENCIA < mean(EFICIENCIA)'), 519),
#  (('CFP < mean(CFP)',
#    'ARQUITECTURA=CLIENTE/SERVIDOR',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   512),
#  (('ARQUITECTURA=CLIENTE/SERVIDOR',
#    'CFP < mean(CFP)',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   512),
#  (('ARQUITECTURA=CLIENTE/SERVIDOR',
#    'FRAMEWORK=OTRO',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   494),
#  (('FRAMEWORK=OTRO',
#    'ARQUITECTURA=CLIENTE/SERVIDOR',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   494),
#  (('CFP < mean(CFP)', 'METODOLOGÍA=CASCADA', 'EFICIENCIA > mean(EFICIENCIA)'),
#   433),
#  (('METODOLOGÍA=CASCADA', 'CFP < mean(CFP)', 'EFICIENCIA > mean(EFICIENCIA)'),
#   433),
#  (('BD=POSTGRESQL', 'METODOLOGÍA=CASCADA', 'EFICIENCIA < mean(EFICIENCIA)'),
#   405),
#  (('METODOLOGÍA=CASCADA', 'BD=POSTGRESQL', 'EFICIENCIA < mean(EFICIENCIA)'),
#   405),
#  (('CFP < mean(CFP)', 'FRAMEWORK=OTRO', 'EFICIENCIA > mean(EFICIENCIA)'), 402),
#  (('FRAMEWORK=OTRO', 'CFP < mean(CFP)', 'EFICIENCIA > mean(EFICIENCIA)'), 402),
#  (('CFP < mean(CFP)',
#    'ARQUITECTURA=CLIENTE/SERVIDOR',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   395),
#  (('ARQUITECTURA=CLIENTE/SERVIDOR',
#    'CFP < mean(CFP)',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   395),
#  (('ARQUITECTURA=CLIENTE/SERVIDOR',
#    'BD=POSTGRESQL',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   350),
#  (('BD=POSTGRESQL',
#    'ARQUITECTURA=CLIENTE/SERVIDOR',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   350),
#  (('BD=POSTGRESQL', 'FRAMEWORK=OTRO', 'EFICIENCIA < mean(EFICIENCIA)'), 350),
#  (('BD=POSTGRESQL', 'METODOLOGÍA=CASCADA', 'EFICIENCIA > mean(EFICIENCIA)'),
#   350),
#  (('FRAMEWORK=OTRO', 'BD=POSTGRESQL', 'EFICIENCIA < mean(EFICIENCIA)'), 350),
#  (('METODOLOGÍA=CASCADA', 'BD=POSTGRESQL', 'EFICIENCIA > mean(EFICIENCIA)'),
#   350),
#  (('ARQUITECTURA=CLIENTE/SERVIDOR',
#    'BD=POSTGRESQL',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   332),
#  (('BD=POSTGRESQL',
#    'ARQUITECTURA=CLIENTE/SERVIDOR',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   332),
#  (('CFP < mean(CFP)', 'BD=POSTGRESQL', 'EFICIENCIA < mean(EFICIENCIA)'), 330),
#  (('BD=POSTGRESQL', 'CFP < mean(CFP)', 'EFICIENCIA < mean(EFICIENCIA)'), 330),
#  (('BD=POSTGRESQL', 'FRAMEWORK=OTRO', 'EFICIENCIA > mean(EFICIENCIA)'), 324),
#  (('FRAMEWORK=OTRO', 'BD=POSTGRESQL', 'EFICIENCIA > mean(EFICIENCIA)'), 324),
#  (('CFP < mean(CFP)', 'BD=POSTGRESQL', 'EFICIENCIA > mean(EFICIENCIA)'), 249),
#  (('BD=POSTGRESQL', 'CFP < mean(CFP)', 'EFICIENCIA > mean(EFICIENCIA)'), 249),
#  (('LENGUAJE=PHP', 'METODOLOGÍA=CASCADA', 'EFICIENCIA < mean(EFICIENCIA)'),
#   237),
#  (('METODOLOGÍA=CASCADA', 'LENGUAJE=PHP', 'EFICIENCIA < mean(EFICIENCIA)'),
#   237),
#  (('LENGUAJE=C++', 'FRAMEWORK=OTRO', 'EFICIENCIA < mean(EFICIENCIA)'), 210),
#  (('FRAMEWORK=OTRO', 'LENGUAJE=C++', 'EFICIENCIA < mean(EFICIENCIA)'), 210),
#  (('LENGUAJE=C++', 'METODOLOGÍA=CASCADA', 'EFICIENCIA < mean(EFICIENCIA)'),
#   208),
#  (('METODOLOGÍA=CASCADA', 'LENGUAJE=C++', 'EFICIENCIA < mean(EFICIENCIA)'),
#   208),
#  (('ARQUITECTURA=CLIENTE/SERVIDOR',
#    'LENGUAJE=C++',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   205),
#  (('LENGUAJE=C++',
#    'ARQUITECTURA=CLIENTE/SERVIDOR',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   205),
#  (('CFP > mean(CFP)', 'METODOLOGÍA=CASCADA', 'EFICIENCIA > mean(EFICIENCIA)'),
#   202),
#  (('METODOLOGÍA=CASCADA', 'CFP > mean(CFP)', 'EFICIENCIA > mean(EFICIENCIA)'),
#   202),
#  (('LENGUAJE=PHP', 'METODOLOGÍA=CASCADA', 'EFICIENCIA > mean(EFICIENCIA)'),
#   195),
#  (('BD=SQLSERVER', 'METODOLOGÍA=CASCADA', 'EFICIENCIA < mean(EFICIENCIA)'),
#   195),
#  (('METODOLOGÍA=CASCADA', 'LENGUAJE=PHP', 'EFICIENCIA > mean(EFICIENCIA)'),
#   195),
#  (('METODOLOGÍA=CASCADA', 'BD=SQLSERVER', 'EFICIENCIA < mean(EFICIENCIA)'),
#   195),
#  (('LENGUAJE=PHP', 'FRAMEWORK=OTRO', 'EFICIENCIA < mean(EFICIENCIA)'), 190),
#  (('FRAMEWORK=OTRO', 'LENGUAJE=PHP', 'EFICIENCIA < mean(EFICIENCIA)'), 190),
#  (('CFP < mean(CFP)', 'LENGUAJE=C++', 'EFICIENCIA < mean(EFICIENCIA)'), 187),
#  (('LENGUAJE=C++', 'CFP < mean(CFP)', 'EFICIENCIA < mean(EFICIENCIA)'), 187),
#  (('CFP < mean(CFP)', 'LENGUAJE=PHP', 'EFICIENCIA < mean(EFICIENCIA)'), 186),
#  (('LENGUAJE=PHP', 'CFP < mean(CFP)', 'EFICIENCIA < mean(EFICIENCIA)'), 186),
#  (('CFP > mean(CFP)',
#    'ARQUITECTURA=CLIENTE/SERVIDOR',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   183),
#  (('ARQUITECTURA=CLIENTE/SERVIDOR',
#    'CFP > mean(CFP)',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   183),
#  (('CFP > mean(CFP)', 'METODOLOGÍA=CASCADA', 'EFICIENCIA < mean(EFICIENCIA)'),
#   180),
#  (('METODOLOGÍA=CASCADA', 'CFP > mean(CFP)', 'EFICIENCIA < mean(EFICIENCIA)'),
#   180),
#  (('ARQUITECTURA=CLIENTE/SERVIDOR',
#    'LENGUAJE=PHP',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   179),
#  (('ARQUITECTURA=CLIENTE/SERVIDOR',
#    'LENGUAJE=C++',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   179),
#  (('LENGUAJE=PHP',
#    'ARQUITECTURA=CLIENTE/SERVIDOR',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   179),
#  (('LENGUAJE=C++',
#    'ARQUITECTURA=CLIENTE/SERVIDOR',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   179),
#  (('LENGUAJE=C++', 'FRAMEWORK=OTRO', 'EFICIENCIA > mean(EFICIENCIA)'), 178),
#  (('FRAMEWORK=OTRO', 'LENGUAJE=C++', 'EFICIENCIA > mean(EFICIENCIA)'), 178),
#  (('BD=SQLSERVER', 'METODOLOGÍA=CASCADA', 'EFICIENCIA > mean(EFICIENCIA)'),
#   173),
#  (('METODOLOGÍA=CASCADA', 'BD=SQLSERVER', 'EFICIENCIA > mean(EFICIENCIA)'),
#   173),
#  (('LENGUAJE=C++', 'METODOLOGÍA=CASCADA', 'EFICIENCIA > mean(EFICIENCIA)'),
#   172),
#  (('METODOLOGÍA=CASCADA', 'LENGUAJE=C++', 'EFICIENCIA > mean(EFICIENCIA)'),
#   172),
#  (('CFP > mean(CFP)', 'FRAMEWORK=OTRO', 'EFICIENCIA > mean(EFICIENCIA)'), 168),
#  (('FRAMEWORK=OTRO', 'CFP > mean(CFP)', 'EFICIENCIA > mean(EFICIENCIA)'), 168),
#  (('BD=SQLSERVER', 'FRAMEWORK=OTRO', 'EFICIENCIA < mean(EFICIENCIA)'), 165),
#  (('FRAMEWORK=OTRO', 'BD=SQLSERVER', 'EFICIENCIA < mean(EFICIENCIA)'), 165),
#  (('ARQUITECTURA=CLIENTE/SERVIDOR',
#    'BD=SQLSERVER',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   164),
#  (('BD=SQLSERVER',
#    'ARQUITECTURA=CLIENTE/SERVIDOR',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   164),
#  (('ARQUITECTURA=CLIENTE/SERVIDOR',
#    'LENGUAJE=PHP',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   161),
#  (('LENGUAJE=PHP',
#    'ARQUITECTURA=CLIENTE/SERVIDOR',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   161),
#  (('LENGUAJE=C++', 'BD=POSTGRESQL', 'EFICIENCIA < mean(EFICIENCIA)'), 160),
#  (('BD=POSTGRESQL', 'LENGUAJE=C++', 'EFICIENCIA < mean(EFICIENCIA)'), 160),
#  (('CFP < mean(CFP)', 'BD=SQLSERVER', 'EFICIENCIA < mean(EFICIENCIA)'), 158),
#  (('BD=SQLSERVER', 'CFP < mean(CFP)', 'EFICIENCIA < mean(EFICIENCIA)'), 158),
#  (('ARQUITECTURA=CLIENTE/SERVIDOR',
#    'BD=SQLSERVER',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   154),
#  (('BD=SQLSERVER',
#    'ARQUITECTURA=CLIENTE/SERVIDOR',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   154),
#  (('LENGUAJE=PHP', 'FRAMEWORK=OTRO', 'EFICIENCIA > mean(EFICIENCIA)'), 153),
#  (('FRAMEWORK=OTRO', 'LENGUAJE=PHP', 'EFICIENCIA > mean(EFICIENCIA)'), 153),
#  (('ARQUITECTURA=CAPAS',
#    'METODOLOGÍA=CASCADA',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   148),
#  (('METODOLOGÍA=CASCADA',
#    'ARQUITECTURA=CAPAS',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   148),
#  (('LENGUAJE=PHP', 'BD=POSTGRESQL', 'EFICIENCIA < mean(EFICIENCIA)'), 147),
#  (('BD=POSTGRESQL', 'LENGUAJE=PHP', 'EFICIENCIA < mean(EFICIENCIA)'), 147),
#  (('CFP > mean(CFP)',
#    'ARQUITECTURA=CLIENTE/SERVIDOR',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   141),
#  (('ARQUITECTURA=CLIENTE/SERVIDOR',
#    'CFP > mean(CFP)',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   141),
#  (('LENGUAJE=PHP', 'BD=POSTGRESQL', 'EFICIENCIA > mean(EFICIENCIA)'), 141),
#  (('LENGUAJE=C++', 'BD=POSTGRESQL', 'EFICIENCIA > mean(EFICIENCIA)'), 141),
#  (('BD=POSTGRESQL', 'LENGUAJE=PHP', 'EFICIENCIA > mean(EFICIENCIA)'), 141),
#  (('BD=POSTGRESQL', 'LENGUAJE=C++', 'EFICIENCIA > mean(EFICIENCIA)'), 141),
#  (('LENGUAJE=C#', 'METODOLOGÍA=CASCADA', 'EFICIENCIA < mean(EFICIENCIA)'),
#   138),
#  (('BD=SQLSERVER', 'FRAMEWORK=OTRO', 'EFICIENCIA > mean(EFICIENCIA)'), 138),
#  (('FRAMEWORK=OTRO', 'BD=SQLSERVER', 'EFICIENCIA > mean(EFICIENCIA)'), 138),
#  (('METODOLOGÍA=CASCADA', 'LENGUAJE=C#', 'EFICIENCIA < mean(EFICIENCIA)'),
#   138),
#  (('CFP < mean(CFP)', 'LENGUAJE=PHP', 'EFICIENCIA > mean(EFICIENCIA)'), 135),
#  (('CFP > mean(CFP)', 'FRAMEWORK=OTRO', 'EFICIENCIA < mean(EFICIENCIA)'), 135),
#  (('LENGUAJE=PHP', 'CFP < mean(CFP)', 'EFICIENCIA > mean(EFICIENCIA)'), 135),
#  (('FRAMEWORK=OTRO', 'CFP > mean(CFP)', 'EFICIENCIA < mean(EFICIENCIA)'), 135),
#  (('CFP < mean(CFP)', 'BD=SQLSERVER', 'EFICIENCIA > mean(EFICIENCIA)'), 134),
#  (('BD=SQLSERVER', 'CFP < mean(CFP)', 'EFICIENCIA > mean(EFICIENCIA)'), 134),
#  (('ARQUITECTURA=CLIENTE/SERVIDOR',
#    'LENGUAJE=C#',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   133),
#  (('LENGUAJE=C#',
#    'ARQUITECTURA=CLIENTE/SERVIDOR',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   133),
#  (('LENGUAJE=C#', 'FRAMEWORK=OTRO', 'EFICIENCIA < mean(EFICIENCIA)'), 131),
#  (('FRAMEWORK=OTRO', 'LENGUAJE=C#', 'EFICIENCIA < mean(EFICIENCIA)'), 131),
#  (('CFP < mean(CFP)', 'LENGUAJE=C++', 'EFICIENCIA > mean(EFICIENCIA)'), 129),
#  (('LENGUAJE=C++', 'CFP < mean(CFP)', 'EFICIENCIA > mean(EFICIENCIA)'), 129),
#  (('ARQUITECTURA=CLIENTE/SERVIDOR',
#    'LENGUAJE=C#',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   128),
#  (('LENGUAJE=C#',
#    'ARQUITECTURA=CLIENTE/SERVIDOR',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   128),
#  (('LENGUAJE=C#', 'METODOLOGÍA=CASCADA', 'EFICIENCIA > mean(EFICIENCIA)'),
#   128),
#  (('METODOLOGÍA=CASCADA', 'LENGUAJE=C#', 'EFICIENCIA > mean(EFICIENCIA)'),
#   128),
#  (('CFP > mean(CFP)', 'BD=POSTGRESQL', 'EFICIENCIA > mean(EFICIENCIA)'), 126),
#  (('BD=POSTGRESQL', 'CFP > mean(CFP)', 'EFICIENCIA > mean(EFICIENCIA)'), 126),
#  (('LENGUAJE=C#', 'FRAMEWORK=OTRO', 'EFICIENCIA > mean(EFICIENCIA)'), 121),
#  (('FRAMEWORK=OTRO', 'LENGUAJE=C#', 'EFICIENCIA > mean(EFICIENCIA)'), 121),
#  (('CFP < mean(CFP)', 'LENGUAJE=C#', 'EFICIENCIA < mean(EFICIENCIA)'), 116),
#  (('LENGUAJE=C#', 'CFP < mean(CFP)', 'EFICIENCIA < mean(EFICIENCIA)'), 116),
#  (('CFP < mean(CFP)', 'ARQUITECTURA=CAPAS', 'EFICIENCIA < mean(EFICIENCIA)'),
#   114),
#  (('ARQUITECTURA=CAPAS', 'CFP < mean(CFP)', 'EFICIENCIA < mean(EFICIENCIA)'),
#   114),
#  (('ARQUITECTURA=CAPAS', 'FRAMEWORK=OTRO', 'EFICIENCIA < mean(EFICIENCIA)'),
#   114),
#  (('FRAMEWORK=OTRO', 'ARQUITECTURA=CAPAS', 'EFICIENCIA < mean(EFICIENCIA)'),
#   114),
#  (('CFP > mean(CFP)', 'BD=POSTGRESQL', 'EFICIENCIA < mean(EFICIENCIA)'), 103),
#  (('BD=POSTGRESQL', 'CFP > mean(CFP)', 'EFICIENCIA < mean(EFICIENCIA)'), 103),
#  (('CFP < mean(CFP)', 'LENGUAJE=C#', 'EFICIENCIA > mean(EFICIENCIA)'), 101),
#  (('LENGUAJE=C#', 'CFP < mean(CFP)', 'EFICIENCIA > mean(EFICIENCIA)'), 101),
#  (('LENGUAJE=C#', 'BD=SQLSERVER', 'EFICIENCIA < mean(EFICIENCIA)'), 100),
#  (('BD=SQLSERVER', 'LENGUAJE=C#', 'EFICIENCIA < mean(EFICIENCIA)'), 100),
#  (('LENGUAJE=C#', 'BD=SQLSERVER', 'EFICIENCIA > mean(EFICIENCIA)'), 99),
#  (('BD=SQLSERVER', 'LENGUAJE=C#', 'EFICIENCIA > mean(EFICIENCIA)'), 99),
#  (('BD=POSTGRESQL/INFORMIX',
#    'METODOLOGÍA=CASCADA',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   92),
#  (('METODOLOGÍA=CASCADA',
#    'BD=POSTGRESQL/INFORMIX',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   92),
#  (('ARQUITECTURA=CLIENTE/SERVIDOR',
#    'BD=POSTGRESQL/INFORMIX',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   89),
#  (('BD=POSTGRESQL/INFORMIX',
#    'ARQUITECTURA=CLIENTE/SERVIDOR',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   89),
#  (('ARQUITECTURA=CAPAS',
#    'METODOLOGÍA=CASCADA',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   87),
#  (('METODOLOGÍA=CASCADA',
#    'ARQUITECTURA=CAPAS',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   87),
#  (('BD=POSTGRESQL/INFORMIX',
#    'FRAMEWORK=OTRO',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   85),
#  (('FRAMEWORK=OTRO',
#    'BD=POSTGRESQL/INFORMIX',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   85),
#  (('CFP < mean(CFP)',
#    'BD=POSTGRESQL/INFORMIX',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   83),
#  (('ARQUITECTURA=CAPAS', 'BD=POSTGRESQL', 'EFICIENCIA < mean(EFICIENCIA)'),
#   83),
#  (('BD=POSTGRESQL/INFORMIX',
#    'CFP < mean(CFP)',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   83),
#  (('BD=POSTGRESQL', 'ARQUITECTURA=CAPAS', 'EFICIENCIA < mean(EFICIENCIA)'),
#   83),
#  (('ARQUITECTURA=CAPAS', 'LENGUAJE=PHP', 'EFICIENCIA < mean(EFICIENCIA)'), 82),
#  (('LENGUAJE=PHP', 'ARQUITECTURA=CAPAS', 'EFICIENCIA < mean(EFICIENCIA)'), 82),
#  (('CFP > mean(CFP)', 'LENGUAJE=PHP', 'EFICIENCIA < mean(EFICIENCIA)'), 76),
#  (('LENGUAJE=PHP', 'CFP > mean(CFP)', 'EFICIENCIA < mean(EFICIENCIA)'), 76),
#  (('CFP > mean(CFP)', 'BD=SQLSERVER', 'EFICIENCIA < mean(EFICIENCIA)'), 75),
#  (('BD=SQLSERVER', 'CFP > mean(CFP)', 'EFICIENCIA < mean(EFICIENCIA)'), 75),
#  (('ARQUITECTURA=CAPAS', 'FRAMEWORK=OTRO', 'EFICIENCIA > mean(EFICIENCIA)'),
#   73),
#  (('FRAMEWORK=OTRO', 'ARQUITECTURA=CAPAS', 'EFICIENCIA > mean(EFICIENCIA)'),
#   73),
#  (('LENGUAJE=PHP', 'BD=SQLSERVER', 'EFICIENCIA < mean(EFICIENCIA)'), 72),
#  (('BD=SQLSERVER', 'LENGUAJE=PHP', 'EFICIENCIA < mean(EFICIENCIA)'), 72),
#  (('CFP > mean(CFP)', 'LENGUAJE=PHP', 'EFICIENCIA > mean(EFICIENCIA)'), 69),
#  (('LENGUAJE=PHP', 'CFP > mean(CFP)', 'EFICIENCIA > mean(EFICIENCIA)'), 69),
#  (('CFP < mean(CFP)', 'ARQUITECTURA=CAPAS', 'EFICIENCIA > mean(EFICIENCIA)'),
#   68),
#  (('ARQUITECTURA=CAPAS', 'CFP < mean(CFP)', 'EFICIENCIA > mean(EFICIENCIA)'),
#   68),
#  (('ARQUITECTURA=CAPAS', 'BD=SQLSERVER', 'EFICIENCIA < mean(EFICIENCIA)'), 68),
#  (('BD=SQLSERVER', 'ARQUITECTURA=CAPAS', 'EFICIENCIA < mean(EFICIENCIA)'), 68),
#  (('FRAMEWORK=OTRO', 'METODOLOGÍA=ÁGIL', 'EFICIENCIA < mean(EFICIENCIA)'), 64),
#  (('METODOLOGÍA=ÁGIL', 'FRAMEWORK=OTRO', 'EFICIENCIA < mean(EFICIENCIA)'), 64),
#  (('CFP > mean(CFP)', 'BD=SQLSERVER', 'EFICIENCIA > mean(EFICIENCIA)'), 59),
#  (('BD=SQLSERVER', 'CFP > mean(CFP)', 'EFICIENCIA > mean(EFICIENCIA)'), 59),
#  (('BD=POSTGRESQL/INFORMIX',
#    'METODOLOGÍA=CASCADA',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   59),
#  (('METODOLOGÍA=CASCADA',
#    'BD=POSTGRESQL/INFORMIX',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   59),
#  (('CFP > mean(CFP)', 'ARQUITECTURA=CAPAS', 'EFICIENCIA < mean(EFICIENCIA)'),
#   57),
#  (('ARQUITECTURA=CAPAS', 'CFP > mean(CFP)', 'EFICIENCIA < mean(EFICIENCIA)'),
#   57),
#  (('BD=POSTGRESQL/INFORMIX',
#    'FRAMEWORK=OTRO',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   57),
#  (('FRAMEWORK=OTRO',
#    'BD=POSTGRESQL/INFORMIX',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   57),
#  (('CFP > mean(CFP)', 'LENGUAJE=C++', 'EFICIENCIA > mean(EFICIENCIA)'), 56),
#  (('LENGUAJE=C++', 'CFP > mean(CFP)', 'EFICIENCIA > mean(EFICIENCIA)'), 56),
#  (('LENGUAJE=C#', 'BD=POSTGRESQL', 'EFICIENCIA < mean(EFICIENCIA)'), 56),
#  (('BD=POSTGRESQL', 'LENGUAJE=C#', 'EFICIENCIA < mean(EFICIENCIA)'), 56),
#  (('CFP < mean(CFP)', 'METODOLOGÍA=ÁGIL', 'EFICIENCIA < mean(EFICIENCIA)'),
#   55),
#  (('ARQUITECTURA=CLIENTE/SERVIDOR',
#    'BD=POSTGRESQL/INFORMIX',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   55),
#  (('BD=POSTGRESQL/INFORMIX',
#    'ARQUITECTURA=CLIENTE/SERVIDOR',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   55),
#  (('METODOLOGÍA=ÁGIL', 'CFP < mean(CFP)', 'EFICIENCIA < mean(EFICIENCIA)'),
#   55),
#  (('ARQUITECTURA=CLIENTE/SERVIDOR',
#    'METODOLOGÍA=ÁGIL',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   52),
#  (('METODOLOGÍA=ÁGIL',
#    'ARQUITECTURA=CLIENTE/SERVIDOR',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   52),
#  (('LENGUAJE=C#', 'BD=POSTGRESQL', 'EFICIENCIA > mean(EFICIENCIA)'), 47),
#  (('BD=POSTGRESQL', 'LENGUAJE=C#', 'EFICIENCIA > mean(EFICIENCIA)'), 47),
#  (('CFP > mean(CFP)', 'LENGUAJE=C#', 'EFICIENCIA > mean(EFICIENCIA)'), 46),
#  (('LENGUAJE=C#', 'CFP > mean(CFP)', 'EFICIENCIA > mean(EFICIENCIA)'), 46),
#  (('CFP > mean(CFP)', 'LENGUAJE=C#', 'EFICIENCIA < mean(EFICIENCIA)'), 44),
#  (('LENGUAJE=C#', 'CFP > mean(CFP)', 'EFICIENCIA < mean(EFICIENCIA)'), 44),
#  (('ARQUITECTURA=CAPAS', 'LENGUAJE=PHP', 'EFICIENCIA > mean(EFICIENCIA)'), 43),
#  (('ARQUITECTURA=CAPAS', 'BD=POSTGRESQL', 'EFICIENCIA > mean(EFICIENCIA)'),
#   43),
#  (('LENGUAJE=PHP', 'ARQUITECTURA=CAPAS', 'EFICIENCIA > mean(EFICIENCIA)'), 43),
#  (('BD=POSTGRESQL', 'ARQUITECTURA=CAPAS', 'EFICIENCIA > mean(EFICIENCIA)'),
#   43),
#  (('LENGUAJE=PHP', 'BD=SQLSERVER', 'EFICIENCIA > mean(EFICIENCIA)'), 42),
#  (('BD=SQLSERVER', 'LENGUAJE=PHP', 'EFICIENCIA > mean(EFICIENCIA)'), 42),
#  (('CFP < mean(CFP)',
#    'BD=POSTGRESQL/INFORMIX',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   40),
#  (('LENGUAJE=C++', 'BD=SQLSERVER', 'EFICIENCIA < mean(EFICIENCIA)'), 40),
#  (('BD=POSTGRESQL/INFORMIX',
#    'CFP < mean(CFP)',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   40),
#  (('BD=SQLSERVER', 'LENGUAJE=C++', 'EFICIENCIA < mean(EFICIENCIA)'), 40),
#  (('ARQUITECTURA=CAPAS', 'BD=SQLSERVER', 'EFICIENCIA > mean(EFICIENCIA)'), 39),
#  (('BD=SQLSERVER', 'ARQUITECTURA=CAPAS', 'EFICIENCIA > mean(EFICIENCIA)'), 39),
#  (('CFP > mean(CFP)', 'LENGUAJE=C++', 'EFICIENCIA < mean(EFICIENCIA)'), 38),
#  (('LENGUAJE=C++', 'CFP > mean(CFP)', 'EFICIENCIA < mean(EFICIENCIA)'), 38),
#  (('BD=SQLSERVER', 'METODOLOGÍA=ÁGIL', 'EFICIENCIA < mean(EFICIENCIA)'), 38),
#  (('METODOLOGÍA=ÁGIL', 'BD=SQLSERVER', 'EFICIENCIA < mean(EFICIENCIA)'), 38),
#  (('CFP > mean(CFP)', 'ARQUITECTURA=CAPAS', 'EFICIENCIA > mean(EFICIENCIA)'),
#   37),
#  (('ARQUITECTURA=CAPAS', 'CFP > mean(CFP)', 'EFICIENCIA > mean(EFICIENCIA)'),
#   37),
#  (('LENGUAJE=C++', 'BD=SQLSERVER', 'EFICIENCIA > mean(EFICIENCIA)'), 37),
#  (('BD=SQLSERVER', 'LENGUAJE=C++', 'EFICIENCIA > mean(EFICIENCIA)'), 37),
#  (('FRAMEWORK=OTRO', 'METODOLOGÍA=ÁGIL', 'EFICIENCIA > mean(EFICIENCIA)'), 37),
#  (('METODOLOGÍA=ÁGIL', 'FRAMEWORK=OTRO', 'EFICIENCIA > mean(EFICIENCIA)'), 37),
#  (('LENGUAJE=PHP', 'BD=POSTGRESQL/INFORMIX', 'EFICIENCIA < mean(EFICIENCIA)'),
#   36),
#  (('BD=POSTGRESQL/INFORMIX', 'LENGUAJE=PHP', 'EFICIENCIA < mean(EFICIENCIA)'),
#   36),
#  (('FRAMEWORK=COPPELFRONTWEB',
#    'METODOLOGÍA=CASCADA',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   35),
#  (('METODOLOGÍA=CASCADA',
#    'FRAMEWORK=COPPELFRONTWEB',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   35),
#  (('CFP < mean(CFP)', 'METODOLOGÍA=ÁGIL', 'EFICIENCIA > mean(EFICIENCIA)'),
#   33),
#  (('ARQUITECTURA=CLIENTE/SERVIDOR',
#    'METODOLOGÍA=ÁGIL',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   33),
#  (('FRAMEWORK=RAC(PHP)',
#    'METODOLOGÍA=CASCADA',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   33),
#  (('METODOLOGÍA=ÁGIL', 'CFP < mean(CFP)', 'EFICIENCIA > mean(EFICIENCIA)'),
#   33),
#  (('METODOLOGÍA=ÁGIL',
#    'ARQUITECTURA=CLIENTE/SERVIDOR',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   33),
#  (('METODOLOGÍA=CASCADA',
#    'FRAMEWORK=RAC(PHP)',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   33),
#  (('LENGUAJE=PHP', 'FRAMEWORK=RAC(PHP)', 'EFICIENCIA < mean(EFICIENCIA)'), 32),
#  (('FRAMEWORK=RAC(PHP)', 'LENGUAJE=PHP', 'EFICIENCIA < mean(EFICIENCIA)'), 32),
#  (('LENGUAJE=PHP',
#    'FRAMEWORK=COPPELFRONTWEB',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   30),
#  (('FRAMEWORK=COPPELFRONTWEB',
#    'LENGUAJE=PHP',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   30),
#  (('BD=POSTGRESQL', 'METODOLOGÍA=ÁGIL', 'EFICIENCIA < mean(EFICIENCIA)'), 28),
#  (('FRAMEWORK=RAC(PHP)',
#    'METODOLOGÍA=CASCADA',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   28),
#  (('METODOLOGÍA=ÁGIL', 'BD=POSTGRESQL', 'EFICIENCIA < mean(EFICIENCIA)'), 28),
#  (('METODOLOGÍA=CASCADA',
#    'FRAMEWORK=RAC(PHP)',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   28),
#  (('CFP < mean(CFP)', 'FRAMEWORK=RAC(PHP)', 'EFICIENCIA < mean(EFICIENCIA)'),
#   27),
#  (('ARQUITECTURA=CAPAS', 'LENGUAJE=C#', 'EFICIENCIA < mean(EFICIENCIA)'), 27),
#  (('LENGUAJE=C#', 'ARQUITECTURA=CAPAS', 'EFICIENCIA < mean(EFICIENCIA)'), 27),
#  (('FRAMEWORK=RAC(PHP)', 'CFP < mean(CFP)', 'EFICIENCIA < mean(EFICIENCIA)'),
#   27),
#  (('LENGUAJE=PHP', 'FRAMEWORK=RAC(PHP)', 'EFICIENCIA > mean(EFICIENCIA)'), 25),
#  (('LENGUAJE=PHP', 'METODOLOGÍA=ÁGIL', 'EFICIENCIA < mean(EFICIENCIA)'), 25),
#  (('BD=POSTGRESQL', 'METODOLOGÍA=ÁGIL', 'EFICIENCIA > mean(EFICIENCIA)'), 25),
#  (('FRAMEWORK=RAC(PHP)', 'LENGUAJE=PHP', 'EFICIENCIA > mean(EFICIENCIA)'), 25),
#  (('METODOLOGÍA=ÁGIL', 'LENGUAJE=PHP', 'EFICIENCIA < mean(EFICIENCIA)'), 25),
#  (('METODOLOGÍA=ÁGIL', 'BD=POSTGRESQL', 'EFICIENCIA > mean(EFICIENCIA)'), 25),
#  (('ARQUITECTURA=CAPAS', 'METODOLOGÍA=ÁGIL', 'EFICIENCIA < mean(EFICIENCIA)'),
#   23),
#  (('METODOLOGÍA=ÁGIL', 'ARQUITECTURA=CAPAS', 'EFICIENCIA < mean(EFICIENCIA)'),
#   23),
#  (('ARQUITECTURA=CLIENTE/SERVIDOR',
#    'FRAMEWORK=COPPELFRONTWEB',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   22),
#  (('LENGUAJE=C#', 'METODOLOGÍA=ÁGIL', 'EFICIENCIA < mean(EFICIENCIA)'), 22),
#  (('FRAMEWORK=COPPELFRONTWEB',
#    'ARQUITECTURA=CLIENTE/SERVIDOR',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   22),
#  (('METODOLOGÍA=ÁGIL', 'LENGUAJE=C#', 'EFICIENCIA < mean(EFICIENCIA)'), 22),
#  (('CFP > mean(CFP)', 'METODOLOGÍA=ÁGIL', 'EFICIENCIA < mean(EFICIENCIA)'),
#   21),
#  (('METODOLOGÍA=ÁGIL', 'CFP > mean(CFP)', 'EFICIENCIA < mean(EFICIENCIA)'),
#   21),
#  (('CFP > mean(CFP)',
#    'BD=POSTGRESQL/INFORMIX',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   20),
#  (('CFP < mean(CFP)', 'FRAMEWORK=RAC(PHP)', 'EFICIENCIA > mean(EFICIENCIA)'),
#   20),
#  (('ARQUITECTURA=CAPAS', 'LENGUAJE=C++', 'EFICIENCIA < mean(EFICIENCIA)'), 20),
#  (('LENGUAJE=C++', 'ARQUITECTURA=CAPAS', 'EFICIENCIA < mean(EFICIENCIA)'), 20),
#  (('LENGUAJE=C#', 'FRAMEWORK=CSHARP', 'EFICIENCIA < mean(EFICIENCIA)'), 20),
#  (('BD=POSTGRESQL/INFORMIX',
#    'CFP > mean(CFP)',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   20),
#  (('BD=SQLSERVER', 'METODOLOGÍA=ÁGIL', 'EFICIENCIA > mean(EFICIENCIA)'), 20),
#  (('FRAMEWORK=RAC(PHP)', 'CFP < mean(CFP)', 'EFICIENCIA > mean(EFICIENCIA)'),
#   20),
#  (('FRAMEWORK=CSHARP', 'LENGUAJE=C#', 'EFICIENCIA < mean(EFICIENCIA)'), 20),
#  (('METODOLOGÍA=ÁGIL', 'BD=SQLSERVER', 'EFICIENCIA > mean(EFICIENCIA)'), 20),
#  (('CFP > mean(CFP)',
#    'FRAMEWORK=COPPELFRONTWEB',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   19),
#  (('ARQUITECTURA=CAPAS', 'LENGUAJE=C#', 'EFICIENCIA > mean(EFICIENCIA)'), 19),
#  (('ARQUITECTURA=CLIENTE/SERVIDOR',
#    'FRAMEWORK=RAC(PHP)',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   19),
#  (('LENGUAJE=C#', 'ARQUITECTURA=CAPAS', 'EFICIENCIA > mean(EFICIENCIA)'), 19),
#  (('LENGUAJE=C#', 'METODOLOGÍA=ÁGIL', 'EFICIENCIA > mean(EFICIENCIA)'), 19),
#  (('BD=SQLSERVER', 'FRAMEWORK=RAC(PHP)', 'EFICIENCIA > mean(EFICIENCIA)'), 19),
#  (('BD=SQLSERVER', 'FRAMEWORK=RAC(PHP)', 'EFICIENCIA < mean(EFICIENCIA)'), 19),
#  (('FRAMEWORK=COPPELFRONTWEB',
#    'CFP > mean(CFP)',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   19),
#  (('FRAMEWORK=RAC(PHP)',
#    'ARQUITECTURA=CLIENTE/SERVIDOR',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   19),
#  (('FRAMEWORK=RAC(PHP)', 'BD=SQLSERVER', 'EFICIENCIA > mean(EFICIENCIA)'), 19),
#  (('FRAMEWORK=RAC(PHP)', 'BD=SQLSERVER', 'EFICIENCIA < mean(EFICIENCIA)'), 19),
#  (('FRAMEWORK=CSHARP', 'METODOLOGÍA=CASCADA', 'EFICIENCIA < mean(EFICIENCIA)'),
#   19),
#  (('METODOLOGÍA=ÁGIL', 'LENGUAJE=C#', 'EFICIENCIA > mean(EFICIENCIA)'), 19),
#  (('METODOLOGÍA=CASCADA', 'FRAMEWORK=CSHARP', 'EFICIENCIA < mean(EFICIENCIA)'),
#   19),
#  (('CFP > mean(CFP)', 'METODOLOGÍA=ÁGIL', 'EFICIENCIA > mean(EFICIENCIA)'),
#   18),
#  (('ARQUITECTURA=CAPAS', 'METODOLOGÍA=ÁGIL', 'EFICIENCIA > mean(EFICIENCIA)'),
#   18),
#  (('LENGUAJE=C#', 'FRAMEWORK=CSHARP', 'EFICIENCIA > mean(EFICIENCIA)'), 18),
#  (('BD=SQLSERVER',
#    'FRAMEWORK=COPPELFRONTWEB',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   18),
#  (('FRAMEWORK=CSHARP', 'LENGUAJE=C#', 'EFICIENCIA > mean(EFICIENCIA)'), 18),
#  (('FRAMEWORK=COPPELFRONTWEB',
#    'BD=SQLSERVER',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   18),
#  (('METODOLOGÍA=ÁGIL', 'CFP > mean(CFP)', 'EFICIENCIA > mean(EFICIENCIA)'),
#   18),
#  (('METODOLOGÍA=ÁGIL', 'ARQUITECTURA=CAPAS', 'EFICIENCIA > mean(EFICIENCIA)'),
#   18),
#  (('CFP < mean(CFP)',
#    'FRAMEWORK=COPPELFRONTWEB',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   17),
#  (('ARQUITECTURA=CLIENTE/SERVIDOR',
#    'FRAMEWORK=CSHARP',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   17),
#  (('ARQUITECTURA=CAPAS',
#    'FRAMEWORK=RAC(PHP)',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   17),
#  (('LENGUAJE=C++', 'METODOLOGÍA=ÁGIL', 'EFICIENCIA < mean(EFICIENCIA)'), 17),
#  (('FRAMEWORK=COPPELFRONTWEB',
#    'CFP < mean(CFP)',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   17),
#  (('FRAMEWORK=CSHARP',
#    'ARQUITECTURA=CLIENTE/SERVIDOR',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   17),
#  (('FRAMEWORK=RAC(PHP)',
#    'ARQUITECTURA=CAPAS',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   17),
#  (('METODOLOGÍA=ÁGIL', 'LENGUAJE=C++', 'EFICIENCIA < mean(EFICIENCIA)'), 17),
#  (('LENGUAJE=PHP', 'BD=POSTGRESQL/INFORMIX', 'EFICIENCIA > mean(EFICIENCIA)'),
#   16),
#  (('LENGUAJE=C++', 'BD=POSTGRESQL/INFORMIX', 'EFICIENCIA < mean(EFICIENCIA)'),
#   16),
#  (('BD=POSTGRESQL/INFORMIX', 'LENGUAJE=PHP', 'EFICIENCIA > mean(EFICIENCIA)'),
#   16),
#  (('BD=POSTGRESQL/INFORMIX', 'LENGUAJE=C++', 'EFICIENCIA < mean(EFICIENCIA)'),
#   16),
#  (('BD=POSTGRESQL', 'FRAMEWORK=RAC(PHP)', 'EFICIENCIA < mean(EFICIENCIA)'),
#   16),
#  (('FRAMEWORK=RAC(PHP)', 'BD=POSTGRESQL', 'EFICIENCIA < mean(EFICIENCIA)'),
#   16),
#  (('FRAMEWORK=COPPELFRONTWEB',
#    'METODOLOGÍA=CASCADA',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   16),
#  (('FRAMEWORK=CSHARP', 'METODOLOGÍA=CASCADA', 'EFICIENCIA > mean(EFICIENCIA)'),
#   16),
#  (('METODOLOGÍA=CASCADA',
#    'FRAMEWORK=COPPELFRONTWEB',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   16),
#  (('METODOLOGÍA=CASCADA', 'FRAMEWORK=CSHARP', 'EFICIENCIA > mean(EFICIENCIA)'),
#   16),
#  (('ARQUITECTURA=CLIENTE/SERVIDOR',
#    'FRAMEWORK=RAC(PHP)',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   15),
#  (('BD=POSTGRESQL',
#    'FRAMEWORK=COPPELFRONTWEB',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   15),
#  (('FRAMEWORK=RAC(PHP)',
#    'ARQUITECTURA=CLIENTE/SERVIDOR',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   15),
#  (('FRAMEWORK=COPPELFRONTWEB',
#    'BD=POSTGRESQL',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   15),
#  (('CFP < mean(CFP)', 'FRAMEWORK=CSHARP', 'EFICIENCIA < mean(EFICIENCIA)'),
#   14),
#  (('LENGUAJE=PHP',
#    'FRAMEWORK=COPPELFRONTWEB',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   14),
#  (('FRAMEWORK=CSHARP', 'CFP < mean(CFP)', 'EFICIENCIA < mean(EFICIENCIA)'),
#   14),
#  (('FRAMEWORK=COPPELFRONTWEB',
#    'LENGUAJE=PHP',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   14),
#  (('ARQUITECTURA=CLIENTE/SERVIDOR',
#    'FRAMEWORK=COPPELFRONTWEB',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   13),
#  (('ARQUITECTURA=CLIENTE/SERVIDOR',
#    'FRAMEWORK=CSHARP',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   13),
#  (('ARQUITECTURA=CAPAS',
#    'FRAMEWORK=COPPELFRONTWEB',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   13),
#  (('ARQUITECTURA=CAPAS',
#    'FRAMEWORK=RAC(PHP)',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   13),
#  (('LENGUAJE=C++', 'METODOLOGÍA=ÁGIL', 'EFICIENCIA > mean(EFICIENCIA)'), 13),
#  (('BD=SQLSERVER', 'FRAMEWORK=CSHARP', 'EFICIENCIA > mean(EFICIENCIA)'), 13),
#  (('FRAMEWORK=COPPELFRONTWEB',
#    'ARQUITECTURA=CLIENTE/SERVIDOR',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   13),
#  (('FRAMEWORK=COPPELFRONTWEB',
#    'ARQUITECTURA=CAPAS',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   13),
#  (('FRAMEWORK=CSHARP',
#    'ARQUITECTURA=CLIENTE/SERVIDOR',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   13),
#  (('FRAMEWORK=RAC(PHP)',
#    'ARQUITECTURA=CAPAS',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   13),
#  (('FRAMEWORK=CSHARP', 'BD=SQLSERVER', 'EFICIENCIA > mean(EFICIENCIA)'), 13),
#  (('METODOLOGÍA=ÁGIL', 'LENGUAJE=C++', 'EFICIENCIA > mean(EFICIENCIA)'), 13),
#  (('CFP > mean(CFP)',
#    'BD=POSTGRESQL/INFORMIX',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   12),
#  (('BD=POSTGRESQL/INFORMIX',
#    'CFP > mean(CFP)',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   12),
#  (('CFP > mean(CFP)', 'FRAMEWORK=CSHARP', 'EFICIENCIA > mean(EFICIENCIA)'),
#   11),
#  (('FRAMEWORK=CSHARP', 'CFP > mean(CFP)', 'EFICIENCIA > mean(EFICIENCIA)'),
#   11),
#  (('CFP > mean(CFP)',
#    'FRAMEWORK=COPPELFRONTWEB',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   10),
#  (('BD=SQLSERVER', 'FRAMEWORK=CSHARP', 'EFICIENCIA < mean(EFICIENCIA)'), 10),
#  (('FRAMEWORK=COPPELFRONTWEB',
#    'CFP > mean(CFP)',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   10),
#  (('FRAMEWORK=CSHARP', 'BD=SQLSERVER', 'EFICIENCIA < mean(EFICIENCIA)'), 10),
#  (('CFP > mean(CFP)', 'FRAMEWORK=RAC(PHP)', 'EFICIENCIA < mean(EFICIENCIA)'),
#   9),
#  (('CFP < mean(CFP)', 'FRAMEWORK=CSHARP', 'EFICIENCIA > mean(EFICIENCIA)'), 9),
#  (('LENGUAJE=PHP', 'METODOLOGÍA=ÁGIL', 'EFICIENCIA > mean(EFICIENCIA)'), 9),
#  (('BD=POSTGRESQL', 'FRAMEWORK=CSHARP', 'EFICIENCIA < mean(EFICIENCIA)'), 9),
#  (('BD=POSTGRESQL', 'FRAMEWORK=RAC(PHP)', 'EFICIENCIA > mean(EFICIENCIA)'), 9),
#  (('BD=SQLSERVER',
#    'FRAMEWORK=COPPELFRONTWEB',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   9),
#  (('FRAMEWORK=CSHARP', 'CFP < mean(CFP)', 'EFICIENCIA > mean(EFICIENCIA)'), 9),
#  (('FRAMEWORK=RAC(PHP)', 'CFP > mean(CFP)', 'EFICIENCIA < mean(EFICIENCIA)'),
#   9),
#  (('FRAMEWORK=COPPELFRONTWEB',
#    'BD=SQLSERVER',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   9),
#  (('FRAMEWORK=CSHARP', 'BD=POSTGRESQL', 'EFICIENCIA < mean(EFICIENCIA)'), 9),
#  (('FRAMEWORK=RAC(PHP)', 'BD=POSTGRESQL', 'EFICIENCIA > mean(EFICIENCIA)'), 9),
#  (('METODOLOGÍA=ÁGIL', 'LENGUAJE=PHP', 'EFICIENCIA > mean(EFICIENCIA)'), 9),
#  (('CFP > mean(CFP)', 'FRAMEWORK=RAC(PHP)', 'EFICIENCIA > mean(EFICIENCIA)'),
#   8),
#  (('BD=POSTGRESQL',
#    'FRAMEWORK=COPPELFRONTWEB',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   8),
#  (('FRAMEWORK=RAC(PHP)', 'CFP > mean(CFP)', 'EFICIENCIA > mean(EFICIENCIA)'),
#   8),
#  (('FRAMEWORK=COPPELFRONTWEB',
#    'BD=POSTGRESQL',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   8),
#  (('CFP > mean(CFP)', 'BD=DB2', 'EFICIENCIA > mean(EFICIENCIA)'), 7),
#  (('CFP < mean(CFP)',
#    'FRAMEWORK=COPPELFRONTWEB',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   7),
#  (('ARQUITECTURA=CAPAS', 'FRAMEWORK=CSHARP', 'EFICIENCIA < mean(EFICIENCIA)'),
#   7),
#  (('BD=DB2', 'CFP > mean(CFP)', 'EFICIENCIA > mean(EFICIENCIA)'), 7),
#  (('BD=POSTGRESQL', 'FRAMEWORK=CSHARP', 'EFICIENCIA > mean(EFICIENCIA)'), 7),
#  (('BD=DB2', 'FRAMEWORK=OTRO', 'EFICIENCIA > mean(EFICIENCIA)'), 7),
#  (('BD=DB2', 'METODOLOGÍA=CASCADA', 'EFICIENCIA > mean(EFICIENCIA)'), 7),
#  (('FRAMEWORK=COPPELFRONTWEB',
#    'CFP < mean(CFP)',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   7),
#  (('FRAMEWORK=CSHARP', 'ARQUITECTURA=CAPAS', 'EFICIENCIA < mean(EFICIENCIA)'),
#   7),
#  (('FRAMEWORK=CSHARP', 'BD=POSTGRESQL', 'EFICIENCIA > mean(EFICIENCIA)'), 7),
#  (('FRAMEWORK=OTRO', 'BD=DB2', 'EFICIENCIA > mean(EFICIENCIA)'), 7),
#  (('METODOLOGÍA=CASCADA', 'BD=DB2', 'EFICIENCIA > mean(EFICIENCIA)'), 7),
#  (('CFP > mean(CFP)', 'FRAMEWORK=CSHARP', 'EFICIENCIA < mean(EFICIENCIA)'), 6),
#  (('ARQUITECTURA=CAPAS', 'LENGUAJE=C++', 'EFICIENCIA > mean(EFICIENCIA)'), 6),
#  (('ARQUITECTURA=CLIENTE/SERVIDOR', 'BD=DB2', 'EFICIENCIA > mean(EFICIENCIA)'),
#   6),
#  (('ARQUITECTURA=CAPAS',
#    'BD=POSTGRESQL/INFORMIX',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   6),
#  (('LENGUAJE=C++', 'ARQUITECTURA=CAPAS', 'EFICIENCIA > mean(EFICIENCIA)'), 6),
#  (('BD=POSTGRESQL/INFORMIX',
#    'ARQUITECTURA=CAPAS',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   6),
#  (('BD=DB2', 'ARQUITECTURA=CLIENTE/SERVIDOR', 'EFICIENCIA > mean(EFICIENCIA)'),
#   6),
#  (('FRAMEWORK=CSHARP', 'CFP > mean(CFP)', 'EFICIENCIA < mean(EFICIENCIA)'), 6),
#  (('ARQUITECTURA=CAPAS',
#    'BD=POSTGRESQL/INFORMIX',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   5),
#  (('LENGUAJE=C++', 'BD=POSTGRESQL/INFORMIX', 'EFICIENCIA > mean(EFICIENCIA)'),
#   5),
#  (('BD=POSTGRESQL/INFORMIX',
#    'ARQUITECTURA=CAPAS',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   5),
#  (('BD=POSTGRESQL/INFORMIX', 'LENGUAJE=C++', 'EFICIENCIA > mean(EFICIENCIA)'),
#   5),
#  (('CFP < mean(CFP)', 'BD=DB2', 'EFICIENCIA < mean(EFICIENCIA)'), 4),
#  (('ARQUITECTURA=CLIENTE/SERVIDOR', 'BD=DB2', 'EFICIENCIA < mean(EFICIENCIA)'),
#   4),
#  (('ARQUITECTURA=CAPAS',
#    'FRAMEWORK=COPPELFRONTWEB',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   4),
#  (('BD=DB2', 'CFP < mean(CFP)', 'EFICIENCIA < mean(EFICIENCIA)'), 4),
#  (('BD=DB2', 'ARQUITECTURA=CLIENTE/SERVIDOR', 'EFICIENCIA < mean(EFICIENCIA)'),
#   4),
#  (('FRAMEWORK=COPPELFRONTWEB',
#    'ARQUITECTURA=CAPAS',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   4),
#  (('FRAMEWORK=CSHARP', 'METODOLOGÍA=ÁGIL', 'EFICIENCIA > mean(EFICIENCIA)'),
#   4),
#  (('METODOLOGÍA=ÁGIL', 'FRAMEWORK=CSHARP', 'EFICIENCIA > mean(EFICIENCIA)'),
#   4),
#  (('CFP < mean(CFP)', 'ARQUITECTURA=OTRO', 'EFICIENCIA > mean(EFICIENCIA)'),
#   3),
#  (('ARQUITECTURA=OTRO', 'CFP < mean(CFP)', 'EFICIENCIA > mean(EFICIENCIA)'),
#   3),
#  (('ARQUITECTURA=CAPAS', 'BD=DB2', 'EFICIENCIA > mean(EFICIENCIA)'), 3),
#  (('ARQUITECTURA=CAPAS', 'FRAMEWORK=CSHARP', 'EFICIENCIA > mean(EFICIENCIA)'),
#   3),
#  (('ARQUITECTURA=OTRO', 'FRAMEWORK=OTRO', 'EFICIENCIA > mean(EFICIENCIA)'), 3),
#  (('ARQUITECTURA=OTRO', 'FRAMEWORK=OTRO', 'EFICIENCIA < mean(EFICIENCIA)'), 3),
#  (('ARQUITECTURA=OTRO',
#    'METODOLOGÍA=CASCADA',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   3),
#  (('BD=DB2', 'ARQUITECTURA=CAPAS', 'EFICIENCIA > mean(EFICIENCIA)'), 3),
#  (('BD=POSTGRESQL/INFORMIX',
#    'FRAMEWORK=COPPELFRONTWEB',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   3),
#  (('BD=DB2', 'FRAMEWORK=OTRO', 'EFICIENCIA < mean(EFICIENCIA)'), 3),
#  (('BD=POSTGRESQL/INFORMIX',
#    'METODOLOGÍA=ÁGIL',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   3),
#  (('BD=DB2', 'METODOLOGÍA=CASCADA', 'EFICIENCIA < mean(EFICIENCIA)'), 3),
#  (('FRAMEWORK=CSHARP', 'ARQUITECTURA=CAPAS', 'EFICIENCIA > mean(EFICIENCIA)'),
#   3),
#  (('FRAMEWORK=OTRO', 'ARQUITECTURA=OTRO', 'EFICIENCIA > mean(EFICIENCIA)'), 3),
#  (('FRAMEWORK=OTRO', 'ARQUITECTURA=OTRO', 'EFICIENCIA < mean(EFICIENCIA)'), 3),
#  (('FRAMEWORK=COPPELFRONTWEB',
#    'BD=POSTGRESQL/INFORMIX',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   3),
#  (('FRAMEWORK=OTRO', 'BD=DB2', 'EFICIENCIA < mean(EFICIENCIA)'), 3),
#  (('FRAMEWORK=RAC(PHP)', 'METODOLOGÍA=ÁGIL', 'EFICIENCIA < mean(EFICIENCIA)'),
#   3),
#  (('METODOLOGÍA=CASCADA',
#    'ARQUITECTURA=OTRO',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   3),
#  (('METODOLOGÍA=CASCADA', 'BD=DB2', 'EFICIENCIA < mean(EFICIENCIA)'), 3),
#  (('METODOLOGÍA=ÁGIL',
#    'BD=POSTGRESQL/INFORMIX',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   3),
#  (('METODOLOGÍA=ÁGIL', 'FRAMEWORK=RAC(PHP)', 'EFICIENCIA < mean(EFICIENCIA)'),
#   3),
#  (('CFP > mean(CFP)', 'ARQUITECTURA=OTRO', 'EFICIENCIA < mean(EFICIENCIA)'),
#   2),
#  (('CFP < mean(CFP)', 'BD=DB2', 'EFICIENCIA > mean(EFICIENCIA)'), 2),
#  (('ARQUITECTURA=OTRO', 'CFP > mean(CFP)', 'EFICIENCIA < mean(EFICIENCIA)'),
#   2),
#  (('ARQUITECTURA=CLIENTE/SERVIDOR',
#    'BD=MYSQL',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   2),
#  (('ARQUITECTURA=OTRO',
#    'METODOLOGÍA=CASCADA',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   2),
#  (('LENGUAJE=PHP', 'BD=MYSQL', 'EFICIENCIA < mean(EFICIENCIA)'), 2),
#  (('LENGUAJE=C++', 'FRAMEWORK=CSHARP', 'EFICIENCIA > mean(EFICIENCIA)'), 2),
#  (('LENGUAJE=C++', 'FRAMEWORK=RAC(PHP)', 'EFICIENCIA < mean(EFICIENCIA)'), 2),
#  (('LENGUAJE=C#', 'FRAMEWORK=COPPELFRONTWEB', 'EFICIENCIA < mean(EFICIENCIA)'),
#   2),
#  (('LENGUAJE=C#', 'FRAMEWORK=RAC(PHP)', 'EFICIENCIA > mean(EFICIENCIA)'), 2),
#  (('LENGUAJE=C#', 'FRAMEWORK=RAC(PHP)', 'EFICIENCIA < mean(EFICIENCIA)'), 2),
#  (('BD=DB2', 'CFP < mean(CFP)', 'EFICIENCIA > mean(EFICIENCIA)'), 2),
#  (('BD=MYSQL',
#    'ARQUITECTURA=CLIENTE/SERVIDOR',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   2),
#  (('BD=MYSQL', 'LENGUAJE=PHP', 'EFICIENCIA < mean(EFICIENCIA)'), 2),
#  (('BD=MYSQL', 'FRAMEWORK=OTRO', 'EFICIENCIA < mean(EFICIENCIA)'), 2),
#  (('BD=MYSQL', 'METODOLOGÍA=CASCADA', 'EFICIENCIA < mean(EFICIENCIA)'), 2),
#  (('BD=DB2', 'METODOLOGÍA=ÁGIL', 'EFICIENCIA > mean(EFICIENCIA)'), 2),
#  (('FRAMEWORK=COPPELFRONTWEB', 'LENGUAJE=C#', 'EFICIENCIA < mean(EFICIENCIA)'),
#   2),
#  (('FRAMEWORK=CSHARP', 'LENGUAJE=C++', 'EFICIENCIA > mean(EFICIENCIA)'), 2),
#  (('FRAMEWORK=RAC(PHP)', 'LENGUAJE=C++', 'EFICIENCIA < mean(EFICIENCIA)'), 2),
#  (('FRAMEWORK=RAC(PHP)', 'LENGUAJE=C#', 'EFICIENCIA > mean(EFICIENCIA)'), 2),
#  (('FRAMEWORK=RAC(PHP)', 'LENGUAJE=C#', 'EFICIENCIA < mean(EFICIENCIA)'), 2),
#  (('FRAMEWORK=OTRO', 'BD=MYSQL', 'EFICIENCIA < mean(EFICIENCIA)'), 2),
#  (('METODOLOGÍA=CASCADA',
#    'ARQUITECTURA=OTRO',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   2),
#  (('METODOLOGÍA=CASCADA', 'BD=MYSQL', 'EFICIENCIA < mean(EFICIENCIA)'), 2),
#  (('METODOLOGÍA=ÁGIL', 'BD=DB2', 'EFICIENCIA > mean(EFICIENCIA)'), 2),
#  (('CFP > mean(CFP)', 'ARQUITECTURA=MVC', 'EFICIENCIA < mean(EFICIENCIA)'), 1),
#  (('CFP < mean(CFP)', 'ARQUITECTURA=OTRO', 'EFICIENCIA < mean(EFICIENCIA)'),
#   1),
#  (('CFP > mean(CFP)', 'BD=MYSQL', 'EFICIENCIA < mean(EFICIENCIA)'), 1),
#  (('CFP < mean(CFP)', 'BD=MYSQL', 'EFICIENCIA > mean(EFICIENCIA)'), 1),
#  (('CFP < mean(CFP)', 'BD=MYSQL', 'EFICIENCIA < mean(EFICIENCIA)'), 1),
#  (('CFP > mean(CFP)', 'FRAMEWORK=VUEJS', 'EFICIENCIA > mean(EFICIENCIA)'), 1),
#  (('ARQUITECTURA=MVC', 'CFP > mean(CFP)', 'EFICIENCIA < mean(EFICIENCIA)'), 1),
#  (('ARQUITECTURA=OTRO', 'CFP < mean(CFP)', 'EFICIENCIA < mean(EFICIENCIA)'),
#   1),
#  (('ARQUITECTURA=MVC', 'LENGUAJE=PHP', 'EFICIENCIA < mean(EFICIENCIA)'), 1),
#  (('ARQUITECTURA=CLIENTE/SERVIDOR',
#    'BD=MYSQL',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   1),
#  (('ARQUITECTURA=MVC', 'BD=SQLSERVER', 'EFICIENCIA < mean(EFICIENCIA)'), 1),
#  (('ARQUITECTURA=CAPAS', 'FRAMEWORK=VUEJS', 'EFICIENCIA > mean(EFICIENCIA)'),
#   1),
#  (('ARQUITECTURA=MVC',
#    'FRAMEWORK=COPPELFRONTWEB',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   1),
#  (('ARQUITECTURA=MVC', 'METODOLOGÍA=CASCADA', 'EFICIENCIA < mean(EFICIENCIA)'),
#   1),
#  (('ARQUITECTURA=OTRO', 'METODOLOGÍA=ÁGIL', 'EFICIENCIA < mean(EFICIENCIA)'),
#   1),
#  (('LENGUAJE=PHP', 'ARQUITECTURA=MVC', 'EFICIENCIA < mean(EFICIENCIA)'), 1),
#  (('LENGUAJE=PHP', 'BD=MYSQL', 'EFICIENCIA > mean(EFICIENCIA)'), 1),
#  (('LENGUAJE=C#', 'BD=POSTGRESQL/INFORMIX', 'EFICIENCIA < mean(EFICIENCIA)'),
#   1),
#  (('LENGUAJE=C++',
#    'FRAMEWORK=COPPELFRONTWEB',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   1),
#  (('LENGUAJE=C++',
#    'FRAMEWORK=COPPELFRONTWEB',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   1),
#  (('LENGUAJE=C#', 'FRAMEWORK=COPPELFRONTWEB', 'EFICIENCIA > mean(EFICIENCIA)'),
#   1),
#  (('BD=MYSQL', 'CFP > mean(CFP)', 'EFICIENCIA < mean(EFICIENCIA)'), 1),
#  (('BD=MYSQL', 'CFP < mean(CFP)', 'EFICIENCIA > mean(EFICIENCIA)'), 1),
#  (('BD=MYSQL', 'CFP < mean(CFP)', 'EFICIENCIA < mean(EFICIENCIA)'), 1),
#  (('BD=SQLSERVER', 'ARQUITECTURA=MVC', 'EFICIENCIA < mean(EFICIENCIA)'), 1),
#  (('BD=MYSQL',
#    'ARQUITECTURA=CLIENTE/SERVIDOR',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   1),
#  (('BD=POSTGRESQL/INFORMIX', 'LENGUAJE=C#', 'EFICIENCIA < mean(EFICIENCIA)'),
#   1),
#  (('BD=MYSQL', 'LENGUAJE=PHP', 'EFICIENCIA > mean(EFICIENCIA)'), 1),
#  (('BD=POSTGRESQL', 'FRAMEWORK=VUEJS', 'EFICIENCIA > mean(EFICIENCIA)'), 1),
#  (('BD=MYSQL', 'FRAMEWORK=OTRO', 'EFICIENCIA > mean(EFICIENCIA)'), 1),
#  (('BD=POSTGRESQL/INFORMIX',
#    'METODOLOGÍA=ÁGIL',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   1),
#  (('BD=MYSQL', 'METODOLOGÍA=CASCADA', 'EFICIENCIA > mean(EFICIENCIA)'), 1),
#  (('BD=DB2', 'METODOLOGÍA=ÁGIL', 'EFICIENCIA < mean(EFICIENCIA)'), 1),
#  (('FRAMEWORK=VUEJS', 'CFP > mean(CFP)', 'EFICIENCIA > mean(EFICIENCIA)'), 1),
#  (('FRAMEWORK=COPPELFRONTWEB',
#    'ARQUITECTURA=MVC',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   1),
#  (('FRAMEWORK=VUEJS', 'ARQUITECTURA=CAPAS', 'EFICIENCIA > mean(EFICIENCIA)'),
#   1),
#  (('FRAMEWORK=COPPELFRONTWEB',
#    'LENGUAJE=C++',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   1),
#  (('FRAMEWORK=COPPELFRONTWEB',
#    'LENGUAJE=C++',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   1),
#  (('FRAMEWORK=COPPELFRONTWEB', 'LENGUAJE=C#', 'EFICIENCIA > mean(EFICIENCIA)'),
#   1),
#  (('FRAMEWORK=VUEJS', 'BD=POSTGRESQL', 'EFICIENCIA > mean(EFICIENCIA)'), 1),
#  (('FRAMEWORK=OTRO', 'BD=MYSQL', 'EFICIENCIA > mean(EFICIENCIA)'), 1),
#  (('FRAMEWORK=COPPELFRONTWEB',
#    'METODOLOGÍA=ÁGIL',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   1),
#  (('FRAMEWORK=COPPELFRONTWEB',
#    'METODOLOGÍA=ÁGIL',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   1),
#  (('FRAMEWORK=CSHARP', 'METODOLOGÍA=ÁGIL', 'EFICIENCIA < mean(EFICIENCIA)'),
#   1),
#  (('FRAMEWORK=VUEJS', 'METODOLOGÍA=CASCADA', 'EFICIENCIA > mean(EFICIENCIA)'),
#   1),
#  (('METODOLOGÍA=CASCADA', 'ARQUITECTURA=MVC', 'EFICIENCIA < mean(EFICIENCIA)'),
#   1),
#  (('METODOLOGÍA=ÁGIL', 'ARQUITECTURA=OTRO', 'EFICIENCIA < mean(EFICIENCIA)'),
#   1),
#  (('METODOLOGÍA=CASCADA', 'BD=MYSQL', 'EFICIENCIA > mean(EFICIENCIA)'), 1),
#  (('METODOLOGÍA=ÁGIL',
#    'BD=POSTGRESQL/INFORMIX',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   1),
#  (('METODOLOGÍA=ÁGIL', 'BD=DB2', 'EFICIENCIA < mean(EFICIENCIA)'), 1),
#  (('METODOLOGÍA=CASCADA', 'FRAMEWORK=VUEJS', 'EFICIENCIA > mean(EFICIENCIA)'),
#   1),
#  (('METODOLOGÍA=ÁGIL',
#    'FRAMEWORK=COPPELFRONTWEB',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   1),
#  (('METODOLOGÍA=ÁGIL',
#    'FRAMEWORK=COPPELFRONTWEB',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   1),
#  (('METODOLOGÍA=ÁGIL', 'FRAMEWORK=CSHARP', 'EFICIENCIA < mean(EFICIENCIA)'),
#   1),
#  (('CFP > mean(CFP)', 'ARQUITECTURA=MVC', 'EFICIENCIA > mean(EFICIENCIA)'), 0),
#  (('CFP > mean(CFP)', 'ARQUITECTURA=OTRO', 'EFICIENCIA > mean(EFICIENCIA)'),
#   0),
#  (('CFP < mean(CFP)', 'ARQUITECTURA=MVC', 'EFICIENCIA > mean(EFICIENCIA)'), 0),
#  (('CFP < mean(CFP)', 'ARQUITECTURA=MVC', 'EFICIENCIA < mean(EFICIENCIA)'), 0),
#  (('CFP > mean(CFP)', 'BD=MYSQL', 'EFICIENCIA > mean(EFICIENCIA)'), 0),
#  (('CFP > mean(CFP)', 'BD=DB2', 'EFICIENCIA < mean(EFICIENCIA)'), 0),
#  (('CFP > mean(CFP)', 'FRAMEWORK=VUEJS', 'EFICIENCIA < mean(EFICIENCIA)'), 0),
#  (('CFP < mean(CFP)', 'FRAMEWORK=VUEJS', 'EFICIENCIA > mean(EFICIENCIA)'), 0),
#  (('CFP < mean(CFP)', 'FRAMEWORK=VUEJS', 'EFICIENCIA < mean(EFICIENCIA)'), 0),
#  (('ARQUITECTURA=MVC', 'CFP > mean(CFP)', 'EFICIENCIA > mean(EFICIENCIA)'), 0),
#  (('ARQUITECTURA=MVC', 'CFP < mean(CFP)', 'EFICIENCIA > mean(EFICIENCIA)'), 0),
#  (('ARQUITECTURA=MVC', 'CFP < mean(CFP)', 'EFICIENCIA < mean(EFICIENCIA)'), 0),
#  (('ARQUITECTURA=OTRO', 'CFP > mean(CFP)', 'EFICIENCIA > mean(EFICIENCIA)'),
#   0),
#  (('ARQUITECTURA=MVC', 'LENGUAJE=PHP', 'EFICIENCIA > mean(EFICIENCIA)'), 0),
#  (('ARQUITECTURA=MVC', 'LENGUAJE=C++', 'EFICIENCIA > mean(EFICIENCIA)'), 0),
#  (('ARQUITECTURA=MVC', 'LENGUAJE=C++', 'EFICIENCIA < mean(EFICIENCIA)'), 0),
#  (('ARQUITECTURA=MVC', 'LENGUAJE=C#', 'EFICIENCIA > mean(EFICIENCIA)'), 0),
#  (('ARQUITECTURA=MVC', 'LENGUAJE=C#', 'EFICIENCIA < mean(EFICIENCIA)'), 0),
#  (('ARQUITECTURA=OTRO', 'LENGUAJE=PHP', 'EFICIENCIA > mean(EFICIENCIA)'), 0),
#  (('ARQUITECTURA=OTRO', 'LENGUAJE=PHP', 'EFICIENCIA < mean(EFICIENCIA)'), 0),
#  (('ARQUITECTURA=OTRO', 'LENGUAJE=C++', 'EFICIENCIA > mean(EFICIENCIA)'), 0),
#  (('ARQUITECTURA=OTRO', 'LENGUAJE=C++', 'EFICIENCIA < mean(EFICIENCIA)'), 0),
#  (('ARQUITECTURA=OTRO', 'LENGUAJE=C#', 'EFICIENCIA > mean(EFICIENCIA)'), 0),
#  (('ARQUITECTURA=OTRO', 'LENGUAJE=C#', 'EFICIENCIA < mean(EFICIENCIA)'), 0),
#  (('ARQUITECTURA=CAPAS', 'BD=MYSQL', 'EFICIENCIA > mean(EFICIENCIA)'), 0),
#  (('ARQUITECTURA=CAPAS', 'BD=MYSQL', 'EFICIENCIA < mean(EFICIENCIA)'), 0),
#  (('ARQUITECTURA=CAPAS', 'BD=DB2', 'EFICIENCIA < mean(EFICIENCIA)'), 0),
#  (('ARQUITECTURA=MVC', 'BD=POSTGRESQL', 'EFICIENCIA > mean(EFICIENCIA)'), 0),
#  (('ARQUITECTURA=MVC', 'BD=POSTGRESQL', 'EFICIENCIA < mean(EFICIENCIA)'), 0),
#  (('ARQUITECTURA=MVC', 'BD=SQLSERVER', 'EFICIENCIA > mean(EFICIENCIA)'), 0),
#  (('ARQUITECTURA=MVC',
#    'BD=POSTGRESQL/INFORMIX',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   0),
#  (('ARQUITECTURA=MVC',
#    'BD=POSTGRESQL/INFORMIX',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   0),
#  (('ARQUITECTURA=MVC', 'BD=MYSQL', 'EFICIENCIA > mean(EFICIENCIA)'), 0),
#  (('ARQUITECTURA=MVC', 'BD=MYSQL', 'EFICIENCIA < mean(EFICIENCIA)'), 0),
#  (('ARQUITECTURA=MVC', 'BD=DB2', 'EFICIENCIA > mean(EFICIENCIA)'), 0),
#  (('ARQUITECTURA=MVC', 'BD=DB2', 'EFICIENCIA < mean(EFICIENCIA)'), 0),
#  (('ARQUITECTURA=OTRO', 'BD=POSTGRESQL', 'EFICIENCIA > mean(EFICIENCIA)'), 0),
#  (('ARQUITECTURA=OTRO', 'BD=POSTGRESQL', 'EFICIENCIA < mean(EFICIENCIA)'), 0),
#  (('ARQUITECTURA=OTRO', 'BD=SQLSERVER', 'EFICIENCIA > mean(EFICIENCIA)'), 0),
#  (('ARQUITECTURA=OTRO', 'BD=SQLSERVER', 'EFICIENCIA < mean(EFICIENCIA)'), 0),
#  (('ARQUITECTURA=OTRO',
#    'BD=POSTGRESQL/INFORMIX',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   0),
#  (('ARQUITECTURA=OTRO',
#    'BD=POSTGRESQL/INFORMIX',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   0),
#  (('ARQUITECTURA=OTRO', 'BD=MYSQL', 'EFICIENCIA > mean(EFICIENCIA)'), 0),
#  (('ARQUITECTURA=OTRO', 'BD=MYSQL', 'EFICIENCIA < mean(EFICIENCIA)'), 0),
#  (('ARQUITECTURA=OTRO', 'BD=DB2', 'EFICIENCIA > mean(EFICIENCIA)'), 0),
#  (('ARQUITECTURA=OTRO', 'BD=DB2', 'EFICIENCIA < mean(EFICIENCIA)'), 0),
#  (('ARQUITECTURA=CLIENTE/SERVIDOR',
#    'FRAMEWORK=VUEJS',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   0),
#  (('ARQUITECTURA=CLIENTE/SERVIDOR',
#    'FRAMEWORK=VUEJS',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   0),
#  (('ARQUITECTURA=CAPAS', 'FRAMEWORK=VUEJS', 'EFICIENCIA < mean(EFICIENCIA)'),
#   0),
#  (('ARQUITECTURA=MVC',
#    'FRAMEWORK=COPPELFRONTWEB',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   0),
#  (('ARQUITECTURA=MVC', 'FRAMEWORK=CSHARP', 'EFICIENCIA > mean(EFICIENCIA)'),
#   0),
#  (('ARQUITECTURA=MVC', 'FRAMEWORK=CSHARP', 'EFICIENCIA < mean(EFICIENCIA)'),
#   0),
#  (('ARQUITECTURA=MVC', 'FRAMEWORK=RAC(PHP)', 'EFICIENCIA > mean(EFICIENCIA)'),
#   0),
#  (('ARQUITECTURA=MVC', 'FRAMEWORK=RAC(PHP)', 'EFICIENCIA < mean(EFICIENCIA)'),
#   0),
#  (('ARQUITECTURA=MVC', 'FRAMEWORK=VUEJS', 'EFICIENCIA > mean(EFICIENCIA)'), 0),
#  (('ARQUITECTURA=MVC', 'FRAMEWORK=VUEJS', 'EFICIENCIA < mean(EFICIENCIA)'), 0),
#  (('ARQUITECTURA=MVC', 'FRAMEWORK=OTRO', 'EFICIENCIA > mean(EFICIENCIA)'), 0),
#  (('ARQUITECTURA=MVC', 'FRAMEWORK=OTRO', 'EFICIENCIA < mean(EFICIENCIA)'), 0),
#  (('ARQUITECTURA=OTRO',
#    'FRAMEWORK=COPPELFRONTWEB',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   0),
#  (('ARQUITECTURA=OTRO',
#    'FRAMEWORK=COPPELFRONTWEB',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   0),
#  (('ARQUITECTURA=OTRO', 'FRAMEWORK=CSHARP', 'EFICIENCIA > mean(EFICIENCIA)'),
#   0),
#  (('ARQUITECTURA=OTRO', 'FRAMEWORK=CSHARP', 'EFICIENCIA < mean(EFICIENCIA)'),
#   0),
#  (('ARQUITECTURA=OTRO', 'FRAMEWORK=RAC(PHP)', 'EFICIENCIA > mean(EFICIENCIA)'),
#   0),
#  (('ARQUITECTURA=OTRO', 'FRAMEWORK=RAC(PHP)', 'EFICIENCIA < mean(EFICIENCIA)'),
#   0),
#  (('ARQUITECTURA=OTRO', 'FRAMEWORK=VUEJS', 'EFICIENCIA > mean(EFICIENCIA)'),
#   0),
#  (('ARQUITECTURA=OTRO', 'FRAMEWORK=VUEJS', 'EFICIENCIA < mean(EFICIENCIA)'),
#   0),
#  (('ARQUITECTURA=MVC', 'METODOLOGÍA=CASCADA', 'EFICIENCIA > mean(EFICIENCIA)'),
#   0),
#  (('ARQUITECTURA=MVC', 'METODOLOGÍA=ÁGIL', 'EFICIENCIA > mean(EFICIENCIA)'),
#   0),
#  (('ARQUITECTURA=MVC', 'METODOLOGÍA=ÁGIL', 'EFICIENCIA < mean(EFICIENCIA)'),
#   0),
#  (('ARQUITECTURA=OTRO', 'METODOLOGÍA=ÁGIL', 'EFICIENCIA > mean(EFICIENCIA)'),
#   0),
#  (('LENGUAJE=PHP', 'ARQUITECTURA=MVC', 'EFICIENCIA > mean(EFICIENCIA)'), 0),
#  (('LENGUAJE=PHP', 'ARQUITECTURA=OTRO', 'EFICIENCIA > mean(EFICIENCIA)'), 0),
#  (('LENGUAJE=PHP', 'ARQUITECTURA=OTRO', 'EFICIENCIA < mean(EFICIENCIA)'), 0),
#  (('LENGUAJE=C++', 'ARQUITECTURA=MVC', 'EFICIENCIA > mean(EFICIENCIA)'), 0),
#  (('LENGUAJE=C++', 'ARQUITECTURA=MVC', 'EFICIENCIA < mean(EFICIENCIA)'), 0),
#  (('LENGUAJE=C++', 'ARQUITECTURA=OTRO', 'EFICIENCIA > mean(EFICIENCIA)'), 0),
#  (('LENGUAJE=C++', 'ARQUITECTURA=OTRO', 'EFICIENCIA < mean(EFICIENCIA)'), 0),
#  (('LENGUAJE=C#', 'ARQUITECTURA=MVC', 'EFICIENCIA > mean(EFICIENCIA)'), 0),
#  (('LENGUAJE=C#', 'ARQUITECTURA=MVC', 'EFICIENCIA < mean(EFICIENCIA)'), 0),
#  (('LENGUAJE=C#', 'ARQUITECTURA=OTRO', 'EFICIENCIA > mean(EFICIENCIA)'), 0),
#  (('LENGUAJE=C#', 'ARQUITECTURA=OTRO', 'EFICIENCIA < mean(EFICIENCIA)'), 0),
#  (('LENGUAJE=PHP', 'BD=DB2', 'EFICIENCIA > mean(EFICIENCIA)'), 0),
#  (('LENGUAJE=PHP', 'BD=DB2', 'EFICIENCIA < mean(EFICIENCIA)'), 0),
#  (('LENGUAJE=C++', 'BD=MYSQL', 'EFICIENCIA > mean(EFICIENCIA)'), 0),
#  (('LENGUAJE=C++', 'BD=MYSQL', 'EFICIENCIA < mean(EFICIENCIA)'), 0),
#  (('LENGUAJE=C++', 'BD=DB2', 'EFICIENCIA > mean(EFICIENCIA)'), 0),
#  (('LENGUAJE=C++', 'BD=DB2', 'EFICIENCIA < mean(EFICIENCIA)'), 0),
#  (('LENGUAJE=C#', 'BD=POSTGRESQL/INFORMIX', 'EFICIENCIA > mean(EFICIENCIA)'),
#   0),
#  (('LENGUAJE=C#', 'BD=MYSQL', 'EFICIENCIA > mean(EFICIENCIA)'), 0),
#  (('LENGUAJE=C#', 'BD=MYSQL', 'EFICIENCIA < mean(EFICIENCIA)'), 0),
#  (('LENGUAJE=C#', 'BD=DB2', 'EFICIENCIA > mean(EFICIENCIA)'), 0),
#  (('LENGUAJE=C#', 'BD=DB2', 'EFICIENCIA < mean(EFICIENCIA)'), 0),
#  (('LENGUAJE=PHP', 'FRAMEWORK=CSHARP', 'EFICIENCIA > mean(EFICIENCIA)'), 0),
#  (('LENGUAJE=PHP', 'FRAMEWORK=CSHARP', 'EFICIENCIA < mean(EFICIENCIA)'), 0),
#  (('LENGUAJE=PHP', 'FRAMEWORK=VUEJS', 'EFICIENCIA > mean(EFICIENCIA)'), 0),
#  (('LENGUAJE=PHP', 'FRAMEWORK=VUEJS', 'EFICIENCIA < mean(EFICIENCIA)'), 0),
#  (('LENGUAJE=C++', 'FRAMEWORK=CSHARP', 'EFICIENCIA < mean(EFICIENCIA)'), 0),
#  (('LENGUAJE=C++', 'FRAMEWORK=RAC(PHP)', 'EFICIENCIA > mean(EFICIENCIA)'), 0),
#  (('LENGUAJE=C++', 'FRAMEWORK=VUEJS', 'EFICIENCIA > mean(EFICIENCIA)'), 0),
#  (('LENGUAJE=C++', 'FRAMEWORK=VUEJS', 'EFICIENCIA < mean(EFICIENCIA)'), 0),
#  (('LENGUAJE=C#', 'FRAMEWORK=VUEJS', 'EFICIENCIA > mean(EFICIENCIA)'), 0),
#  (('LENGUAJE=C#', 'FRAMEWORK=VUEJS', 'EFICIENCIA < mean(EFICIENCIA)'), 0),
#  (('BD=MYSQL', 'CFP > mean(CFP)', 'EFICIENCIA > mean(EFICIENCIA)'), 0),
#  (('BD=DB2', 'CFP > mean(CFP)', 'EFICIENCIA < mean(EFICIENCIA)'), 0),
#  (('BD=POSTGRESQL', 'ARQUITECTURA=MVC', 'EFICIENCIA > mean(EFICIENCIA)'), 0),
#  (('BD=POSTGRESQL', 'ARQUITECTURA=MVC', 'EFICIENCIA < mean(EFICIENCIA)'), 0),
#  (('BD=POSTGRESQL', 'ARQUITECTURA=OTRO', 'EFICIENCIA > mean(EFICIENCIA)'), 0),
#  (('BD=POSTGRESQL', 'ARQUITECTURA=OTRO', 'EFICIENCIA < mean(EFICIENCIA)'), 0),
#  (('BD=SQLSERVER', 'ARQUITECTURA=MVC', 'EFICIENCIA > mean(EFICIENCIA)'), 0),
#  (('BD=SQLSERVER', 'ARQUITECTURA=OTRO', 'EFICIENCIA > mean(EFICIENCIA)'), 0),
#  (('BD=SQLSERVER', 'ARQUITECTURA=OTRO', 'EFICIENCIA < mean(EFICIENCIA)'), 0),
#  (('BD=POSTGRESQL/INFORMIX',
#    'ARQUITECTURA=MVC',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   0),
#  (('BD=POSTGRESQL/INFORMIX',
#    'ARQUITECTURA=MVC',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   0),
#  (('BD=POSTGRESQL/INFORMIX',
#    'ARQUITECTURA=OTRO',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   0),
#  (('BD=POSTGRESQL/INFORMIX',
#    'ARQUITECTURA=OTRO',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   0),
#  (('BD=MYSQL', 'ARQUITECTURA=CAPAS', 'EFICIENCIA > mean(EFICIENCIA)'), 0),
#  (('BD=MYSQL', 'ARQUITECTURA=CAPAS', 'EFICIENCIA < mean(EFICIENCIA)'), 0),
#  (('BD=MYSQL', 'ARQUITECTURA=MVC', 'EFICIENCIA > mean(EFICIENCIA)'), 0),
#  (('BD=MYSQL', 'ARQUITECTURA=MVC', 'EFICIENCIA < mean(EFICIENCIA)'), 0),
#  (('BD=MYSQL', 'ARQUITECTURA=OTRO', 'EFICIENCIA > mean(EFICIENCIA)'), 0),
#  (('BD=MYSQL', 'ARQUITECTURA=OTRO', 'EFICIENCIA < mean(EFICIENCIA)'), 0),
#  (('BD=DB2', 'ARQUITECTURA=CAPAS', 'EFICIENCIA < mean(EFICIENCIA)'), 0),
#  (('BD=DB2', 'ARQUITECTURA=MVC', 'EFICIENCIA > mean(EFICIENCIA)'), 0),
#  (('BD=DB2', 'ARQUITECTURA=MVC', 'EFICIENCIA < mean(EFICIENCIA)'), 0),
#  (('BD=DB2', 'ARQUITECTURA=OTRO', 'EFICIENCIA > mean(EFICIENCIA)'), 0),
#  (('BD=DB2', 'ARQUITECTURA=OTRO', 'EFICIENCIA < mean(EFICIENCIA)'), 0),
#  (('BD=POSTGRESQL/INFORMIX', 'LENGUAJE=C#', 'EFICIENCIA > mean(EFICIENCIA)'),
#   0),
#  (('BD=MYSQL', 'LENGUAJE=C++', 'EFICIENCIA > mean(EFICIENCIA)'), 0),
#  (('BD=MYSQL', 'LENGUAJE=C++', 'EFICIENCIA < mean(EFICIENCIA)'), 0),
#  (('BD=MYSQL', 'LENGUAJE=C#', 'EFICIENCIA > mean(EFICIENCIA)'), 0),
#  (('BD=MYSQL', 'LENGUAJE=C#', 'EFICIENCIA < mean(EFICIENCIA)'), 0),
#  (('BD=DB2', 'LENGUAJE=PHP', 'EFICIENCIA > mean(EFICIENCIA)'), 0),
#  (('BD=DB2', 'LENGUAJE=PHP', 'EFICIENCIA < mean(EFICIENCIA)'), 0),
#  (('BD=DB2', 'LENGUAJE=C++', 'EFICIENCIA > mean(EFICIENCIA)'), 0),
#  (('BD=DB2', 'LENGUAJE=C++', 'EFICIENCIA < mean(EFICIENCIA)'), 0),
#  (('BD=DB2', 'LENGUAJE=C#', 'EFICIENCIA > mean(EFICIENCIA)'), 0),
#  (('BD=DB2', 'LENGUAJE=C#', 'EFICIENCIA < mean(EFICIENCIA)'), 0),
#  (('BD=POSTGRESQL', 'FRAMEWORK=VUEJS', 'EFICIENCIA < mean(EFICIENCIA)'), 0),
#  (('BD=SQLSERVER', 'FRAMEWORK=VUEJS', 'EFICIENCIA > mean(EFICIENCIA)'), 0),
#  (('BD=SQLSERVER', 'FRAMEWORK=VUEJS', 'EFICIENCIA < mean(EFICIENCIA)'), 0),
#  (('BD=POSTGRESQL/INFORMIX',
#    'FRAMEWORK=COPPELFRONTWEB',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   0),
#  (('BD=POSTGRESQL/INFORMIX',
#    'FRAMEWORK=CSHARP',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   0),
#  (('BD=POSTGRESQL/INFORMIX',
#    'FRAMEWORK=CSHARP',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   0),
#  (('BD=POSTGRESQL/INFORMIX',
#    'FRAMEWORK=RAC(PHP)',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   0),
#  (('BD=POSTGRESQL/INFORMIX',
#    'FRAMEWORK=RAC(PHP)',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   0),
#  (('BD=POSTGRESQL/INFORMIX',
#    'FRAMEWORK=VUEJS',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   0),
#  (('BD=POSTGRESQL/INFORMIX',
#    'FRAMEWORK=VUEJS',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   0),
#  (('BD=MYSQL', 'FRAMEWORK=COPPELFRONTWEB', 'EFICIENCIA > mean(EFICIENCIA)'),
#   0),
#  (('BD=MYSQL', 'FRAMEWORK=COPPELFRONTWEB', 'EFICIENCIA < mean(EFICIENCIA)'),
#   0),
#  (('BD=MYSQL', 'FRAMEWORK=CSHARP', 'EFICIENCIA > mean(EFICIENCIA)'), 0),
#  (('BD=MYSQL', 'FRAMEWORK=CSHARP', 'EFICIENCIA < mean(EFICIENCIA)'), 0),
#  (('BD=MYSQL', 'FRAMEWORK=RAC(PHP)', 'EFICIENCIA > mean(EFICIENCIA)'), 0),
#  (('BD=MYSQL', 'FRAMEWORK=RAC(PHP)', 'EFICIENCIA < mean(EFICIENCIA)'), 0),
#  (('BD=MYSQL', 'FRAMEWORK=VUEJS', 'EFICIENCIA > mean(EFICIENCIA)'), 0),
#  (('BD=MYSQL', 'FRAMEWORK=VUEJS', 'EFICIENCIA < mean(EFICIENCIA)'), 0),
#  (('BD=DB2', 'FRAMEWORK=COPPELFRONTWEB', 'EFICIENCIA > mean(EFICIENCIA)'), 0),
#  (('BD=DB2', 'FRAMEWORK=COPPELFRONTWEB', 'EFICIENCIA < mean(EFICIENCIA)'), 0),
#  (('BD=DB2', 'FRAMEWORK=CSHARP', 'EFICIENCIA > mean(EFICIENCIA)'), 0),
#  (('BD=DB2', 'FRAMEWORK=CSHARP', 'EFICIENCIA < mean(EFICIENCIA)'), 0),
#  (('BD=DB2', 'FRAMEWORK=RAC(PHP)', 'EFICIENCIA > mean(EFICIENCIA)'), 0),
#  (('BD=DB2', 'FRAMEWORK=RAC(PHP)', 'EFICIENCIA < mean(EFICIENCIA)'), 0),
#  (('BD=DB2', 'FRAMEWORK=VUEJS', 'EFICIENCIA > mean(EFICIENCIA)'), 0),
#  (('BD=DB2', 'FRAMEWORK=VUEJS', 'EFICIENCIA < mean(EFICIENCIA)'), 0),
#  (('BD=MYSQL', 'METODOLOGÍA=ÁGIL', 'EFICIENCIA > mean(EFICIENCIA)'), 0),
#  (('BD=MYSQL', 'METODOLOGÍA=ÁGIL', 'EFICIENCIA < mean(EFICIENCIA)'), 0),
#  (('FRAMEWORK=VUEJS', 'CFP > mean(CFP)', 'EFICIENCIA < mean(EFICIENCIA)'), 0),
#  (('FRAMEWORK=VUEJS', 'CFP < mean(CFP)', 'EFICIENCIA > mean(EFICIENCIA)'), 0),
#  (('FRAMEWORK=VUEJS', 'CFP < mean(CFP)', 'EFICIENCIA < mean(EFICIENCIA)'), 0),
#  (('FRAMEWORK=COPPELFRONTWEB',
#    'ARQUITECTURA=MVC',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   0),
#  (('FRAMEWORK=COPPELFRONTWEB',
#    'ARQUITECTURA=OTRO',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   0),
#  (('FRAMEWORK=COPPELFRONTWEB',
#    'ARQUITECTURA=OTRO',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   0),
#  (('FRAMEWORK=CSHARP', 'ARQUITECTURA=MVC', 'EFICIENCIA > mean(EFICIENCIA)'),
#   0),
#  (('FRAMEWORK=CSHARP', 'ARQUITECTURA=MVC', 'EFICIENCIA < mean(EFICIENCIA)'),
#   0),
#  (('FRAMEWORK=CSHARP', 'ARQUITECTURA=OTRO', 'EFICIENCIA > mean(EFICIENCIA)'),
#   0),
#  (('FRAMEWORK=CSHARP', 'ARQUITECTURA=OTRO', 'EFICIENCIA < mean(EFICIENCIA)'),
#   0),
#  (('FRAMEWORK=RAC(PHP)', 'ARQUITECTURA=MVC', 'EFICIENCIA > mean(EFICIENCIA)'),
#   0),
#  (('FRAMEWORK=RAC(PHP)', 'ARQUITECTURA=MVC', 'EFICIENCIA < mean(EFICIENCIA)'),
#   0),
#  (('FRAMEWORK=RAC(PHP)', 'ARQUITECTURA=OTRO', 'EFICIENCIA > mean(EFICIENCIA)'),
#   0),
#  (('FRAMEWORK=RAC(PHP)', 'ARQUITECTURA=OTRO', 'EFICIENCIA < mean(EFICIENCIA)'),
#   0),
#  (('FRAMEWORK=VUEJS',
#    'ARQUITECTURA=CLIENTE/SERVIDOR',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   0),
#  (('FRAMEWORK=VUEJS',
#    'ARQUITECTURA=CLIENTE/SERVIDOR',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   0),
#  (('FRAMEWORK=VUEJS', 'ARQUITECTURA=CAPAS', 'EFICIENCIA < mean(EFICIENCIA)'),
#   0),
#  (('FRAMEWORK=VUEJS', 'ARQUITECTURA=MVC', 'EFICIENCIA > mean(EFICIENCIA)'), 0),
#  (('FRAMEWORK=VUEJS', 'ARQUITECTURA=MVC', 'EFICIENCIA < mean(EFICIENCIA)'), 0),
#  (('FRAMEWORK=VUEJS', 'ARQUITECTURA=OTRO', 'EFICIENCIA > mean(EFICIENCIA)'),
#   0),
#  (('FRAMEWORK=VUEJS', 'ARQUITECTURA=OTRO', 'EFICIENCIA < mean(EFICIENCIA)'),
#   0),
#  (('FRAMEWORK=OTRO', 'ARQUITECTURA=MVC', 'EFICIENCIA > mean(EFICIENCIA)'), 0),
#  (('FRAMEWORK=OTRO', 'ARQUITECTURA=MVC', 'EFICIENCIA < mean(EFICIENCIA)'), 0),
#  (('FRAMEWORK=CSHARP', 'LENGUAJE=PHP', 'EFICIENCIA > mean(EFICIENCIA)'), 0),
#  (('FRAMEWORK=CSHARP', 'LENGUAJE=PHP', 'EFICIENCIA < mean(EFICIENCIA)'), 0),
#  (('FRAMEWORK=CSHARP', 'LENGUAJE=C++', 'EFICIENCIA < mean(EFICIENCIA)'), 0),
#  (('FRAMEWORK=RAC(PHP)', 'LENGUAJE=C++', 'EFICIENCIA > mean(EFICIENCIA)'), 0),
#  (('FRAMEWORK=VUEJS', 'LENGUAJE=PHP', 'EFICIENCIA > mean(EFICIENCIA)'), 0),
#  (('FRAMEWORK=VUEJS', 'LENGUAJE=PHP', 'EFICIENCIA < mean(EFICIENCIA)'), 0),
#  (('FRAMEWORK=VUEJS', 'LENGUAJE=C++', 'EFICIENCIA > mean(EFICIENCIA)'), 0),
#  (('FRAMEWORK=VUEJS', 'LENGUAJE=C++', 'EFICIENCIA < mean(EFICIENCIA)'), 0),
#  (('FRAMEWORK=VUEJS', 'LENGUAJE=C#', 'EFICIENCIA > mean(EFICIENCIA)'), 0),
#  (('FRAMEWORK=VUEJS', 'LENGUAJE=C#', 'EFICIENCIA < mean(EFICIENCIA)'), 0),
#  (('FRAMEWORK=COPPELFRONTWEB',
#    'BD=POSTGRESQL/INFORMIX',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   0),
#  (('FRAMEWORK=COPPELFRONTWEB', 'BD=MYSQL', 'EFICIENCIA > mean(EFICIENCIA)'),
#   0),
#  (('FRAMEWORK=COPPELFRONTWEB', 'BD=MYSQL', 'EFICIENCIA < mean(EFICIENCIA)'),
#   0),
#  (('FRAMEWORK=COPPELFRONTWEB', 'BD=DB2', 'EFICIENCIA > mean(EFICIENCIA)'), 0),
#  (('FRAMEWORK=COPPELFRONTWEB', 'BD=DB2', 'EFICIENCIA < mean(EFICIENCIA)'), 0),
#  (('FRAMEWORK=CSHARP',
#    'BD=POSTGRESQL/INFORMIX',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   0),
#  (('FRAMEWORK=CSHARP',
#    'BD=POSTGRESQL/INFORMIX',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   0),
#  (('FRAMEWORK=CSHARP', 'BD=MYSQL', 'EFICIENCIA > mean(EFICIENCIA)'), 0),
#  (('FRAMEWORK=CSHARP', 'BD=MYSQL', 'EFICIENCIA < mean(EFICIENCIA)'), 0),
#  (('FRAMEWORK=CSHARP', 'BD=DB2', 'EFICIENCIA > mean(EFICIENCIA)'), 0),
#  (('FRAMEWORK=CSHARP', 'BD=DB2', 'EFICIENCIA < mean(EFICIENCIA)'), 0),
#  (('FRAMEWORK=RAC(PHP)',
#    'BD=POSTGRESQL/INFORMIX',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   0),
#  (('FRAMEWORK=RAC(PHP)',
#    'BD=POSTGRESQL/INFORMIX',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   0),
#  (('FRAMEWORK=RAC(PHP)', 'BD=MYSQL', 'EFICIENCIA > mean(EFICIENCIA)'), 0),
#  (('FRAMEWORK=RAC(PHP)', 'BD=MYSQL', 'EFICIENCIA < mean(EFICIENCIA)'), 0),
#  (('FRAMEWORK=RAC(PHP)', 'BD=DB2', 'EFICIENCIA > mean(EFICIENCIA)'), 0),
#  (('FRAMEWORK=RAC(PHP)', 'BD=DB2', 'EFICIENCIA < mean(EFICIENCIA)'), 0),
#  (('FRAMEWORK=VUEJS', 'BD=POSTGRESQL', 'EFICIENCIA < mean(EFICIENCIA)'), 0),
#  (('FRAMEWORK=VUEJS', 'BD=SQLSERVER', 'EFICIENCIA > mean(EFICIENCIA)'), 0),
#  (('FRAMEWORK=VUEJS', 'BD=SQLSERVER', 'EFICIENCIA < mean(EFICIENCIA)'), 0),
#  (('FRAMEWORK=VUEJS',
#    'BD=POSTGRESQL/INFORMIX',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   0),
#  (('FRAMEWORK=VUEJS',
#    'BD=POSTGRESQL/INFORMIX',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   0),
#  (('FRAMEWORK=VUEJS', 'BD=MYSQL', 'EFICIENCIA > mean(EFICIENCIA)'), 0),
#  (('FRAMEWORK=VUEJS', 'BD=MYSQL', 'EFICIENCIA < mean(EFICIENCIA)'), 0),
#  (('FRAMEWORK=VUEJS', 'BD=DB2', 'EFICIENCIA > mean(EFICIENCIA)'), 0),
#  (('FRAMEWORK=VUEJS', 'BD=DB2', 'EFICIENCIA < mean(EFICIENCIA)'), 0),
#  (('FRAMEWORK=RAC(PHP)', 'METODOLOGÍA=ÁGIL', 'EFICIENCIA > mean(EFICIENCIA)'),
#   0),
#  (('FRAMEWORK=VUEJS', 'METODOLOGÍA=CASCADA', 'EFICIENCIA < mean(EFICIENCIA)'),
#   0),
#  (('FRAMEWORK=VUEJS', 'METODOLOGÍA=ÁGIL', 'EFICIENCIA > mean(EFICIENCIA)'), 0),
#  (('FRAMEWORK=VUEJS', 'METODOLOGÍA=ÁGIL', 'EFICIENCIA < mean(EFICIENCIA)'), 0),
#  (('METODOLOGÍA=CASCADA', 'ARQUITECTURA=MVC', 'EFICIENCIA > mean(EFICIENCIA)'),
#   0),
#  (('METODOLOGÍA=ÁGIL', 'ARQUITECTURA=MVC', 'EFICIENCIA > mean(EFICIENCIA)'),
#   0),
#  (('METODOLOGÍA=ÁGIL', 'ARQUITECTURA=MVC', 'EFICIENCIA < mean(EFICIENCIA)'),
#   0),
#  (('METODOLOGÍA=ÁGIL', 'ARQUITECTURA=OTRO', 'EFICIENCIA > mean(EFICIENCIA)'),
#   0),
#  (('METODOLOGÍA=ÁGIL', 'BD=MYSQL', 'EFICIENCIA > mean(EFICIENCIA)'), 0),
#  (('METODOLOGÍA=ÁGIL', 'BD=MYSQL', 'EFICIENCIA < mean(EFICIENCIA)'), 0),
#  (('METODOLOGÍA=CASCADA', 'FRAMEWORK=VUEJS', 'EFICIENCIA < mean(EFICIENCIA)'),
#   0),
#  (('METODOLOGÍA=ÁGIL', 'FRAMEWORK=RAC(PHP)', 'EFICIENCIA > mean(EFICIENCIA)'),
#   0),
#  (('METODOLOGÍA=ÁGIL', 'FRAMEWORK=VUEJS', 'EFICIENCIA > mean(EFICIENCIA)'), 0),
#  (('METODOLOGÍA=ÁGIL', 'FRAMEWORK=VUEJS', 'EFICIENCIA < mean(EFICIENCIA)'), 0)]

# %%
sorted(confidences.items(), key=itemgetter(1), reverse=True)
# Out:
# [(('CFP > mean(CFP)', 'BD=DB2', 'EFICIENCIA > mean(EFICIENCIA)'), 100.0),
#  (('CFP > mean(CFP)', 'FRAMEWORK=VUEJS', 'EFICIENCIA > mean(EFICIENCIA)'),
#   100.0),
#  (('ARQUITECTURA=CAPAS', 'BD=DB2', 'EFICIENCIA > mean(EFICIENCIA)'), 100.0),
#  (('ARQUITECTURA=CAPAS', 'FRAMEWORK=VUEJS', 'EFICIENCIA > mean(EFICIENCIA)'),
#   100.0),
#  (('LENGUAJE=C++', 'FRAMEWORK=CSHARP', 'EFICIENCIA > mean(EFICIENCIA)'),
#   100.0),
#  (('BD=DB2', 'CFP > mean(CFP)', 'EFICIENCIA > mean(EFICIENCIA)'), 100.0),
#  (('BD=DB2', 'ARQUITECTURA=CAPAS', 'EFICIENCIA > mean(EFICIENCIA)'), 100.0),
#  (('BD=POSTGRESQL', 'FRAMEWORK=VUEJS', 'EFICIENCIA > mean(EFICIENCIA)'),
#   100.0),
#  (('FRAMEWORK=VUEJS', 'CFP > mean(CFP)', 'EFICIENCIA > mean(EFICIENCIA)'),
#   100.0),
#  (('FRAMEWORK=VUEJS', 'ARQUITECTURA=CAPAS', 'EFICIENCIA > mean(EFICIENCIA)'),
#   100.0),
#  (('FRAMEWORK=CSHARP', 'LENGUAJE=C++', 'EFICIENCIA > mean(EFICIENCIA)'),
#   100.0),
#  (('FRAMEWORK=VUEJS', 'BD=POSTGRESQL', 'EFICIENCIA > mean(EFICIENCIA)'),
#   100.0),
#  (('FRAMEWORK=VUEJS', 'METODOLOGÍA=CASCADA', 'EFICIENCIA > mean(EFICIENCIA)'),
#   100.0),
#  (('METODOLOGÍA=CASCADA', 'FRAMEWORK=VUEJS', 'EFICIENCIA > mean(EFICIENCIA)'),
#   100.0),
#  (('FRAMEWORK=CSHARP', 'METODOLOGÍA=ÁGIL', 'EFICIENCIA > mean(EFICIENCIA)'),
#   80.0),
#  (('METODOLOGÍA=ÁGIL', 'FRAMEWORK=CSHARP', 'EFICIENCIA > mean(EFICIENCIA)'),
#   80.0),
#  (('CFP < mean(CFP)', 'ARQUITECTURA=OTRO', 'EFICIENCIA > mean(EFICIENCIA)'),
#   75.0),
#  (('ARQUITECTURA=OTRO', 'CFP < mean(CFP)', 'EFICIENCIA > mean(EFICIENCIA)'),
#   75.0),
#  (('BD=DB2', 'FRAMEWORK=OTRO', 'EFICIENCIA > mean(EFICIENCIA)'), 70.0),
#  (('BD=DB2', 'METODOLOGÍA=CASCADA', 'EFICIENCIA > mean(EFICIENCIA)'), 70.0),
#  (('FRAMEWORK=OTRO', 'BD=DB2', 'EFICIENCIA > mean(EFICIENCIA)'), 70.0),
#  (('METODOLOGÍA=CASCADA', 'BD=DB2', 'EFICIENCIA > mean(EFICIENCIA)'), 70.0),
#  (('BD=DB2', 'METODOLOGÍA=ÁGIL', 'EFICIENCIA > mean(EFICIENCIA)'),
#   66.66666666666667),
#  (('METODOLOGÍA=ÁGIL', 'BD=DB2', 'EFICIENCIA > mean(EFICIENCIA)'),
#   66.66666666666667),
#  (('CFP > mean(CFP)', 'FRAMEWORK=CSHARP', 'EFICIENCIA > mean(EFICIENCIA)'),
#   64.70588235294117),
#  (('FRAMEWORK=CSHARP', 'CFP > mean(CFP)', 'EFICIENCIA > mean(EFICIENCIA)'),
#   64.70588235294117),
#  (('CFP > mean(CFP)',
#    'BD=POSTGRESQL/INFORMIX',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   62.5),
#  (('BD=POSTGRESQL/INFORMIX',
#    'CFP > mean(CFP)',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   62.5),
#  (('ARQUITECTURA=CLIENTE/SERVIDOR', 'BD=DB2', 'EFICIENCIA > mean(EFICIENCIA)'),
#   60.0),
#  (('ARQUITECTURA=OTRO',
#    'METODOLOGÍA=CASCADA',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   60.0),
#  (('BD=DB2', 'ARQUITECTURA=CLIENTE/SERVIDOR', 'EFICIENCIA > mean(EFICIENCIA)'),
#   60.0),
#  (('METODOLOGÍA=CASCADA',
#    'ARQUITECTURA=OTRO',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   60.0),
#  (('CFP > mean(CFP)', 'LENGUAJE=C++', 'EFICIENCIA > mean(EFICIENCIA)'),
#   59.57446808510638),
#  (('LENGUAJE=C++', 'CFP > mean(CFP)', 'EFICIENCIA > mean(EFICIENCIA)'),
#   59.57446808510638),
#  (('ARQUITECTURA=CLIENTE/SERVIDOR',
#    'FRAMEWORK=CSHARP',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   56.666666666666664),
#  (('FRAMEWORK=CSHARP',
#    'ARQUITECTURA=CLIENTE/SERVIDOR',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   56.666666666666664),
#  (('BD=SQLSERVER', 'FRAMEWORK=CSHARP', 'EFICIENCIA > mean(EFICIENCIA)'),
#   56.52173913043478),
#  (('FRAMEWORK=CSHARP', 'BD=SQLSERVER', 'EFICIENCIA > mean(EFICIENCIA)'),
#   56.52173913043478),
#  (('CFP > mean(CFP)',
#    'ARQUITECTURA=CLIENTE/SERVIDOR',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   56.48148148148148),
#  (('ARQUITECTURA=CLIENTE/SERVIDOR',
#    'CFP > mean(CFP)',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   56.48148148148148),
#  (('CFP > mean(CFP)', 'FRAMEWORK=OTRO', 'EFICIENCIA > mean(EFICIENCIA)'),
#   55.445544554455445),
#  (('FRAMEWORK=OTRO', 'CFP > mean(CFP)', 'EFICIENCIA > mean(EFICIENCIA)'),
#   55.445544554455445),
#  (('CFP > mean(CFP)', 'BD=POSTGRESQL', 'EFICIENCIA > mean(EFICIENCIA)'),
#   55.02183406113537),
#  (('BD=POSTGRESQL', 'CFP > mean(CFP)', 'EFICIENCIA > mean(EFICIENCIA)'),
#   55.02183406113537),
#  (('CFP > mean(CFP)', 'METODOLOGÍA=CASCADA', 'EFICIENCIA > mean(EFICIENCIA)'),
#   52.87958115183246),
#  (('METODOLOGÍA=CASCADA', 'CFP > mean(CFP)', 'EFICIENCIA > mean(EFICIENCIA)'),
#   52.87958115183246),
#  (('CFP > mean(CFP)', 'LENGUAJE=C#', 'EFICIENCIA > mean(EFICIENCIA)'),
#   51.111111111111114),
#  (('LENGUAJE=C#', 'CFP > mean(CFP)', 'EFICIENCIA > mean(EFICIENCIA)'),
#   51.111111111111114),
#  (('CFP > mean(CFP)', 'ARQUITECTURA=MVC', 'EFICIENCIA < mean(EFICIENCIA)'),
#   50.0),
#  (('CFP > mean(CFP)', 'ARQUITECTURA=OTRO', 'EFICIENCIA < mean(EFICIENCIA)'),
#   50.0),
#  (('CFP > mean(CFP)', 'BD=MYSQL', 'EFICIENCIA < mean(EFICIENCIA)'), 50.0),
#  (('CFP < mean(CFP)', 'BD=MYSQL', 'EFICIENCIA > mean(EFICIENCIA)'), 50.0),
#  (('ARQUITECTURA=MVC', 'CFP > mean(CFP)', 'EFICIENCIA < mean(EFICIENCIA)'),
#   50.0),
#  (('ARQUITECTURA=OTRO', 'CFP > mean(CFP)', 'EFICIENCIA < mean(EFICIENCIA)'),
#   50.0),
#  (('ARQUITECTURA=MVC', 'LENGUAJE=PHP', 'EFICIENCIA < mean(EFICIENCIA)'), 50.0),
#  (('ARQUITECTURA=MVC', 'BD=SQLSERVER', 'EFICIENCIA < mean(EFICIENCIA)'), 50.0),
#  (('ARQUITECTURA=MVC',
#    'FRAMEWORK=COPPELFRONTWEB',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   50.0),
#  (('ARQUITECTURA=OTRO', 'FRAMEWORK=OTRO', 'EFICIENCIA > mean(EFICIENCIA)'),
#   50.0),
#  (('ARQUITECTURA=MVC', 'METODOLOGÍA=CASCADA', 'EFICIENCIA < mean(EFICIENCIA)'),
#   50.0),
#  (('ARQUITECTURA=OTRO', 'METODOLOGÍA=ÁGIL', 'EFICIENCIA < mean(EFICIENCIA)'),
#   50.0),
#  (('LENGUAJE=PHP', 'ARQUITECTURA=MVC', 'EFICIENCIA < mean(EFICIENCIA)'), 50.0),
#  (('LENGUAJE=C#', 'BD=POSTGRESQL/INFORMIX', 'EFICIENCIA < mean(EFICIENCIA)'),
#   50.0),
#  (('LENGUAJE=C++',
#    'FRAMEWORK=COPPELFRONTWEB',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   50.0),
#  (('LENGUAJE=C++', 'FRAMEWORK=RAC(PHP)', 'EFICIENCIA < mean(EFICIENCIA)'),
#   50.0),
#  (('LENGUAJE=C#', 'FRAMEWORK=RAC(PHP)', 'EFICIENCIA > mean(EFICIENCIA)'),
#   50.0),
#  (('BD=MYSQL', 'CFP > mean(CFP)', 'EFICIENCIA < mean(EFICIENCIA)'), 50.0),
#  (('BD=MYSQL', 'CFP < mean(CFP)', 'EFICIENCIA > mean(EFICIENCIA)'), 50.0),
#  (('BD=SQLSERVER', 'ARQUITECTURA=MVC', 'EFICIENCIA < mean(EFICIENCIA)'), 50.0),
#  (('BD=POSTGRESQL/INFORMIX', 'LENGUAJE=C#', 'EFICIENCIA < mean(EFICIENCIA)'),
#   50.0),
#  (('BD=SQLSERVER', 'FRAMEWORK=RAC(PHP)', 'EFICIENCIA > mean(EFICIENCIA)'),
#   50.0),
#  (('BD=POSTGRESQL/INFORMIX',
#    'FRAMEWORK=COPPELFRONTWEB',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   50.0),
#  (('FRAMEWORK=COPPELFRONTWEB',
#    'ARQUITECTURA=MVC',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   50.0),
#  (('FRAMEWORK=OTRO', 'ARQUITECTURA=OTRO', 'EFICIENCIA > mean(EFICIENCIA)'),
#   50.0),
#  (('FRAMEWORK=COPPELFRONTWEB',
#    'LENGUAJE=C++',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   50.0),
#  (('FRAMEWORK=RAC(PHP)', 'LENGUAJE=C++', 'EFICIENCIA < mean(EFICIENCIA)'),
#   50.0),
#  (('FRAMEWORK=RAC(PHP)', 'LENGUAJE=C#', 'EFICIENCIA > mean(EFICIENCIA)'),
#   50.0),
#  (('FRAMEWORK=COPPELFRONTWEB',
#    'BD=POSTGRESQL/INFORMIX',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   50.0),
#  (('FRAMEWORK=RAC(PHP)', 'BD=SQLSERVER', 'EFICIENCIA > mean(EFICIENCIA)'),
#   50.0),
#  (('FRAMEWORK=COPPELFRONTWEB',
#    'METODOLOGÍA=ÁGIL',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   50.0),
#  (('FRAMEWORK=RAC(PHP)', 'METODOLOGÍA=ÁGIL', 'EFICIENCIA < mean(EFICIENCIA)'),
#   50.0),
#  (('METODOLOGÍA=CASCADA', 'ARQUITECTURA=MVC', 'EFICIENCIA < mean(EFICIENCIA)'),
#   50.0),
#  (('METODOLOGÍA=ÁGIL', 'ARQUITECTURA=OTRO', 'EFICIENCIA < mean(EFICIENCIA)'),
#   50.0),
#  (('METODOLOGÍA=ÁGIL',
#    'FRAMEWORK=COPPELFRONTWEB',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   50.0),
#  (('METODOLOGÍA=ÁGIL', 'FRAMEWORK=RAC(PHP)', 'EFICIENCIA < mean(EFICIENCIA)'),
#   50.0),
#  (('LENGUAJE=C#', 'BD=SQLSERVER', 'EFICIENCIA > mean(EFICIENCIA)'),
#   49.74874371859296),
#  (('BD=SQLSERVER', 'LENGUAJE=C#', 'EFICIENCIA > mean(EFICIENCIA)'),
#   49.74874371859296),
#  (('ARQUITECTURA=CLIENTE/SERVIDOR',
#    'LENGUAJE=C#',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   49.04214559386973),
#  (('LENGUAJE=C#',
#    'ARQUITECTURA=CLIENTE/SERVIDOR',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   49.04214559386973),
#  (('LENGUAJE=PHP', 'BD=POSTGRESQL', 'EFICIENCIA > mean(EFICIENCIA)'),
#   48.958333333333336),
#  (('BD=POSTGRESQL', 'LENGUAJE=PHP', 'EFICIENCIA > mean(EFICIENCIA)'),
#   48.958333333333336),
#  (('ARQUITECTURA=CLIENTE/SERVIDOR',
#    'BD=POSTGRESQL',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   48.68035190615836),
#  (('BD=POSTGRESQL',
#    'ARQUITECTURA=CLIENTE/SERVIDOR',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   48.68035190615836),
#  (('ARQUITECTURA=CLIENTE/SERVIDOR',
#    'BD=SQLSERVER',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   48.42767295597484),
#  (('BD=SQLSERVER',
#    'ARQUITECTURA=CLIENTE/SERVIDOR',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   48.42767295597484),
#  (('LENGUAJE=C#', 'METODOLOGÍA=CASCADA', 'EFICIENCIA > mean(EFICIENCIA)'),
#   48.1203007518797),
#  (('METODOLOGÍA=CASCADA', 'LENGUAJE=C#', 'EFICIENCIA > mean(EFICIENCIA)'),
#   48.1203007518797),
#  (('BD=POSTGRESQL', 'FRAMEWORK=OTRO', 'EFICIENCIA > mean(EFICIENCIA)'),
#   48.07121661721068),
#  (('FRAMEWORK=OTRO', 'BD=POSTGRESQL', 'EFICIENCIA > mean(EFICIENCIA)'),
#   48.07121661721068),
#  (('LENGUAJE=C++', 'BD=SQLSERVER', 'EFICIENCIA > mean(EFICIENCIA)'),
#   48.05194805194805),
#  (('BD=SQLSERVER', 'LENGUAJE=C++', 'EFICIENCIA > mean(EFICIENCIA)'),
#   48.05194805194805),
#  (('LENGUAJE=C#', 'FRAMEWORK=OTRO', 'EFICIENCIA > mean(EFICIENCIA)'),
#   48.01587301587302),
#  (('FRAMEWORK=OTRO', 'LENGUAJE=C#', 'EFICIENCIA > mean(EFICIENCIA)'),
#   48.01587301587302),
#  (('ARQUITECTURA=CLIENTE/SERVIDOR',
#    'FRAMEWORK=OTRO',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   47.91464597478176),
#  (('FRAMEWORK=OTRO',
#    'ARQUITECTURA=CLIENTE/SERVIDOR',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   47.91464597478176),
#  (('CFP > mean(CFP)', 'LENGUAJE=PHP', 'EFICIENCIA > mean(EFICIENCIA)'),
#   47.58620689655172),
#  (('LENGUAJE=PHP', 'CFP > mean(CFP)', 'EFICIENCIA > mean(EFICIENCIA)'),
#   47.58620689655172),
#  (('ARQUITECTURA=CLIENTE/SERVIDOR',
#    'METODOLOGÍA=CASCADA',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   47.55671902268761),
#  (('METODOLOGÍA=CASCADA',
#    'ARQUITECTURA=CLIENTE/SERVIDOR',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   47.55671902268761),
#  (('FRAMEWORK=OTRO', 'METODOLOGÍA=CASCADA', 'EFICIENCIA > mean(EFICIENCIA)'),
#   47.46215494211933),
#  (('METODOLOGÍA=CASCADA', 'FRAMEWORK=OTRO', 'EFICIENCIA > mean(EFICIENCIA)'),
#   47.46215494211933),
#  (('LENGUAJE=C#', 'FRAMEWORK=CSHARP', 'EFICIENCIA > mean(EFICIENCIA)'),
#   47.36842105263158),
#  (('FRAMEWORK=CSHARP', 'LENGUAJE=C#', 'EFICIENCIA > mean(EFICIENCIA)'),
#   47.36842105263158),
#  (('ARQUITECTURA=CLIENTE/SERVIDOR',
#    'LENGUAJE=PHP',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   47.35294117647059),
#  (('LENGUAJE=PHP',
#    'ARQUITECTURA=CLIENTE/SERVIDOR',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   47.35294117647059),
#  (('BD=POSTGRESQL', 'METODOLOGÍA=ÁGIL', 'EFICIENCIA > mean(EFICIENCIA)'),
#   47.16981132075472),
#  (('METODOLOGÍA=ÁGIL', 'BD=POSTGRESQL', 'EFICIENCIA > mean(EFICIENCIA)'),
#   47.16981132075472),
#  (('CFP > mean(CFP)', 'FRAMEWORK=RAC(PHP)', 'EFICIENCIA > mean(EFICIENCIA)'),
#   47.05882352941177),
#  (('FRAMEWORK=RAC(PHP)', 'CFP > mean(CFP)', 'EFICIENCIA > mean(EFICIENCIA)'),
#   47.05882352941177),
#  (('BD=SQLSERVER', 'METODOLOGÍA=CASCADA', 'EFICIENCIA > mean(EFICIENCIA)'),
#   47.01086956521739),
#  (('METODOLOGÍA=CASCADA', 'BD=SQLSERVER', 'EFICIENCIA > mean(EFICIENCIA)'),
#   47.01086956521739),
#  (('LENGUAJE=C++', 'BD=POSTGRESQL', 'EFICIENCIA > mean(EFICIENCIA)'),
#   46.84385382059801),
#  (('BD=POSTGRESQL', 'LENGUAJE=C++', 'EFICIENCIA > mean(EFICIENCIA)'),
#   46.84385382059801),
#  (('ARQUITECTURA=CLIENTE/SERVIDOR',
#    'LENGUAJE=C++',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   46.614583333333336),
#  (('LENGUAJE=C++',
#    'ARQUITECTURA=CLIENTE/SERVIDOR',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   46.614583333333336),
#  (('CFP < mean(CFP)', 'LENGUAJE=C#', 'EFICIENCIA > mean(EFICIENCIA)'),
#   46.54377880184332),
#  (('LENGUAJE=C#', 'CFP < mean(CFP)', 'EFICIENCIA > mean(EFICIENCIA)'),
#   46.54377880184332),
#  (('BD=POSTGRESQL', 'METODOLOGÍA=CASCADA', 'EFICIENCIA > mean(EFICIENCIA)'),
#   46.35761589403973),
#  (('METODOLOGÍA=CASCADA', 'BD=POSTGRESQL', 'EFICIENCIA > mean(EFICIENCIA)'),
#   46.35761589403973),
#  (('LENGUAJE=C#', 'METODOLOGÍA=ÁGIL', 'EFICIENCIA > mean(EFICIENCIA)'),
#   46.34146341463415),
#  (('METODOLOGÍA=ÁGIL', 'LENGUAJE=C#', 'EFICIENCIA > mean(EFICIENCIA)'),
#   46.34146341463415),
#  (('CFP > mean(CFP)', 'METODOLOGÍA=ÁGIL', 'EFICIENCIA > mean(EFICIENCIA)'),
#   46.15384615384615),
#  (('METODOLOGÍA=ÁGIL', 'CFP > mean(CFP)', 'EFICIENCIA > mean(EFICIENCIA)'),
#   46.15384615384615),
#  (('FRAMEWORK=RAC(PHP)',
#    'METODOLOGÍA=CASCADA',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   45.90163934426229),
#  (('METODOLOGÍA=CASCADA',
#    'FRAMEWORK=RAC(PHP)',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   45.90163934426229),
#  (('CFP < mean(CFP)', 'BD=SQLSERVER', 'EFICIENCIA > mean(EFICIENCIA)'),
#   45.89041095890411),
#  (('BD=SQLSERVER', 'CFP < mean(CFP)', 'EFICIENCIA > mean(EFICIENCIA)'),
#   45.89041095890411),
#  (('LENGUAJE=C++', 'FRAMEWORK=OTRO', 'EFICIENCIA > mean(EFICIENCIA)'),
#   45.876288659793815),
#  (('FRAMEWORK=OTRO', 'LENGUAJE=C++', 'EFICIENCIA > mean(EFICIENCIA)'),
#   45.876288659793815),
#  (('FRAMEWORK=CSHARP', 'METODOLOGÍA=CASCADA', 'EFICIENCIA > mean(EFICIENCIA)'),
#   45.714285714285715),
#  (('METODOLOGÍA=CASCADA', 'FRAMEWORK=CSHARP', 'EFICIENCIA > mean(EFICIENCIA)'),
#   45.714285714285715),
#  (('LENGUAJE=C#', 'BD=POSTGRESQL', 'EFICIENCIA > mean(EFICIENCIA)'),
#   45.63106796116505),
#  (('BD=POSTGRESQL', 'LENGUAJE=C#', 'EFICIENCIA > mean(EFICIENCIA)'),
#   45.63106796116505),
#  (('BD=SQLSERVER', 'FRAMEWORK=OTRO', 'EFICIENCIA > mean(EFICIENCIA)'),
#   45.54455445544554),
#  (('FRAMEWORK=OTRO', 'BD=SQLSERVER', 'EFICIENCIA > mean(EFICIENCIA)'),
#   45.54455445544554),
#  (('ARQUITECTURA=CAPAS',
#    'BD=POSTGRESQL/INFORMIX',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   45.45454545454545),
#  (('BD=POSTGRESQL/INFORMIX',
#    'ARQUITECTURA=CAPAS',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   45.45454545454545),
#  (('LENGUAJE=C++', 'METODOLOGÍA=CASCADA', 'EFICIENCIA > mean(EFICIENCIA)'),
#   45.26315789473684),
#  (('METODOLOGÍA=CASCADA', 'LENGUAJE=C++', 'EFICIENCIA > mean(EFICIENCIA)'),
#   45.26315789473684),
#  (('LENGUAJE=PHP', 'METODOLOGÍA=CASCADA', 'EFICIENCIA > mean(EFICIENCIA)'),
#   45.138888888888886),
#  (('METODOLOGÍA=CASCADA', 'LENGUAJE=PHP', 'EFICIENCIA > mean(EFICIENCIA)'),
#   45.138888888888886),
#  (('LENGUAJE=PHP', 'FRAMEWORK=OTRO', 'EFICIENCIA > mean(EFICIENCIA)'),
#   44.606413994169095),
#  (('FRAMEWORK=OTRO', 'LENGUAJE=PHP', 'EFICIENCIA > mean(EFICIENCIA)'),
#   44.606413994169095),
#  (('ARQUITECTURA=CLIENTE/SERVIDOR',
#    'FRAMEWORK=RAC(PHP)',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   44.11764705882353),
#  (('FRAMEWORK=RAC(PHP)',
#    'ARQUITECTURA=CLIENTE/SERVIDOR',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   44.11764705882353),
#  (('CFP > mean(CFP)', 'BD=SQLSERVER', 'EFICIENCIA > mean(EFICIENCIA)'),
#   44.02985074626866),
#  (('BD=SQLSERVER', 'CFP > mean(CFP)', 'EFICIENCIA > mean(EFICIENCIA)'),
#   44.02985074626866),
#  (('ARQUITECTURA=CAPAS', 'METODOLOGÍA=ÁGIL', 'EFICIENCIA > mean(EFICIENCIA)'),
#   43.90243902439025),
#  (('METODOLOGÍA=ÁGIL', 'ARQUITECTURA=CAPAS', 'EFICIENCIA > mean(EFICIENCIA)'),
#   43.90243902439025),
#  (('LENGUAJE=PHP', 'FRAMEWORK=RAC(PHP)', 'EFICIENCIA > mean(EFICIENCIA)'),
#   43.85964912280702),
#  (('FRAMEWORK=RAC(PHP)', 'LENGUAJE=PHP', 'EFICIENCIA > mean(EFICIENCIA)'),
#   43.85964912280702),
#  (('BD=POSTGRESQL', 'FRAMEWORK=CSHARP', 'EFICIENCIA > mean(EFICIENCIA)'),
#   43.75),
#  (('FRAMEWORK=CSHARP', 'BD=POSTGRESQL', 'EFICIENCIA > mean(EFICIENCIA)'),
#   43.75),
#  (('CFP < mean(CFP)', 'FRAMEWORK=OTRO', 'EFICIENCIA > mean(EFICIENCIA)'),
#   43.648208469055376),
#  (('FRAMEWORK=OTRO', 'CFP < mean(CFP)', 'EFICIENCIA > mean(EFICIENCIA)'),
#   43.648208469055376),
#  (('CFP < mean(CFP)',
#    'ARQUITECTURA=CLIENTE/SERVIDOR',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   43.550165380374864),
#  (('ARQUITECTURA=CLIENTE/SERVIDOR',
#    'CFP < mean(CFP)',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   43.550165380374864),
#  (('ARQUITECTURA=CAPAS',
#    'FRAMEWORK=RAC(PHP)',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   43.333333333333336),
#  (('LENGUAJE=C++', 'METODOLOGÍA=ÁGIL', 'EFICIENCIA > mean(EFICIENCIA)'),
#   43.333333333333336),
#  (('FRAMEWORK=RAC(PHP)',
#    'ARQUITECTURA=CAPAS',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   43.333333333333336),
#  (('METODOLOGÍA=ÁGIL', 'LENGUAJE=C++', 'EFICIENCIA > mean(EFICIENCIA)'),
#   43.333333333333336),
#  (('CFP < mean(CFP)', 'METODOLOGÍA=CASCADA', 'EFICIENCIA > mean(EFICIENCIA)'),
#   43.08457711442786),
#  (('METODOLOGÍA=CASCADA', 'CFP < mean(CFP)', 'EFICIENCIA > mean(EFICIENCIA)'),
#   43.08457711442786),
#  (('CFP < mean(CFP)', 'BD=POSTGRESQL', 'EFICIENCIA > mean(EFICIENCIA)'),
#   43.005181347150256),
#  (('BD=POSTGRESQL', 'CFP < mean(CFP)', 'EFICIENCIA > mean(EFICIENCIA)'),
#   43.005181347150256),
#  (('CFP < mean(CFP)', 'FRAMEWORK=RAC(PHP)', 'EFICIENCIA > mean(EFICIENCIA)'),
#   42.5531914893617),
#  (('FRAMEWORK=RAC(PHP)', 'CFP < mean(CFP)', 'EFICIENCIA > mean(EFICIENCIA)'),
#   42.5531914893617),
#  (('CFP < mean(CFP)', 'LENGUAJE=PHP', 'EFICIENCIA > mean(EFICIENCIA)'),
#   42.05607476635514),
#  (('LENGUAJE=PHP', 'CFP < mean(CFP)', 'EFICIENCIA > mean(EFICIENCIA)'),
#   42.05607476635514),
#  (('ARQUITECTURA=CAPAS', 'LENGUAJE=C#', 'EFICIENCIA > mean(EFICIENCIA)'),
#   41.30434782608695),
#  (('LENGUAJE=C#', 'ARQUITECTURA=CAPAS', 'EFICIENCIA > mean(EFICIENCIA)'),
#   41.30434782608695),
#  (('CFP < mean(CFP)', 'LENGUAJE=C++', 'EFICIENCIA > mean(EFICIENCIA)'),
#   40.822784810126585),
#  (('LENGUAJE=C++', 'CFP < mean(CFP)', 'EFICIENCIA > mean(EFICIENCIA)'),
#   40.822784810126585),
#  (('BD=POSTGRESQL/INFORMIX',
#    'FRAMEWORK=OTRO',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   40.140845070422536),
#  (('FRAMEWORK=OTRO',
#    'BD=POSTGRESQL/INFORMIX',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   40.140845070422536),
#  (('CFP > mean(CFP)', 'ARQUITECTURA=CAPAS', 'EFICIENCIA > mean(EFICIENCIA)'),
#   39.361702127659576),
#  (('ARQUITECTURA=CAPAS', 'CFP > mean(CFP)', 'EFICIENCIA > mean(EFICIENCIA)'),
#   39.361702127659576),
#  (('CFP < mean(CFP)', 'FRAMEWORK=CSHARP', 'EFICIENCIA > mean(EFICIENCIA)'),
#   39.130434782608695),
#  (('FRAMEWORK=CSHARP', 'CFP < mean(CFP)', 'EFICIENCIA > mean(EFICIENCIA)'),
#   39.130434782608695),
#  (('BD=POSTGRESQL/INFORMIX',
#    'METODOLOGÍA=CASCADA',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   39.0728476821192),
#  (('METODOLOGÍA=CASCADA',
#    'BD=POSTGRESQL/INFORMIX',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   39.0728476821192),
#  (('ARQUITECTURA=CAPAS', 'FRAMEWORK=OTRO', 'EFICIENCIA > mean(EFICIENCIA)'),
#   39.037433155080215),
#  (('FRAMEWORK=OTRO', 'ARQUITECTURA=CAPAS', 'EFICIENCIA > mean(EFICIENCIA)'),
#   39.037433155080215),
#  (('ARQUITECTURA=CLIENTE/SERVIDOR',
#    'METODOLOGÍA=ÁGIL',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   38.8235294117647),
#  (('METODOLOGÍA=ÁGIL',
#    'ARQUITECTURA=CLIENTE/SERVIDOR',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   38.8235294117647),
#  (('ARQUITECTURA=CAPAS', 'LENGUAJE=C++', 'EFICIENCIA < mean(EFICIENCIA)'),
#   38.46153846153846),
#  (('LENGUAJE=C++', 'ARQUITECTURA=CAPAS', 'EFICIENCIA < mean(EFICIENCIA)'),
#   38.46153846153846),
#  (('ARQUITECTURA=CAPAS',
#    'FRAMEWORK=COPPELFRONTWEB',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   38.23529411764706),
#  (('FRAMEWORK=COPPELFRONTWEB',
#    'ARQUITECTURA=CAPAS',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   38.23529411764706),
#  (('ARQUITECTURA=CLIENTE/SERVIDOR',
#    'BD=POSTGRESQL/INFORMIX',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   38.19444444444444),
#  (('BD=POSTGRESQL/INFORMIX',
#    'ARQUITECTURA=CLIENTE/SERVIDOR',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   38.19444444444444),
#  (('LENGUAJE=C++', 'BD=POSTGRESQL/INFORMIX', 'EFICIENCIA < mean(EFICIENCIA)'),
#   38.095238095238095),
#  (('BD=POSTGRESQL/INFORMIX', 'LENGUAJE=C++', 'EFICIENCIA < mean(EFICIENCIA)'),
#   38.095238095238095),
#  (('CFP < mean(CFP)', 'METODOLOGÍA=ÁGIL', 'EFICIENCIA > mean(EFICIENCIA)'),
#   37.5),
#  (('BD=POSTGRESQL/INFORMIX',
#    'METODOLOGÍA=ÁGIL',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   37.5),
#  (('METODOLOGÍA=ÁGIL', 'CFP < mean(CFP)', 'EFICIENCIA > mean(EFICIENCIA)'),
#   37.5),
#  (('METODOLOGÍA=ÁGIL',
#    'BD=POSTGRESQL/INFORMIX',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   37.5),
#  (('CFP < mean(CFP)', 'ARQUITECTURA=CAPAS', 'EFICIENCIA > mean(EFICIENCIA)'),
#   37.362637362637365),
#  (('ARQUITECTURA=CAPAS', 'CFP < mean(CFP)', 'EFICIENCIA > mean(EFICIENCIA)'),
#   37.362637362637365),
#  (('ARQUITECTURA=CLIENTE/SERVIDOR',
#    'FRAMEWORK=COPPELFRONTWEB',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   37.142857142857146),
#  (('FRAMEWORK=COPPELFRONTWEB',
#    'ARQUITECTURA=CLIENTE/SERVIDOR',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   37.142857142857146),
#  (('ARQUITECTURA=CAPAS',
#    'METODOLOGÍA=CASCADA',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   37.02127659574468),
#  (('METODOLOGÍA=CASCADA',
#    'ARQUITECTURA=CAPAS',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   37.02127659574468),
#  (('LENGUAJE=PHP', 'BD=SQLSERVER', 'EFICIENCIA > mean(EFICIENCIA)'),
#   36.8421052631579),
#  (('BD=SQLSERVER', 'LENGUAJE=PHP', 'EFICIENCIA > mean(EFICIENCIA)'),
#   36.8421052631579),
#  (('LENGUAJE=PHP', 'METODOLOGÍA=ÁGIL', 'EFICIENCIA < mean(EFICIENCIA)'),
#   36.76470588235294),
#  (('METODOLOGÍA=ÁGIL', 'LENGUAJE=PHP', 'EFICIENCIA < mean(EFICIENCIA)'),
#   36.76470588235294),
#  (('FRAMEWORK=OTRO', 'METODOLOGÍA=ÁGIL', 'EFICIENCIA > mean(EFICIENCIA)'),
#   36.633663366336634),
#  (('METODOLOGÍA=ÁGIL', 'FRAMEWORK=OTRO', 'EFICIENCIA > mean(EFICIENCIA)'),
#   36.633663366336634),
#  (('ARQUITECTURA=CAPAS', 'BD=SQLSERVER', 'EFICIENCIA > mean(EFICIENCIA)'),
#   36.44859813084112),
#  (('BD=SQLSERVER', 'ARQUITECTURA=CAPAS', 'EFICIENCIA > mean(EFICIENCIA)'),
#   36.44859813084112),
#  (('BD=POSTGRESQL', 'FRAMEWORK=RAC(PHP)', 'EFICIENCIA > mean(EFICIENCIA)'),
#   36.0),
#  (('FRAMEWORK=RAC(PHP)', 'BD=POSTGRESQL', 'EFICIENCIA > mean(EFICIENCIA)'),
#   36.0),
#  (('CFP < mean(CFP)',
#    'FRAMEWORK=COPPELFRONTWEB',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   35.416666666666664),
#  (('FRAMEWORK=COPPELFRONTWEB',
#    'CFP < mean(CFP)',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   35.416666666666664),
#  (('ARQUITECTURA=CAPAS', 'FRAMEWORK=CSHARP', 'EFICIENCIA < mean(EFICIENCIA)'),
#   35.0),
#  (('FRAMEWORK=CSHARP', 'ARQUITECTURA=CAPAS', 'EFICIENCIA < mean(EFICIENCIA)'),
#   35.0),
#  (('BD=POSTGRESQL',
#    'FRAMEWORK=COPPELFRONTWEB',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   34.78260869565217),
#  (('FRAMEWORK=COPPELFRONTWEB',
#    'BD=POSTGRESQL',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   34.78260869565217),
#  (('LENGUAJE=PHP', 'BD=POSTGRESQL/INFORMIX', 'EFICIENCIA < mean(EFICIENCIA)'),
#   34.61538461538461),
#  (('BD=POSTGRESQL/INFORMIX', 'LENGUAJE=PHP', 'EFICIENCIA < mean(EFICIENCIA)'),
#   34.61538461538461),
#  (('CFP > mean(CFP)',
#    'FRAMEWORK=COPPELFRONTWEB',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   34.48275862068966),
#  (('BD=SQLSERVER', 'METODOLOGÍA=ÁGIL', 'EFICIENCIA > mean(EFICIENCIA)'),
#   34.48275862068966),
#  (('FRAMEWORK=COPPELFRONTWEB',
#    'CFP > mean(CFP)',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   34.48275862068966),
#  (('METODOLOGÍA=ÁGIL', 'BD=SQLSERVER', 'EFICIENCIA > mean(EFICIENCIA)'),
#   34.48275862068966),
#  (('ARQUITECTURA=CAPAS', 'LENGUAJE=PHP', 'EFICIENCIA > mean(EFICIENCIA)'),
#   34.4),
#  (('LENGUAJE=PHP', 'ARQUITECTURA=CAPAS', 'EFICIENCIA > mean(EFICIENCIA)'),
#   34.4),
#  (('FRAMEWORK=COPPELFRONTWEB',
#    'METODOLOGÍA=CASCADA',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   34.31372549019608),
#  (('METODOLOGÍA=CASCADA',
#    'FRAMEWORK=COPPELFRONTWEB',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   34.31372549019608),
#  (('ARQUITECTURA=CAPAS', 'BD=POSTGRESQL', 'EFICIENCIA > mean(EFICIENCIA)'),
#   34.12698412698413),
#  (('BD=POSTGRESQL', 'ARQUITECTURA=CAPAS', 'EFICIENCIA > mean(EFICIENCIA)'),
#   34.12698412698413),
#  (('LENGUAJE=PHP',
#    'FRAMEWORK=COPPELFRONTWEB',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   34.09090909090909),
#  (('FRAMEWORK=COPPELFRONTWEB',
#    'LENGUAJE=PHP',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   34.09090909090909),
#  (('CFP < mean(CFP)',
#    'BD=POSTGRESQL/INFORMIX',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   33.739837398373986),
#  (('BD=POSTGRESQL/INFORMIX',
#    'CFP < mean(CFP)',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   33.739837398373986),
#  (('CFP < mean(CFP)', 'BD=DB2', 'EFICIENCIA > mean(EFICIENCIA)'),
#   33.333333333333336),
#  (('CFP < mean(CFP)', 'BD=DB2', 'EFICIENCIA < mean(EFICIENCIA)'),
#   33.333333333333336),
#  (('ARQUITECTURA=CLIENTE/SERVIDOR',
#    'BD=MYSQL',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   33.333333333333336),
#  (('ARQUITECTURA=CLIENTE/SERVIDOR',
#    'BD=MYSQL',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   33.333333333333336),
#  (('LENGUAJE=PHP', 'BD=MYSQL', 'EFICIENCIA > mean(EFICIENCIA)'),
#   33.333333333333336),
#  (('LENGUAJE=PHP', 'BD=MYSQL', 'EFICIENCIA < mean(EFICIENCIA)'),
#   33.333333333333336),
#  (('LENGUAJE=C#', 'FRAMEWORK=COPPELFRONTWEB', 'EFICIENCIA > mean(EFICIENCIA)'),
#   33.333333333333336),
#  (('LENGUAJE=C#', 'FRAMEWORK=COPPELFRONTWEB', 'EFICIENCIA < mean(EFICIENCIA)'),
#   33.333333333333336),
#  (('BD=DB2', 'CFP < mean(CFP)', 'EFICIENCIA > mean(EFICIENCIA)'),
#   33.333333333333336),
#  (('BD=DB2', 'CFP < mean(CFP)', 'EFICIENCIA < mean(EFICIENCIA)'),
#   33.333333333333336),
#  (('BD=MYSQL',
#    'ARQUITECTURA=CLIENTE/SERVIDOR',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   33.333333333333336),
#  (('BD=MYSQL',
#    'ARQUITECTURA=CLIENTE/SERVIDOR',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   33.333333333333336),
#  (('BD=MYSQL', 'LENGUAJE=PHP', 'EFICIENCIA > mean(EFICIENCIA)'),
#   33.333333333333336),
#  (('BD=MYSQL', 'LENGUAJE=PHP', 'EFICIENCIA < mean(EFICIENCIA)'),
#   33.333333333333336),
#  (('BD=SQLSERVER',
#    'FRAMEWORK=COPPELFRONTWEB',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   33.333333333333336),
#  (('BD=SQLSERVER',
#    'FRAMEWORK=COPPELFRONTWEB',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   33.333333333333336),
#  (('BD=MYSQL', 'FRAMEWORK=OTRO', 'EFICIENCIA > mean(EFICIENCIA)'),
#   33.333333333333336),
#  (('BD=MYSQL', 'FRAMEWORK=OTRO', 'EFICIENCIA < mean(EFICIENCIA)'),
#   33.333333333333336),
#  (('BD=MYSQL', 'METODOLOGÍA=CASCADA', 'EFICIENCIA > mean(EFICIENCIA)'),
#   33.333333333333336),
#  (('BD=MYSQL', 'METODOLOGÍA=CASCADA', 'EFICIENCIA < mean(EFICIENCIA)'),
#   33.333333333333336),
#  (('FRAMEWORK=COPPELFRONTWEB', 'LENGUAJE=C#', 'EFICIENCIA > mean(EFICIENCIA)'),
#   33.333333333333336),
#  (('FRAMEWORK=COPPELFRONTWEB', 'LENGUAJE=C#', 'EFICIENCIA < mean(EFICIENCIA)'),
#   33.333333333333336),
#  (('FRAMEWORK=COPPELFRONTWEB',
#    'BD=SQLSERVER',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   33.333333333333336),
#  (('FRAMEWORK=COPPELFRONTWEB',
#    'BD=SQLSERVER',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   33.333333333333336),
#  (('FRAMEWORK=OTRO', 'BD=MYSQL', 'EFICIENCIA > mean(EFICIENCIA)'),
#   33.333333333333336),
#  (('FRAMEWORK=OTRO', 'BD=MYSQL', 'EFICIENCIA < mean(EFICIENCIA)'),
#   33.333333333333336),
#  (('METODOLOGÍA=CASCADA', 'BD=MYSQL', 'EFICIENCIA > mean(EFICIENCIA)'),
#   33.333333333333336),
#  (('METODOLOGÍA=CASCADA', 'BD=MYSQL', 'EFICIENCIA < mean(EFICIENCIA)'),
#   33.333333333333336),
#  (('ARQUITECTURA=CAPAS', 'BD=POSTGRESQL', 'EFICIENCIA < mean(EFICIENCIA)'),
#   32.93650793650794),
#  (('BD=POSTGRESQL', 'ARQUITECTURA=CAPAS', 'EFICIENCIA < mean(EFICIENCIA)'),
#   32.93650793650794),
#  (('ARQUITECTURA=CAPAS', 'LENGUAJE=PHP', 'EFICIENCIA < mean(EFICIENCIA)'),
#   32.8),
#  (('LENGUAJE=PHP', 'ARQUITECTURA=CAPAS', 'EFICIENCIA < mean(EFICIENCIA)'),
#   32.8),
#  (('CFP > mean(CFP)',
#    'FRAMEWORK=COPPELFRONTWEB',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   32.758620689655174),
#  (('BD=SQLSERVER', 'METODOLOGÍA=ÁGIL', 'EFICIENCIA < mean(EFICIENCIA)'),
#   32.758620689655174),
#  (('FRAMEWORK=COPPELFRONTWEB',
#    'CFP > mean(CFP)',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   32.758620689655174),
#  (('METODOLOGÍA=ÁGIL', 'BD=SQLSERVER', 'EFICIENCIA < mean(EFICIENCIA)'),
#   32.758620689655174),
#  (('BD=POSTGRESQL',
#    'FRAMEWORK=COPPELFRONTWEB',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   32.608695652173914),
#  (('FRAMEWORK=COPPELFRONTWEB',
#    'BD=POSTGRESQL',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   32.608695652173914),
#  (('CFP < mean(CFP)',
#    'BD=POSTGRESQL/INFORMIX',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   32.520325203252035),
#  (('BD=POSTGRESQL/INFORMIX',
#    'CFP < mean(CFP)',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   32.520325203252035),
#  (('BD=POSTGRESQL', 'FRAMEWORK=RAC(PHP)', 'EFICIENCIA < mean(EFICIENCIA)'),
#   32.0),
#  (('FRAMEWORK=RAC(PHP)', 'BD=POSTGRESQL', 'EFICIENCIA < mean(EFICIENCIA)'),
#   32.0),
#  (('LENGUAJE=PHP',
#    'FRAMEWORK=COPPELFRONTWEB',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   31.818181818181817),
#  (('FRAMEWORK=COPPELFRONTWEB',
#    'LENGUAJE=PHP',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   31.818181818181817),
#  (('ARQUITECTURA=CAPAS', 'BD=SQLSERVER', 'EFICIENCIA < mean(EFICIENCIA)'),
#   31.77570093457944),
#  (('BD=SQLSERVER', 'ARQUITECTURA=CAPAS', 'EFICIENCIA < mean(EFICIENCIA)'),
#   31.77570093457944),
#  (('FRAMEWORK=OTRO', 'METODOLOGÍA=ÁGIL', 'EFICIENCIA < mean(EFICIENCIA)'),
#   31.683168316831683),
#  (('METODOLOGÍA=ÁGIL', 'FRAMEWORK=OTRO', 'EFICIENCIA < mean(EFICIENCIA)'),
#   31.683168316831683),
#  (('LENGUAJE=PHP', 'BD=SQLSERVER', 'EFICIENCIA < mean(EFICIENCIA)'),
#   31.57894736842105),
#  (('BD=SQLSERVER', 'LENGUAJE=PHP', 'EFICIENCIA < mean(EFICIENCIA)'),
#   31.57894736842105),
#  (('ARQUITECTURA=CAPAS',
#    'METODOLOGÍA=CASCADA',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   31.48936170212766),
#  (('METODOLOGÍA=CASCADA',
#    'ARQUITECTURA=CAPAS',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   31.48936170212766),
#  (('ARQUITECTURA=CLIENTE/SERVIDOR',
#    'FRAMEWORK=COPPELFRONTWEB',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   31.428571428571427),
#  (('FRAMEWORK=COPPELFRONTWEB',
#    'ARQUITECTURA=CLIENTE/SERVIDOR',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   31.428571428571427),
#  (('FRAMEWORK=COPPELFRONTWEB',
#    'METODOLOGÍA=CASCADA',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   31.372549019607842),
#  (('METODOLOGÍA=CASCADA',
#    'FRAMEWORK=COPPELFRONTWEB',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   31.372549019607842),
#  (('CFP < mean(CFP)', 'ARQUITECTURA=CAPAS', 'EFICIENCIA < mean(EFICIENCIA)'),
#   31.318681318681318),
#  (('ARQUITECTURA=CAPAS', 'CFP < mean(CFP)', 'EFICIENCIA < mean(EFICIENCIA)'),
#   31.318681318681318),
#  (('CFP < mean(CFP)', 'METODOLOGÍA=ÁGIL', 'EFICIENCIA < mean(EFICIENCIA)'),
#   31.25),
#  (('METODOLOGÍA=ÁGIL', 'CFP < mean(CFP)', 'EFICIENCIA < mean(EFICIENCIA)'),
#   31.25),
#  (('ARQUITECTURA=CLIENTE/SERVIDOR',
#    'BD=POSTGRESQL/INFORMIX',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   30.90277777777778),
#  (('BD=POSTGRESQL/INFORMIX',
#    'ARQUITECTURA=CLIENTE/SERVIDOR',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   30.90277777777778),
#  (('LENGUAJE=PHP', 'BD=POSTGRESQL/INFORMIX', 'EFICIENCIA > mean(EFICIENCIA)'),
#   30.76923076923077),
#  (('BD=POSTGRESQL/INFORMIX', 'LENGUAJE=PHP', 'EFICIENCIA > mean(EFICIENCIA)'),
#   30.76923076923077),
#  (('ARQUITECTURA=CLIENTE/SERVIDOR',
#    'METODOLOGÍA=ÁGIL',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   30.58823529411765),
#  (('METODOLOGÍA=ÁGIL',
#    'ARQUITECTURA=CLIENTE/SERVIDOR',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   30.58823529411765),
#  (('ARQUITECTURA=CAPAS', 'FRAMEWORK=OTRO', 'EFICIENCIA < mean(EFICIENCIA)'),
#   30.481283422459892),
#  (('FRAMEWORK=OTRO', 'ARQUITECTURA=CAPAS', 'EFICIENCIA < mean(EFICIENCIA)'),
#   30.481283422459892),
#  (('BD=POSTGRESQL/INFORMIX',
#    'METODOLOGÍA=CASCADA',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   30.4635761589404),
#  (('METODOLOGÍA=CASCADA',
#    'BD=POSTGRESQL/INFORMIX',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   30.4635761589404),
#  (('CFP < mean(CFP)', 'FRAMEWORK=CSHARP', 'EFICIENCIA < mean(EFICIENCIA)'),
#   30.434782608695652),
#  (('FRAMEWORK=CSHARP', 'CFP < mean(CFP)', 'EFICIENCIA < mean(EFICIENCIA)'),
#   30.434782608695652),
#  (('CFP > mean(CFP)', 'ARQUITECTURA=CAPAS', 'EFICIENCIA < mean(EFICIENCIA)'),
#   30.319148936170212),
#  (('ARQUITECTURA=CAPAS', 'CFP > mean(CFP)', 'EFICIENCIA < mean(EFICIENCIA)'),
#   30.319148936170212),
#  (('ARQUITECTURA=CAPAS', 'FRAMEWORK=CSHARP', 'EFICIENCIA > mean(EFICIENCIA)'),
#   30.0),
#  (('FRAMEWORK=CSHARP', 'ARQUITECTURA=CAPAS', 'EFICIENCIA > mean(EFICIENCIA)'),
#   30.0),
#  (('BD=POSTGRESQL/INFORMIX',
#    'FRAMEWORK=OTRO',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   29.929577464788732),
#  (('FRAMEWORK=OTRO',
#    'BD=POSTGRESQL/INFORMIX',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   29.929577464788732),
#  (('CFP < mean(CFP)', 'LENGUAJE=C++', 'EFICIENCIA < mean(EFICIENCIA)'),
#   29.588607594936708),
#  (('LENGUAJE=C++', 'CFP < mean(CFP)', 'EFICIENCIA < mean(EFICIENCIA)'),
#   29.588607594936708),
#  (('ARQUITECTURA=CAPAS', 'LENGUAJE=C#', 'EFICIENCIA < mean(EFICIENCIA)'),
#   29.347826086956523),
#  (('LENGUAJE=C#', 'ARQUITECTURA=CAPAS', 'EFICIENCIA < mean(EFICIENCIA)'),
#   29.347826086956523),
#  (('CFP < mean(CFP)',
#    'FRAMEWORK=COPPELFRONTWEB',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   29.166666666666668),
#  (('FRAMEWORK=COPPELFRONTWEB',
#    'CFP < mean(CFP)',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   29.166666666666668),
#  (('CFP < mean(CFP)', 'LENGUAJE=PHP', 'EFICIENCIA < mean(EFICIENCIA)'),
#   28.97196261682243),
#  (('LENGUAJE=PHP', 'CFP < mean(CFP)', 'EFICIENCIA < mean(EFICIENCIA)'),
#   28.97196261682243),
#  (('CFP < mean(CFP)', 'FRAMEWORK=RAC(PHP)', 'EFICIENCIA < mean(EFICIENCIA)'),
#   28.72340425531915),
#  (('FRAMEWORK=RAC(PHP)', 'CFP < mean(CFP)', 'EFICIENCIA < mean(EFICIENCIA)'),
#   28.72340425531915),
#  (('CFP < mean(CFP)', 'BD=POSTGRESQL', 'EFICIENCIA < mean(EFICIENCIA)'),
#   28.497409326424872),
#  (('BD=POSTGRESQL', 'CFP < mean(CFP)', 'EFICIENCIA < mean(EFICIENCIA)'),
#   28.497409326424872),
#  (('CFP < mean(CFP)', 'METODOLOGÍA=CASCADA', 'EFICIENCIA < mean(EFICIENCIA)'),
#   28.45771144278607),
#  (('METODOLOGÍA=CASCADA', 'CFP < mean(CFP)', 'EFICIENCIA < mean(EFICIENCIA)'),
#   28.45771144278607),
#  (('ARQUITECTURA=CAPAS',
#    'FRAMEWORK=RAC(PHP)',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   28.333333333333332),
#  (('LENGUAJE=C++', 'METODOLOGÍA=ÁGIL', 'EFICIENCIA < mean(EFICIENCIA)'),
#   28.333333333333332),
#  (('FRAMEWORK=RAC(PHP)',
#    'ARQUITECTURA=CAPAS',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   28.333333333333332),
#  (('METODOLOGÍA=ÁGIL', 'LENGUAJE=C++', 'EFICIENCIA < mean(EFICIENCIA)'),
#   28.333333333333332),
#  (('CFP < mean(CFP)',
#    'ARQUITECTURA=CLIENTE/SERVIDOR',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   28.224917309812568),
#  (('ARQUITECTURA=CLIENTE/SERVIDOR',
#    'CFP < mean(CFP)',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   28.224917309812568),
#  (('CFP < mean(CFP)', 'FRAMEWORK=OTRO', 'EFICIENCIA < mean(EFICIENCIA)'),
#   28.175895765472312),
#  (('FRAMEWORK=OTRO', 'CFP < mean(CFP)', 'EFICIENCIA < mean(EFICIENCIA)'),
#   28.175895765472312),
#  (('BD=POSTGRESQL', 'FRAMEWORK=CSHARP', 'EFICIENCIA < mean(EFICIENCIA)'),
#   28.125),
#  (('FRAMEWORK=CSHARP', 'BD=POSTGRESQL', 'EFICIENCIA < mean(EFICIENCIA)'),
#   28.125),
#  (('LENGUAJE=PHP', 'FRAMEWORK=RAC(PHP)', 'EFICIENCIA < mean(EFICIENCIA)'),
#   28.07017543859649),
#  (('FRAMEWORK=RAC(PHP)', 'LENGUAJE=PHP', 'EFICIENCIA < mean(EFICIENCIA)'),
#   28.07017543859649),
#  (('ARQUITECTURA=CAPAS', 'METODOLOGÍA=ÁGIL', 'EFICIENCIA < mean(EFICIENCIA)'),
#   28.048780487804876),
#  (('METODOLOGÍA=ÁGIL', 'ARQUITECTURA=CAPAS', 'EFICIENCIA < mean(EFICIENCIA)'),
#   28.048780487804876),
#  (('CFP > mean(CFP)', 'BD=SQLSERVER', 'EFICIENCIA < mean(EFICIENCIA)'),
#   27.98507462686567),
#  (('BD=SQLSERVER', 'CFP > mean(CFP)', 'EFICIENCIA < mean(EFICIENCIA)'),
#   27.98507462686567),
#  (('ARQUITECTURA=CLIENTE/SERVIDOR',
#    'FRAMEWORK=RAC(PHP)',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   27.941176470588236),
#  (('FRAMEWORK=RAC(PHP)',
#    'ARQUITECTURA=CLIENTE/SERVIDOR',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   27.941176470588236),
#  (('LENGUAJE=PHP', 'FRAMEWORK=OTRO', 'EFICIENCIA < mean(EFICIENCIA)'),
#   27.696793002915452),
#  (('FRAMEWORK=OTRO', 'LENGUAJE=PHP', 'EFICIENCIA < mean(EFICIENCIA)'),
#   27.696793002915452),
#  (('LENGUAJE=PHP', 'METODOLOGÍA=CASCADA', 'EFICIENCIA < mean(EFICIENCIA)'),
#   27.430555555555557),
#  (('METODOLOGÍA=CASCADA', 'LENGUAJE=PHP', 'EFICIENCIA < mean(EFICIENCIA)'),
#   27.430555555555557),
#  (('LENGUAJE=C++', 'METODOLOGÍA=CASCADA', 'EFICIENCIA < mean(EFICIENCIA)'),
#   27.36842105263158),
#  (('METODOLOGÍA=CASCADA', 'LENGUAJE=C++', 'EFICIENCIA < mean(EFICIENCIA)'),
#   27.36842105263158),
#  (('ARQUITECTURA=CAPAS',
#    'BD=POSTGRESQL/INFORMIX',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   27.272727272727273),
#  (('BD=POSTGRESQL/INFORMIX',
#    'ARQUITECTURA=CAPAS',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   27.272727272727273),
#  (('BD=SQLSERVER', 'FRAMEWORK=OTRO', 'EFICIENCIA < mean(EFICIENCIA)'),
#   27.22772277227723),
#  (('FRAMEWORK=OTRO', 'BD=SQLSERVER', 'EFICIENCIA < mean(EFICIENCIA)'),
#   27.22772277227723),
#  (('LENGUAJE=C#', 'BD=POSTGRESQL', 'EFICIENCIA < mean(EFICIENCIA)'),
#   27.184466019417474),
#  (('BD=POSTGRESQL', 'LENGUAJE=C#', 'EFICIENCIA < mean(EFICIENCIA)'),
#   27.184466019417474),
#  (('FRAMEWORK=CSHARP', 'METODOLOGÍA=CASCADA', 'EFICIENCIA < mean(EFICIENCIA)'),
#   27.142857142857142),
#  (('METODOLOGÍA=CASCADA', 'FRAMEWORK=CSHARP', 'EFICIENCIA < mean(EFICIENCIA)'),
#   27.142857142857142),
#  (('LENGUAJE=C++', 'FRAMEWORK=OTRO', 'EFICIENCIA < mean(EFICIENCIA)'),
#   27.061855670103093),
#  (('FRAMEWORK=OTRO', 'LENGUAJE=C++', 'EFICIENCIA < mean(EFICIENCIA)'),
#   27.061855670103093),
#  (('CFP < mean(CFP)', 'BD=SQLSERVER', 'EFICIENCIA < mean(EFICIENCIA)'),
#   27.054794520547944),
#  (('BD=SQLSERVER', 'CFP < mean(CFP)', 'EFICIENCIA < mean(EFICIENCIA)'),
#   27.054794520547944),
#  (('FRAMEWORK=RAC(PHP)',
#    'METODOLOGÍA=CASCADA',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   27.049180327868854),
#  (('METODOLOGÍA=CASCADA',
#    'FRAMEWORK=RAC(PHP)',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   27.049180327868854),
#  (('CFP > mean(CFP)', 'METODOLOGÍA=ÁGIL', 'EFICIENCIA < mean(EFICIENCIA)'),
#   26.923076923076923),
#  (('METODOLOGÍA=ÁGIL', 'CFP > mean(CFP)', 'EFICIENCIA < mean(EFICIENCIA)'),
#   26.923076923076923),
#  (('LENGUAJE=C#', 'METODOLOGÍA=ÁGIL', 'EFICIENCIA < mean(EFICIENCIA)'),
#   26.829268292682926),
#  (('METODOLOGÍA=ÁGIL', 'LENGUAJE=C#', 'EFICIENCIA < mean(EFICIENCIA)'),
#   26.829268292682926),
#  (('BD=POSTGRESQL', 'METODOLOGÍA=CASCADA', 'EFICIENCIA < mean(EFICIENCIA)'),
#   26.821192052980134),
#  (('METODOLOGÍA=CASCADA', 'BD=POSTGRESQL', 'EFICIENCIA < mean(EFICIENCIA)'),
#   26.821192052980134),
#  (('CFP < mean(CFP)', 'LENGUAJE=C#', 'EFICIENCIA < mean(EFICIENCIA)'),
#   26.72811059907834),
#  (('LENGUAJE=C#', 'CFP < mean(CFP)', 'EFICIENCIA < mean(EFICIENCIA)'),
#   26.72811059907834),
#  (('ARQUITECTURA=CLIENTE/SERVIDOR',
#    'LENGUAJE=C++',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   26.692708333333332),
#  (('LENGUAJE=C++',
#    'ARQUITECTURA=CLIENTE/SERVIDOR',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   26.692708333333332),
#  (('LENGUAJE=C++', 'BD=POSTGRESQL', 'EFICIENCIA < mean(EFICIENCIA)'),
#   26.578073089700997),
#  (('BD=POSTGRESQL', 'LENGUAJE=C++', 'EFICIENCIA < mean(EFICIENCIA)'),
#   26.578073089700997),
#  (('BD=SQLSERVER', 'METODOLOGÍA=CASCADA', 'EFICIENCIA < mean(EFICIENCIA)'),
#   26.494565217391305),
#  (('METODOLOGÍA=CASCADA', 'BD=SQLSERVER', 'EFICIENCIA < mean(EFICIENCIA)'),
#   26.494565217391305),
#  (('CFP > mean(CFP)', 'FRAMEWORK=RAC(PHP)', 'EFICIENCIA < mean(EFICIENCIA)'),
#   26.470588235294116),
#  (('LENGUAJE=PHP', 'METODOLOGÍA=ÁGIL', 'EFICIENCIA > mean(EFICIENCIA)'),
#   26.470588235294116),
#  (('FRAMEWORK=RAC(PHP)', 'CFP > mean(CFP)', 'EFICIENCIA < mean(EFICIENCIA)'),
#   26.470588235294116),
#  (('METODOLOGÍA=ÁGIL', 'LENGUAJE=PHP', 'EFICIENCIA > mean(EFICIENCIA)'),
#   26.470588235294116),
#  (('BD=POSTGRESQL', 'METODOLOGÍA=ÁGIL', 'EFICIENCIA < mean(EFICIENCIA)'),
#   26.41509433962264),
#  (('METODOLOGÍA=ÁGIL', 'BD=POSTGRESQL', 'EFICIENCIA < mean(EFICIENCIA)'),
#   26.41509433962264),
#  (('ARQUITECTURA=CLIENTE/SERVIDOR',
#    'LENGUAJE=PHP',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   26.323529411764707),
#  (('LENGUAJE=PHP',
#    'ARQUITECTURA=CLIENTE/SERVIDOR',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   26.323529411764707),
#  (('LENGUAJE=C#', 'FRAMEWORK=CSHARP', 'EFICIENCIA < mean(EFICIENCIA)'),
#   26.31578947368421),
#  (('FRAMEWORK=CSHARP', 'LENGUAJE=C#', 'EFICIENCIA < mean(EFICIENCIA)'),
#   26.31578947368421),
#  (('FRAMEWORK=OTRO', 'METODOLOGÍA=CASCADA', 'EFICIENCIA < mean(EFICIENCIA)'),
#   26.268922528940337),
#  (('METODOLOGÍA=CASCADA', 'FRAMEWORK=OTRO', 'EFICIENCIA < mean(EFICIENCIA)'),
#   26.268922528940337),
#  (('ARQUITECTURA=CLIENTE/SERVIDOR',
#    'METODOLOGÍA=CASCADA',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   26.221640488656195),
#  (('METODOLOGÍA=CASCADA',
#    'ARQUITECTURA=CLIENTE/SERVIDOR',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   26.221640488656195),
#  (('CFP > mean(CFP)', 'LENGUAJE=PHP', 'EFICIENCIA < mean(EFICIENCIA)'),
#   26.20689655172414),
#  (('LENGUAJE=PHP', 'CFP > mean(CFP)', 'EFICIENCIA < mean(EFICIENCIA)'),
#   26.20689655172414),
#  (('ARQUITECTURA=CLIENTE/SERVIDOR',
#    'FRAMEWORK=OTRO',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   26.04267701260912),
#  (('FRAMEWORK=OTRO',
#    'ARQUITECTURA=CLIENTE/SERVIDOR',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   26.04267701260912),
#  (('LENGUAJE=C#', 'FRAMEWORK=OTRO', 'EFICIENCIA < mean(EFICIENCIA)'),
#   25.99206349206349),
#  (('FRAMEWORK=OTRO', 'LENGUAJE=C#', 'EFICIENCIA < mean(EFICIENCIA)'),
#   25.99206349206349),
#  (('LENGUAJE=C++', 'BD=SQLSERVER', 'EFICIENCIA < mean(EFICIENCIA)'),
#   25.974025974025974),
#  (('BD=SQLSERVER', 'LENGUAJE=C++', 'EFICIENCIA < mean(EFICIENCIA)'),
#   25.974025974025974),
#  (('BD=POSTGRESQL', 'FRAMEWORK=OTRO', 'EFICIENCIA < mean(EFICIENCIA)'),
#   25.96439169139466),
#  (('FRAMEWORK=OTRO', 'BD=POSTGRESQL', 'EFICIENCIA < mean(EFICIENCIA)'),
#   25.96439169139466),
#  (('LENGUAJE=C#', 'METODOLOGÍA=CASCADA', 'EFICIENCIA < mean(EFICIENCIA)'),
#   25.93984962406015),
#  (('METODOLOGÍA=CASCADA', 'LENGUAJE=C#', 'EFICIENCIA < mean(EFICIENCIA)'),
#   25.93984962406015),
#  (('ARQUITECTURA=CLIENTE/SERVIDOR',
#    'BD=SQLSERVER',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   25.78616352201258),
#  (('BD=SQLSERVER',
#    'ARQUITECTURA=CLIENTE/SERVIDOR',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   25.78616352201258),
#  (('ARQUITECTURA=CLIENTE/SERVIDOR',
#    'BD=POSTGRESQL',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   25.65982404692082),
#  (('BD=POSTGRESQL',
#    'ARQUITECTURA=CLIENTE/SERVIDOR',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   25.65982404692082),
#  (('LENGUAJE=PHP', 'BD=POSTGRESQL', 'EFICIENCIA < mean(EFICIENCIA)'),
#   25.520833333333332),
#  (('BD=POSTGRESQL', 'LENGUAJE=PHP', 'EFICIENCIA < mean(EFICIENCIA)'),
#   25.520833333333332),
#  (('ARQUITECTURA=CLIENTE/SERVIDOR',
#    'LENGUAJE=C#',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   25.478927203065133),
#  (('LENGUAJE=C#',
#    'ARQUITECTURA=CLIENTE/SERVIDOR',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   25.478927203065133),
#  (('LENGUAJE=C#', 'BD=SQLSERVER', 'EFICIENCIA < mean(EFICIENCIA)'),
#   25.12562814070352),
#  (('BD=SQLSERVER', 'LENGUAJE=C#', 'EFICIENCIA < mean(EFICIENCIA)'),
#   25.12562814070352),
#  (('CFP < mean(CFP)', 'BD=MYSQL', 'EFICIENCIA < mean(EFICIENCIA)'), 25.0),
#  (('ARQUITECTURA=OTRO', 'FRAMEWORK=OTRO', 'EFICIENCIA < mean(EFICIENCIA)'),
#   25.0),
#  (('LENGUAJE=C++',
#    'FRAMEWORK=COPPELFRONTWEB',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   25.0),
#  (('LENGUAJE=C#', 'FRAMEWORK=RAC(PHP)', 'EFICIENCIA < mean(EFICIENCIA)'),
#   25.0),
#  (('BD=MYSQL', 'CFP < mean(CFP)', 'EFICIENCIA < mean(EFICIENCIA)'), 25.0),
#  (('BD=SQLSERVER', 'FRAMEWORK=RAC(PHP)', 'EFICIENCIA < mean(EFICIENCIA)'),
#   25.0),
#  (('BD=POSTGRESQL/INFORMIX',
#    'METODOLOGÍA=ÁGIL',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   25.0),
#  (('FRAMEWORK=OTRO', 'ARQUITECTURA=OTRO', 'EFICIENCIA < mean(EFICIENCIA)'),
#   25.0),
#  (('FRAMEWORK=COPPELFRONTWEB',
#    'LENGUAJE=C++',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   25.0),
#  (('FRAMEWORK=RAC(PHP)', 'LENGUAJE=C#', 'EFICIENCIA < mean(EFICIENCIA)'),
#   25.0),
#  (('FRAMEWORK=RAC(PHP)', 'BD=SQLSERVER', 'EFICIENCIA < mean(EFICIENCIA)'),
#   25.0),
#  (('FRAMEWORK=COPPELFRONTWEB',
#    'METODOLOGÍA=ÁGIL',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   25.0),
#  (('METODOLOGÍA=ÁGIL',
#    'BD=POSTGRESQL/INFORMIX',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   25.0),
#  (('METODOLOGÍA=ÁGIL',
#    'FRAMEWORK=COPPELFRONTWEB',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   25.0),
#  (('CFP > mean(CFP)', 'LENGUAJE=C#', 'EFICIENCIA < mean(EFICIENCIA)'),
#   24.444444444444443),
#  (('LENGUAJE=C#', 'CFP > mean(CFP)', 'EFICIENCIA < mean(EFICIENCIA)'),
#   24.444444444444443),
#  (('LENGUAJE=C++', 'BD=POSTGRESQL/INFORMIX', 'EFICIENCIA > mean(EFICIENCIA)'),
#   23.80952380952381),
#  (('BD=POSTGRESQL/INFORMIX', 'LENGUAJE=C++', 'EFICIENCIA > mean(EFICIENCIA)'),
#   23.80952380952381),
#  (('CFP > mean(CFP)', 'METODOLOGÍA=CASCADA', 'EFICIENCIA < mean(EFICIENCIA)'),
#   23.56020942408377),
#  (('METODOLOGÍA=CASCADA', 'CFP > mean(CFP)', 'EFICIENCIA < mean(EFICIENCIA)'),
#   23.56020942408377),
#  (('ARQUITECTURA=CAPAS',
#    'FRAMEWORK=COPPELFRONTWEB',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   23.529411764705884),
#  (('FRAMEWORK=COPPELFRONTWEB',
#    'ARQUITECTURA=CAPAS',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   23.529411764705884),
#  (('ARQUITECTURA=CAPAS', 'LENGUAJE=C++', 'EFICIENCIA > mean(EFICIENCIA)'),
#   23.076923076923077),
#  (('LENGUAJE=C++', 'ARQUITECTURA=CAPAS', 'EFICIENCIA > mean(EFICIENCIA)'),
#   23.076923076923077),
#  (('CFP > mean(CFP)', 'BD=POSTGRESQL', 'EFICIENCIA < mean(EFICIENCIA)'),
#   22.489082969432314),
#  (('BD=POSTGRESQL', 'CFP > mean(CFP)', 'EFICIENCIA < mean(EFICIENCIA)'),
#   22.489082969432314),
#  (('CFP > mean(CFP)', 'FRAMEWORK=OTRO', 'EFICIENCIA < mean(EFICIENCIA)'),
#   22.277227722772277),
#  (('FRAMEWORK=OTRO', 'CFP > mean(CFP)', 'EFICIENCIA < mean(EFICIENCIA)'),
#   22.277227722772277),
#  (('CFP > mean(CFP)',
#    'ARQUITECTURA=CLIENTE/SERVIDOR',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   21.75925925925926),
#  (('ARQUITECTURA=CLIENTE/SERVIDOR',
#    'CFP > mean(CFP)',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   21.75925925925926),
#  (('BD=SQLSERVER', 'FRAMEWORK=CSHARP', 'EFICIENCIA < mean(EFICIENCIA)'),
#   21.73913043478261),
#  (('FRAMEWORK=CSHARP', 'BD=SQLSERVER', 'EFICIENCIA < mean(EFICIENCIA)'),
#   21.73913043478261),
#  (('ARQUITECTURA=CLIENTE/SERVIDOR',
#    'FRAMEWORK=CSHARP',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   21.666666666666668),
#  (('FRAMEWORK=CSHARP',
#    'ARQUITECTURA=CLIENTE/SERVIDOR',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   21.666666666666668),
#  (('CFP > mean(CFP)', 'LENGUAJE=C++', 'EFICIENCIA < mean(EFICIENCIA)'),
#   20.21276595744681),
#  (('LENGUAJE=C++', 'CFP > mean(CFP)', 'EFICIENCIA < mean(EFICIENCIA)'),
#   20.21276595744681),
#  (('ARQUITECTURA=CLIENTE/SERVIDOR', 'BD=DB2', 'EFICIENCIA < mean(EFICIENCIA)'),
#   20.0),
#  (('ARQUITECTURA=OTRO',
#    'METODOLOGÍA=CASCADA',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   20.0),
#  (('BD=DB2', 'ARQUITECTURA=CLIENTE/SERVIDOR', 'EFICIENCIA < mean(EFICIENCIA)'),
#   20.0),
#  (('METODOLOGÍA=CASCADA',
#    'ARQUITECTURA=OTRO',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   20.0),
#  (('CFP > mean(CFP)',
#    'BD=POSTGRESQL/INFORMIX',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   18.75),
#  (('BD=POSTGRESQL/INFORMIX',
#    'CFP > mean(CFP)',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   18.75),
#  (('CFP > mean(CFP)', 'FRAMEWORK=CSHARP', 'EFICIENCIA < mean(EFICIENCIA)'),
#   17.647058823529413),
#  (('FRAMEWORK=CSHARP', 'CFP > mean(CFP)', 'EFICIENCIA < mean(EFICIENCIA)'),
#   17.647058823529413),
#  (('BD=DB2', 'METODOLOGÍA=ÁGIL', 'EFICIENCIA < mean(EFICIENCIA)'),
#   16.666666666666668),
#  (('METODOLOGÍA=ÁGIL', 'BD=DB2', 'EFICIENCIA < mean(EFICIENCIA)'),
#   16.666666666666668),
#  (('BD=DB2', 'FRAMEWORK=OTRO', 'EFICIENCIA < mean(EFICIENCIA)'), 15.0),
#  (('BD=DB2', 'METODOLOGÍA=CASCADA', 'EFICIENCIA < mean(EFICIENCIA)'), 15.0),
#  (('FRAMEWORK=OTRO', 'BD=DB2', 'EFICIENCIA < mean(EFICIENCIA)'), 15.0),
#  (('METODOLOGÍA=CASCADA', 'BD=DB2', 'EFICIENCIA < mean(EFICIENCIA)'), 15.0),
#  (('CFP < mean(CFP)', 'ARQUITECTURA=OTRO', 'EFICIENCIA < mean(EFICIENCIA)'),
#   12.5),
#  (('ARQUITECTURA=OTRO', 'CFP < mean(CFP)', 'EFICIENCIA < mean(EFICIENCIA)'),
#   12.5),
#  (('FRAMEWORK=CSHARP', 'METODOLOGÍA=ÁGIL', 'EFICIENCIA < mean(EFICIENCIA)'),
#   10.0),
#  (('METODOLOGÍA=ÁGIL', 'FRAMEWORK=CSHARP', 'EFICIENCIA < mean(EFICIENCIA)'),
#   10.0),
#  (('CFP > mean(CFP)', 'ARQUITECTURA=MVC', 'EFICIENCIA > mean(EFICIENCIA)'),
#   0.0),
#  (('CFP > mean(CFP)', 'ARQUITECTURA=OTRO', 'EFICIENCIA > mean(EFICIENCIA)'),
#   0.0),
#  (('CFP < mean(CFP)', 'ARQUITECTURA=MVC', 'EFICIENCIA > mean(EFICIENCIA)'),
#   0.0),
#  (('CFP < mean(CFP)', 'ARQUITECTURA=MVC', 'EFICIENCIA < mean(EFICIENCIA)'),
#   0.0),
#  (('CFP > mean(CFP)', 'BD=MYSQL', 'EFICIENCIA > mean(EFICIENCIA)'), 0.0),
#  (('CFP > mean(CFP)', 'BD=DB2', 'EFICIENCIA < mean(EFICIENCIA)'), 0.0),
#  (('CFP > mean(CFP)', 'FRAMEWORK=VUEJS', 'EFICIENCIA < mean(EFICIENCIA)'),
#   0.0),
#  (('CFP < mean(CFP)', 'FRAMEWORK=VUEJS', 'EFICIENCIA > mean(EFICIENCIA)'),
#   0.0),
#  (('CFP < mean(CFP)', 'FRAMEWORK=VUEJS', 'EFICIENCIA < mean(EFICIENCIA)'),
#   0.0),
#  (('ARQUITECTURA=MVC', 'CFP > mean(CFP)', 'EFICIENCIA > mean(EFICIENCIA)'),
#   0.0),
#  (('ARQUITECTURA=MVC', 'CFP < mean(CFP)', 'EFICIENCIA > mean(EFICIENCIA)'),
#   0.0),
#  (('ARQUITECTURA=MVC', 'CFP < mean(CFP)', 'EFICIENCIA < mean(EFICIENCIA)'),
#   0.0),
# ...
#  (('ARQUITECTURA=OTRO', 'BD=MYSQL', 'EFICIENCIA < mean(EFICIENCIA)'), 0.0),
#  (('ARQUITECTURA=OTRO', 'BD=DB2', 'EFICIENCIA > mean(EFICIENCIA)'), 0.0),
#  (('ARQUITECTURA=OTRO', 'BD=DB2', 'EFICIENCIA < mean(EFICIENCIA)'), 0.0),
#  (('ARQUITECTURA=CLIENTE/SERVIDOR',
#    'FRAMEWORK=VUEJS',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   0.0),
#  (('ARQUITECTURA=CLIENTE/SERVIDOR',
#    'FRAMEWORK=VUEJS',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   0.0),
#  (('ARQUITECTURA=CAPAS', 'FRAMEWORK=VUEJS', 'EFICIENCIA < mean(EFICIENCIA)'),
#   0.0),
#  (('ARQUITECTURA=MVC',
#    'FRAMEWORK=COPPELFRONTWEB',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   0.0),
#  (('ARQUITECTURA=MVC', 'FRAMEWORK=CSHARP', 'EFICIENCIA > mean(EFICIENCIA)'),
#   0.0),
#  (('ARQUITECTURA=MVC', 'FRAMEWORK=CSHARP', 'EFICIENCIA < mean(EFICIENCIA)'),
#   0.0),
#  (('ARQUITECTURA=MVC', 'FRAMEWORK=RAC(PHP)', 'EFICIENCIA > mean(EFICIENCIA)'),
#   0.0),
#  (('ARQUITECTURA=MVC', 'FRAMEWORK=RAC(PHP)', 'EFICIENCIA < mean(EFICIENCIA)'),
#   0.0),
#  (('ARQUITECTURA=MVC', 'FRAMEWORK=VUEJS', 'EFICIENCIA > mean(EFICIENCIA)'),
#   0.0),
#  (('ARQUITECTURA=MVC', 'FRAMEWORK=VUEJS', 'EFICIENCIA < mean(EFICIENCIA)'),
#   0.0),
#  (('ARQUITECTURA=MVC', 'FRAMEWORK=OTRO', 'EFICIENCIA > mean(EFICIENCIA)'),
#   0.0),
#  (('ARQUITECTURA=MVC', 'FRAMEWORK=OTRO', 'EFICIENCIA < mean(EFICIENCIA)'),
#   0.0),
#  (('ARQUITECTURA=OTRO',
#    'FRAMEWORK=COPPELFRONTWEB',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   0.0),
#  (('ARQUITECTURA=OTRO',
#    'FRAMEWORK=COPPELFRONTWEB',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   0.0),
#  (('ARQUITECTURA=OTRO', 'FRAMEWORK=CSHARP', 'EFICIENCIA > mean(EFICIENCIA)'),
#   0.0),
#  (('ARQUITECTURA=OTRO', 'FRAMEWORK=CSHARP', 'EFICIENCIA < mean(EFICIENCIA)'),
#   0.0),
#  (('ARQUITECTURA=OTRO', 'FRAMEWORK=RAC(PHP)', 'EFICIENCIA > mean(EFICIENCIA)'),
#   0.0),
#  (('ARQUITECTURA=OTRO', 'FRAMEWORK=RAC(PHP)', 'EFICIENCIA < mean(EFICIENCIA)'),
#   0.0),
#  (('ARQUITECTURA=OTRO', 'FRAMEWORK=VUEJS', 'EFICIENCIA > mean(EFICIENCIA)'),
#   0.0),
#  (('ARQUITECTURA=OTRO', 'FRAMEWORK=VUEJS', 'EFICIENCIA < mean(EFICIENCIA)'),
#   0.0),
#  (('ARQUITECTURA=MVC', 'METODOLOGÍA=CASCADA', 'EFICIENCIA > mean(EFICIENCIA)'),
#   0.0),
#  (('ARQUITECTURA=MVC', 'METODOLOGÍA=ÁGIL', 'EFICIENCIA > mean(EFICIENCIA)'),
#   0.0),
#  (('ARQUITECTURA=MVC', 'METODOLOGÍA=ÁGIL', 'EFICIENCIA < mean(EFICIENCIA)'),
#   0.0),
#  (('ARQUITECTURA=OTRO', 'METODOLOGÍA=ÁGIL', 'EFICIENCIA > mean(EFICIENCIA)'),
#   0.0),
#  (('LENGUAJE=PHP', 'ARQUITECTURA=MVC', 'EFICIENCIA > mean(EFICIENCIA)'), 0.0),
#  (('LENGUAJE=PHP', 'ARQUITECTURA=OTRO', 'EFICIENCIA > mean(EFICIENCIA)'), 0.0),
#  (('LENGUAJE=PHP', 'ARQUITECTURA=OTRO', 'EFICIENCIA < mean(EFICIENCIA)'), 0.0),
#  (('LENGUAJE=C++', 'ARQUITECTURA=MVC', 'EFICIENCIA > mean(EFICIENCIA)'), 0.0),
#  (('LENGUAJE=C++', 'ARQUITECTURA=MVC', 'EFICIENCIA < mean(EFICIENCIA)'), 0.0),
#  (('LENGUAJE=C++', 'ARQUITECTURA=OTRO', 'EFICIENCIA > mean(EFICIENCIA)'), 0.0),
#  (('LENGUAJE=C++', 'ARQUITECTURA=OTRO', 'EFICIENCIA < mean(EFICIENCIA)'), 0.0),
#  (('LENGUAJE=C#', 'ARQUITECTURA=MVC', 'EFICIENCIA > mean(EFICIENCIA)'), 0.0),
#  (('LENGUAJE=C#', 'ARQUITECTURA=MVC', 'EFICIENCIA < mean(EFICIENCIA)'), 0.0),
#  (('LENGUAJE=C#', 'ARQUITECTURA=OTRO', 'EFICIENCIA > mean(EFICIENCIA)'), 0.0),
#  (('LENGUAJE=C#', 'ARQUITECTURA=OTRO', 'EFICIENCIA < mean(EFICIENCIA)'), 0.0),
#  (('LENGUAJE=PHP', 'BD=DB2', 'EFICIENCIA > mean(EFICIENCIA)'), 0.0),
#  (('LENGUAJE=PHP', 'BD=DB2', 'EFICIENCIA < mean(EFICIENCIA)'), 0.0),
#  (('LENGUAJE=C++', 'BD=MYSQL', 'EFICIENCIA > mean(EFICIENCIA)'), 0.0),
#  (('LENGUAJE=C++', 'BD=MYSQL', 'EFICIENCIA < mean(EFICIENCIA)'), 0.0),
#  (('LENGUAJE=C++', 'BD=DB2', 'EFICIENCIA > mean(EFICIENCIA)'), 0.0),
#  (('LENGUAJE=C++', 'BD=DB2', 'EFICIENCIA < mean(EFICIENCIA)'), 0.0),
#  (('LENGUAJE=C#', 'BD=POSTGRESQL/INFORMIX', 'EFICIENCIA > mean(EFICIENCIA)'),
#   0.0),
#  (('LENGUAJE=C#', 'BD=MYSQL', 'EFICIENCIA > mean(EFICIENCIA)'), 0.0),
#  (('LENGUAJE=C#', 'BD=MYSQL', 'EFICIENCIA < mean(EFICIENCIA)'), 0.0),
#  (('LENGUAJE=C#', 'BD=DB2', 'EFICIENCIA > mean(EFICIENCIA)'), 0.0),
#  (('LENGUAJE=C#', 'BD=DB2', 'EFICIENCIA < mean(EFICIENCIA)'), 0.0),
#  (('LENGUAJE=PHP', 'FRAMEWORK=CSHARP', 'EFICIENCIA > mean(EFICIENCIA)'), 0.0),
#  (('LENGUAJE=PHP', 'FRAMEWORK=CSHARP', 'EFICIENCIA < mean(EFICIENCIA)'), 0.0),
#  (('LENGUAJE=PHP', 'FRAMEWORK=VUEJS', 'EFICIENCIA > mean(EFICIENCIA)'), 0.0),
#  (('LENGUAJE=PHP', 'FRAMEWORK=VUEJS', 'EFICIENCIA < mean(EFICIENCIA)'), 0.0),
#  (('LENGUAJE=C++', 'FRAMEWORK=CSHARP', 'EFICIENCIA < mean(EFICIENCIA)'), 0.0),
#  (('LENGUAJE=C++', 'FRAMEWORK=RAC(PHP)', 'EFICIENCIA > mean(EFICIENCIA)'),
#   0.0),
#  (('LENGUAJE=C++', 'FRAMEWORK=VUEJS', 'EFICIENCIA > mean(EFICIENCIA)'), 0.0),
#  (('LENGUAJE=C++', 'FRAMEWORK=VUEJS', 'EFICIENCIA < mean(EFICIENCIA)'), 0.0),
#  (('LENGUAJE=C#', 'FRAMEWORK=VUEJS', 'EFICIENCIA > mean(EFICIENCIA)'), 0.0),
#  (('LENGUAJE=C#', 'FRAMEWORK=VUEJS', 'EFICIENCIA < mean(EFICIENCIA)'), 0.0),
#  (('BD=MYSQL', 'CFP > mean(CFP)', 'EFICIENCIA > mean(EFICIENCIA)'), 0.0),
#  (('BD=DB2', 'CFP > mean(CFP)', 'EFICIENCIA < mean(EFICIENCIA)'), 0.0),
#  (('BD=POSTGRESQL', 'ARQUITECTURA=MVC', 'EFICIENCIA > mean(EFICIENCIA)'), 0.0),
#  (('BD=POSTGRESQL', 'ARQUITECTURA=MVC', 'EFICIENCIA < mean(EFICIENCIA)'), 0.0),
#  (('BD=POSTGRESQL', 'ARQUITECTURA=OTRO', 'EFICIENCIA > mean(EFICIENCIA)'),
#   0.0),
#  (('BD=POSTGRESQL', 'ARQUITECTURA=OTRO', 'EFICIENCIA < mean(EFICIENCIA)'),
#   0.0),
#  (('BD=SQLSERVER', 'ARQUITECTURA=MVC', 'EFICIENCIA > mean(EFICIENCIA)'), 0.0),
#  (('BD=SQLSERVER', 'ARQUITECTURA=OTRO', 'EFICIENCIA > mean(EFICIENCIA)'), 0.0),
#  (('BD=SQLSERVER', 'ARQUITECTURA=OTRO', 'EFICIENCIA < mean(EFICIENCIA)'), 0.0),
#  (('BD=POSTGRESQL/INFORMIX',
#    'ARQUITECTURA=MVC',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   0.0),
#  (('BD=POSTGRESQL/INFORMIX',
#    'ARQUITECTURA=MVC',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   0.0),
#  (('BD=POSTGRESQL/INFORMIX',
#    'ARQUITECTURA=OTRO',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   0.0),
#  (('BD=POSTGRESQL/INFORMIX',
#    'ARQUITECTURA=OTRO',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   0.0),
#  (('BD=MYSQL', 'ARQUITECTURA=CAPAS', 'EFICIENCIA > mean(EFICIENCIA)'), 0.0),
#  (('BD=MYSQL', 'ARQUITECTURA=CAPAS', 'EFICIENCIA < mean(EFICIENCIA)'), 0.0),
#  (('BD=MYSQL', 'ARQUITECTURA=MVC', 'EFICIENCIA > mean(EFICIENCIA)'), 0.0),
#  (('BD=MYSQL', 'ARQUITECTURA=MVC', 'EFICIENCIA < mean(EFICIENCIA)'), 0.0),
#  (('BD=MYSQL', 'ARQUITECTURA=OTRO', 'EFICIENCIA > mean(EFICIENCIA)'), 0.0),
#  (('BD=MYSQL', 'ARQUITECTURA=OTRO', 'EFICIENCIA < mean(EFICIENCIA)'), 0.0),
#  (('BD=DB2', 'ARQUITECTURA=CAPAS', 'EFICIENCIA < mean(EFICIENCIA)'), 0.0),
#  (('BD=DB2', 'ARQUITECTURA=MVC', 'EFICIENCIA > mean(EFICIENCIA)'), 0.0),
#  (('BD=DB2', 'ARQUITECTURA=MVC', 'EFICIENCIA < mean(EFICIENCIA)'), 0.0),
#  (('BD=DB2', 'ARQUITECTURA=OTRO', 'EFICIENCIA > mean(EFICIENCIA)'), 0.0),
#  (('BD=DB2', 'ARQUITECTURA=OTRO', 'EFICIENCIA < mean(EFICIENCIA)'), 0.0),
#  (('BD=POSTGRESQL/INFORMIX', 'LENGUAJE=C#', 'EFICIENCIA > mean(EFICIENCIA)'),
#   0.0),
#  (('BD=MYSQL', 'LENGUAJE=C++', 'EFICIENCIA > mean(EFICIENCIA)'), 0.0),
#  (('BD=MYSQL', 'LENGUAJE=C++', 'EFICIENCIA < mean(EFICIENCIA)'), 0.0),
#  (('BD=MYSQL', 'LENGUAJE=C#', 'EFICIENCIA > mean(EFICIENCIA)'), 0.0),
#  (('BD=MYSQL', 'LENGUAJE=C#', 'EFICIENCIA < mean(EFICIENCIA)'), 0.0),
#  (('BD=DB2', 'LENGUAJE=PHP', 'EFICIENCIA > mean(EFICIENCIA)'), 0.0),
#  (('BD=DB2', 'LENGUAJE=PHP', 'EFICIENCIA < mean(EFICIENCIA)'), 0.0),
#  (('BD=DB2', 'LENGUAJE=C++', 'EFICIENCIA > mean(EFICIENCIA)'), 0.0),
#  (('BD=DB2', 'LENGUAJE=C++', 'EFICIENCIA < mean(EFICIENCIA)'), 0.0),
#  (('BD=DB2', 'LENGUAJE=C#', 'EFICIENCIA > mean(EFICIENCIA)'), 0.0),
#  (('BD=DB2', 'LENGUAJE=C#', 'EFICIENCIA < mean(EFICIENCIA)'), 0.0),
#  (('BD=POSTGRESQL', 'FRAMEWORK=VUEJS', 'EFICIENCIA < mean(EFICIENCIA)'), 0.0),
#  (('BD=SQLSERVER', 'FRAMEWORK=VUEJS', 'EFICIENCIA > mean(EFICIENCIA)'), 0.0),
#  (('BD=SQLSERVER', 'FRAMEWORK=VUEJS', 'EFICIENCIA < mean(EFICIENCIA)'), 0.0),
#  (('BD=POSTGRESQL/INFORMIX',
#    'FRAMEWORK=COPPELFRONTWEB',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   0.0),
#  (('BD=POSTGRESQL/INFORMIX',
#    'FRAMEWORK=CSHARP',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   0.0),
#  (('BD=POSTGRESQL/INFORMIX',
#    'FRAMEWORK=CSHARP',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   0.0),
#  (('BD=POSTGRESQL/INFORMIX',
#    'FRAMEWORK=RAC(PHP)',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   0.0),
#  (('BD=POSTGRESQL/INFORMIX',
#    'FRAMEWORK=RAC(PHP)',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   0.0),
#  (('BD=POSTGRESQL/INFORMIX',
#    'FRAMEWORK=VUEJS',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   0.0),
#  (('BD=POSTGRESQL/INFORMIX',
#    'FRAMEWORK=VUEJS',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   0.0),
#  (('BD=MYSQL', 'FRAMEWORK=COPPELFRONTWEB', 'EFICIENCIA > mean(EFICIENCIA)'),
#   0.0),
#  (('BD=MYSQL', 'FRAMEWORK=COPPELFRONTWEB', 'EFICIENCIA < mean(EFICIENCIA)'),
#   0.0),
#  (('BD=MYSQL', 'FRAMEWORK=CSHARP', 'EFICIENCIA > mean(EFICIENCIA)'), 0.0),
#  (('BD=MYSQL', 'FRAMEWORK=CSHARP', 'EFICIENCIA < mean(EFICIENCIA)'), 0.0),
#  (('BD=MYSQL', 'FRAMEWORK=RAC(PHP)', 'EFICIENCIA > mean(EFICIENCIA)'), 0.0),
#  (('BD=MYSQL', 'FRAMEWORK=RAC(PHP)', 'EFICIENCIA < mean(EFICIENCIA)'), 0.0),
#  (('BD=MYSQL', 'FRAMEWORK=VUEJS', 'EFICIENCIA > mean(EFICIENCIA)'), 0.0),
#  (('BD=MYSQL', 'FRAMEWORK=VUEJS', 'EFICIENCIA < mean(EFICIENCIA)'), 0.0),
#  (('BD=DB2', 'FRAMEWORK=COPPELFRONTWEB', 'EFICIENCIA > mean(EFICIENCIA)'),
#   0.0),
#  (('BD=DB2', 'FRAMEWORK=COPPELFRONTWEB', 'EFICIENCIA < mean(EFICIENCIA)'),
#   0.0),
#  (('BD=DB2', 'FRAMEWORK=CSHARP', 'EFICIENCIA > mean(EFICIENCIA)'), 0.0),
#  (('BD=DB2', 'FRAMEWORK=CSHARP', 'EFICIENCIA < mean(EFICIENCIA)'), 0.0),
#  (('BD=DB2', 'FRAMEWORK=RAC(PHP)', 'EFICIENCIA > mean(EFICIENCIA)'), 0.0),
#  (('BD=DB2', 'FRAMEWORK=RAC(PHP)', 'EFICIENCIA < mean(EFICIENCIA)'), 0.0),
#  (('BD=DB2', 'FRAMEWORK=VUEJS', 'EFICIENCIA > mean(EFICIENCIA)'), 0.0),
#  (('BD=DB2', 'FRAMEWORK=VUEJS', 'EFICIENCIA < mean(EFICIENCIA)'), 0.0),
#  (('BD=MYSQL', 'METODOLOGÍA=ÁGIL', 'EFICIENCIA > mean(EFICIENCIA)'), 0.0),
#  (('BD=MYSQL', 'METODOLOGÍA=ÁGIL', 'EFICIENCIA < mean(EFICIENCIA)'), 0.0),
#  (('FRAMEWORK=VUEJS', 'CFP > mean(CFP)', 'EFICIENCIA < mean(EFICIENCIA)'),
#   0.0),
#  (('FRAMEWORK=VUEJS', 'CFP < mean(CFP)', 'EFICIENCIA > mean(EFICIENCIA)'),
#   0.0),
#  (('FRAMEWORK=VUEJS', 'CFP < mean(CFP)', 'EFICIENCIA < mean(EFICIENCIA)'),
#   0.0),
#  (('FRAMEWORK=COPPELFRONTWEB',
#    'ARQUITECTURA=MVC',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   0.0),
#  (('FRAMEWORK=COPPELFRONTWEB',
#    'ARQUITECTURA=OTRO',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   0.0),
#  (('FRAMEWORK=COPPELFRONTWEB',
#    'ARQUITECTURA=OTRO',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   0.0),
#  (('FRAMEWORK=CSHARP', 'ARQUITECTURA=MVC', 'EFICIENCIA > mean(EFICIENCIA)'),
#   0.0),
#  (('FRAMEWORK=CSHARP', 'ARQUITECTURA=MVC', 'EFICIENCIA < mean(EFICIENCIA)'),
#   0.0),
#  (('FRAMEWORK=CSHARP', 'ARQUITECTURA=OTRO', 'EFICIENCIA > mean(EFICIENCIA)'),
#   0.0),
#  (('FRAMEWORK=CSHARP', 'ARQUITECTURA=OTRO', 'EFICIENCIA < mean(EFICIENCIA)'),
#   0.0),
#  (('FRAMEWORK=RAC(PHP)', 'ARQUITECTURA=MVC', 'EFICIENCIA > mean(EFICIENCIA)'),
#   0.0),
#  (('FRAMEWORK=RAC(PHP)', 'ARQUITECTURA=MVC', 'EFICIENCIA < mean(EFICIENCIA)'),
#   0.0),
#  (('FRAMEWORK=RAC(PHP)', 'ARQUITECTURA=OTRO', 'EFICIENCIA > mean(EFICIENCIA)'),
#   0.0),
#  (('FRAMEWORK=RAC(PHP)', 'ARQUITECTURA=OTRO', 'EFICIENCIA < mean(EFICIENCIA)'),
#   0.0),
#  (('FRAMEWORK=VUEJS',
#    'ARQUITECTURA=CLIENTE/SERVIDOR',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   0.0),
#  (('FRAMEWORK=VUEJS',
#    'ARQUITECTURA=CLIENTE/SERVIDOR',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   0.0),
#  (('FRAMEWORK=VUEJS', 'ARQUITECTURA=CAPAS', 'EFICIENCIA < mean(EFICIENCIA)'),
#   0.0),
#  (('FRAMEWORK=VUEJS', 'ARQUITECTURA=MVC', 'EFICIENCIA > mean(EFICIENCIA)'),
#   0.0),
#  (('FRAMEWORK=VUEJS', 'ARQUITECTURA=MVC', 'EFICIENCIA < mean(EFICIENCIA)'),
#   0.0),
#  (('FRAMEWORK=VUEJS', 'ARQUITECTURA=OTRO', 'EFICIENCIA > mean(EFICIENCIA)'),
#   0.0),
#  (('FRAMEWORK=VUEJS', 'ARQUITECTURA=OTRO', 'EFICIENCIA < mean(EFICIENCIA)'),
#   0.0),
#  (('FRAMEWORK=OTRO', 'ARQUITECTURA=MVC', 'EFICIENCIA > mean(EFICIENCIA)'),
#   0.0),
#  (('FRAMEWORK=OTRO', 'ARQUITECTURA=MVC', 'EFICIENCIA < mean(EFICIENCIA)'),
#   0.0),
#  (('FRAMEWORK=CSHARP', 'LENGUAJE=PHP', 'EFICIENCIA > mean(EFICIENCIA)'), 0.0),
#  (('FRAMEWORK=CSHARP', 'LENGUAJE=PHP', 'EFICIENCIA < mean(EFICIENCIA)'), 0.0),
#  (('FRAMEWORK=CSHARP', 'LENGUAJE=C++', 'EFICIENCIA < mean(EFICIENCIA)'), 0.0),
#  (('FRAMEWORK=RAC(PHP)', 'LENGUAJE=C++', 'EFICIENCIA > mean(EFICIENCIA)'),
#   0.0),
#  (('FRAMEWORK=VUEJS', 'LENGUAJE=PHP', 'EFICIENCIA > mean(EFICIENCIA)'), 0.0),
#  (('FRAMEWORK=VUEJS', 'LENGUAJE=PHP', 'EFICIENCIA < mean(EFICIENCIA)'), 0.0),
#  (('FRAMEWORK=VUEJS', 'LENGUAJE=C++', 'EFICIENCIA > mean(EFICIENCIA)'), 0.0),
#  (('FRAMEWORK=VUEJS', 'LENGUAJE=C++', 'EFICIENCIA < mean(EFICIENCIA)'), 0.0),
#  (('FRAMEWORK=VUEJS', 'LENGUAJE=C#', 'EFICIENCIA > mean(EFICIENCIA)'), 0.0),
#  (('FRAMEWORK=VUEJS', 'LENGUAJE=C#', 'EFICIENCIA < mean(EFICIENCIA)'), 0.0),
#  (('FRAMEWORK=COPPELFRONTWEB',
#    'BD=POSTGRESQL/INFORMIX',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   0.0),
#  (('FRAMEWORK=COPPELFRONTWEB', 'BD=MYSQL', 'EFICIENCIA > mean(EFICIENCIA)'),
#   0.0),
#  (('FRAMEWORK=COPPELFRONTWEB', 'BD=MYSQL', 'EFICIENCIA < mean(EFICIENCIA)'),
#   0.0),
#  (('FRAMEWORK=COPPELFRONTWEB', 'BD=DB2', 'EFICIENCIA > mean(EFICIENCIA)'),
#   0.0),
#  (('FRAMEWORK=COPPELFRONTWEB', 'BD=DB2', 'EFICIENCIA < mean(EFICIENCIA)'),
#   0.0),
#  (('FRAMEWORK=CSHARP',
#    'BD=POSTGRESQL/INFORMIX',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   0.0),
#  (('FRAMEWORK=CSHARP',
#    'BD=POSTGRESQL/INFORMIX',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   0.0),
#  (('FRAMEWORK=CSHARP', 'BD=MYSQL', 'EFICIENCIA > mean(EFICIENCIA)'), 0.0),
#  (('FRAMEWORK=CSHARP', 'BD=MYSQL', 'EFICIENCIA < mean(EFICIENCIA)'), 0.0),
#  (('FRAMEWORK=CSHARP', 'BD=DB2', 'EFICIENCIA > mean(EFICIENCIA)'), 0.0),
#  (('FRAMEWORK=CSHARP', 'BD=DB2', 'EFICIENCIA < mean(EFICIENCIA)'), 0.0),
#  (('FRAMEWORK=RAC(PHP)',
#    'BD=POSTGRESQL/INFORMIX',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   0.0),
#  (('FRAMEWORK=RAC(PHP)',
#    'BD=POSTGRESQL/INFORMIX',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   0.0),
#  (('FRAMEWORK=RAC(PHP)', 'BD=MYSQL', 'EFICIENCIA > mean(EFICIENCIA)'), 0.0),
#  (('FRAMEWORK=RAC(PHP)', 'BD=MYSQL', 'EFICIENCIA < mean(EFICIENCIA)'), 0.0),
#  (('FRAMEWORK=RAC(PHP)', 'BD=DB2', 'EFICIENCIA > mean(EFICIENCIA)'), 0.0),
#  (('FRAMEWORK=RAC(PHP)', 'BD=DB2', 'EFICIENCIA < mean(EFICIENCIA)'), 0.0),
#  (('FRAMEWORK=VUEJS', 'BD=POSTGRESQL', 'EFICIENCIA < mean(EFICIENCIA)'), 0.0),
#  (('FRAMEWORK=VUEJS', 'BD=SQLSERVER', 'EFICIENCIA > mean(EFICIENCIA)'), 0.0),
#  (('FRAMEWORK=VUEJS', 'BD=SQLSERVER', 'EFICIENCIA < mean(EFICIENCIA)'), 0.0),
#  (('FRAMEWORK=VUEJS',
#    'BD=POSTGRESQL/INFORMIX',
#    'EFICIENCIA > mean(EFICIENCIA)'),
#   0.0),
#  (('FRAMEWORK=VUEJS',
#    'BD=POSTGRESQL/INFORMIX',
#    'EFICIENCIA < mean(EFICIENCIA)'),
#   0.0),
#  (('FRAMEWORK=VUEJS', 'BD=MYSQL', 'EFICIENCIA > mean(EFICIENCIA)'), 0.0),
#  (('FRAMEWORK=VUEJS', 'BD=MYSQL', 'EFICIENCIA < mean(EFICIENCIA)'), 0.0),
#  (('FRAMEWORK=VUEJS', 'BD=DB2', 'EFICIENCIA > mean(EFICIENCIA)'), 0.0),
#  (('FRAMEWORK=VUEJS', 'BD=DB2', 'EFICIENCIA < mean(EFICIENCIA)'), 0.0),
#  (('FRAMEWORK=RAC(PHP)', 'METODOLOGÍA=ÁGIL', 'EFICIENCIA > mean(EFICIENCIA)'),
#   0.0),
#  (('FRAMEWORK=VUEJS', 'METODOLOGÍA=CASCADA', 'EFICIENCIA < mean(EFICIENCIA)'),
#   0.0),
#  (('FRAMEWORK=VUEJS', 'METODOLOGÍA=ÁGIL', 'EFICIENCIA > mean(EFICIENCIA)'),
#   0.0),
#  (('FRAMEWORK=VUEJS', 'METODOLOGÍA=ÁGIL', 'EFICIENCIA < mean(EFICIENCIA)'),
#   0.0),
#  (('METODOLOGÍA=CASCADA', 'ARQUITECTURA=MVC', 'EFICIENCIA > mean(EFICIENCIA)'),
#   0.0),
#  (('METODOLOGÍA=ÁGIL', 'ARQUITECTURA=MVC', 'EFICIENCIA > mean(EFICIENCIA)'),
#   0.0),
#  (('METODOLOGÍA=ÁGIL', 'ARQUITECTURA=MVC', 'EFICIENCIA < mean(EFICIENCIA)'),
#   0.0),
#  (('METODOLOGÍA=ÁGIL', 'ARQUITECTURA=OTRO', 'EFICIENCIA > mean(EFICIENCIA)'),
#   0.0),
#  (('METODOLOGÍA=ÁGIL', 'BD=MYSQL', 'EFICIENCIA > mean(EFICIENCIA)'), 0.0),
#  (('METODOLOGÍA=ÁGIL', 'BD=MYSQL', 'EFICIENCIA < mean(EFICIENCIA)'), 0.0),
#  (('METODOLOGÍA=CASCADA', 'FRAMEWORK=VUEJS', 'EFICIENCIA < mean(EFICIENCIA)'),
#   0.0),
#  (('METODOLOGÍA=ÁGIL', 'FRAMEWORK=RAC(PHP)', 'EFICIENCIA > mean(EFICIENCIA)'),
#   0.0),
#  (('METODOLOGÍA=ÁGIL', 'FRAMEWORK=VUEJS', 'EFICIENCIA > mean(EFICIENCIA)'),
#   0.0),
#  (('METODOLOGÍA=ÁGIL', 'FRAMEWORK=VUEJS', 'EFICIENCIA < mean(EFICIENCIA)'),
#   0.0)]

# %%
for (premise_i_label, premise_j_label, conclusion_label), support in sorted(supports.items(), key=itemgetter(1), reverse=True):

    if premise_i_label > premise_j_label:
        continue

    if support < 10:
        continue

    total = occurrences[(premise_i_label, premise_j_label)]

    if total == 0:
        continue

    confidence = confidences[(premise_i_label, premise_j_label, conclusion_label)]

    if confidence < 60:
        continue

    print("SI {} y {}, ENTONCES, {}".format(premise_i_label, premise_j_label, conclusion_label))

    print("SUPPORT: {} TOTAL: {} CONFIDENCE: {:.2f}".format(support, total, confidence))
# Out:
# SI BD=POSTGRESQL/INFORMIX y CFP > mean(CFP), ENTONCES, EFICIENCIA > mean(EFICIENCIA)
# SUPPORT: 20 TOTAL: 64 CONFIDENCE: 62.50
# SI CFP > mean(CFP) y FRAMEWORK=CSHARP, ENTONCES, EFICIENCIA > mean(EFICIENCIA)
# SUPPORT: 11 TOTAL: 34 CONFIDENCE: 64.71
